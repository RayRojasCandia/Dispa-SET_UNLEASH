# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; color: #000099;">
#     <div style="text-align: center;">
#         <span style="font-weight: bold; font-size: 18px; letter-spacing: 1px; text-transform: uppercase;">
#         Time Series Data Processing
#         </span>
#         <br>
#         <span style="font-weight: bold; font-size: 28px; font-style: italic; letter-spacing: 5px;">
#             Load Real Time (Power Sector)
#             <br>
#             Demand Hot Water (Sector X - VPP Resistive Units)
#         </span>
#         <br>
#         <span style="font-weight: bold; font-size: 18px;">
#             Main Formatting Notebook
#         </span>
#     </div>
#     <table style="margin: 20px auto; color: #000099; border-collapse: collapse; text-align: center;">
#         <tr style="background-color: #E6E6E6;">
#             <td style="font-size: 14px; padding: 10px 40px; opacity: 0.8;"><b>FROM</b></td>
#             <td style="font-size: 14px; padding: 10px 40px; opacity: 0.8;"><b>TO</b></td>
#         </tr>
#         <tr style="background-color: #CCCCCC; font-size: 22px; font-style: italic; font-weight: bold;">
#             <td style="padding: 5px 40px 15px 40px;">PYPSA | négaWatt</td>
#             <td style="padding: 5px 40px 15px 40px;">DISPA-SET | Unleash</td>
#         </tr>
#     </table>
#     <div style="border-top: 1px solid #000099; padding: 10px">
#         This notebook processes techno-economic information extracted from <b>PyPSA</b> simulation outputs and converts the resulting infrastructure, operational, and demand-related datasets into formats compatible with the <b>Dispa-SET Unleash</b> framework.
#     </div>
# </div>

# %%
                        import os
                        import csv
from datetime           import datetime
                        import requests
                        import pandas                                 as pd
from shutil             import move
                        import numpy                                  as np
                        import shutil
from bs4                import BeautifulSoup
                        import re
                        import io
                        import plotly.graph_objects                   as go
from typing             import List, Dict, Tuple, Optional, Tuple
from IPython.display    import HTML
from difflib            import get_close_matches
from collections        import defaultdict
                        import warnings
from pathlib            import Path
                        import glob
from itertools          import permutations
from itertools          import combinations
                        import json
                        import calendar

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 12px; text-align: right; color: #000099;">
#         <span style="text-transform: uppercase;">
#         <b>Auxiliary Code</b>
#         </span>
#             <div style="border-top: 1px solid #000099; padding: 10px">
#             This cell facilitates the creation of project directories corresponding to
#             </div>
#         <b>ENTSO-E member countries</b>.
#         <br>
#         <span style="font-style: italic; opacity: 0.8;">
#         Note: Uncomment the code below only if a fresh directory structure is required.</span>
#     </div>
# </div>

# %%
"""
# List of countries with their acronyms in parentheses
countries = [
    "Albania       (AL)", "Armenia        (AM)", "Austria          (AT)", "Azerbaijan (AZ)",
    "Belarus       (BY)", "Belgium        (BE)", "Bosnia and Herz. (BA)", "Bulgaria   (BG)",
    "Croatia       (HR)", "Cyprus         (CY)", "Czech Republic   (CZ)", "Denmark    (DK)",
    "Estonia       (EE)", "Finland        (FI)", "France           (FR)", "Georgia    (GE)",
    "Germany       (DE)", "Greece         (EL)", "Hungary          (HU)", "Iceland    (IS)",
    "Ireland       (IE)", "Italy          (IT)", "Kosovo           (XK)", "Latvia     (LV)",
    "Lithuania     (LT)", "Luxembourg     (LU)", "Malta            (MT)", "Moldova    (MD)",
    "Montenegro    (ME)", "Netherlands    (NL)", "North Macedonia  (MK)", "Norway     (NO)",
    "Poland        (PL)", "Portugal       (PT)", "Romania          (RO)", "Russia     (RU)",
    "Russia Legacy (RU)", "Serbia         (RS)", "Slovakia         (SK)", "Slovenia   (SI)",
    "Spain         (ES)", "Sweden         (SE)", "Switzerland      (CH)", "Turkey     (TR)",
    "Ukraine       (UA)", "United Kingdom (UK)"
]
# Set the path where you want to create the folders
base_path = '/home/ray/Dispa-SET_Unleash/Database_PyPSA/Suficiency_Scenario/PowerPlants'
# Ensure the base path exists
os.makedirs(base_path, exist_ok=True)
# Loop through the list of countries
for country_string in countries:
    # Use a regular expression to find the acronym inside the parentheses
    match = re.search(r'\((.*?)\)', country_string)
    # If a match is found, extract the acronym
    if match:
        acronym = match.group(1).strip()  # Use strip() to remove any extra whitespace
        folder_path = os.path.join(base_path, acronym)
        # Check if the folder already exists to avoid errors
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)
            print(f"Created folder: {folder_path}")
        else:
            print(f"Folder already exists: {folder_path}")
    else:
        print(f"Could not extract acronym from: {country_string}")
print("\nAll folders created successfully!")
"""
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\('
# <>:1: SyntaxWarning: invalid escape sequence '\('
# /tmp/ipykernel_3482812/3390782925.py:1: SyntaxWarning: invalid escape sequence '\('
#   """
# '\n# List of countries with their acronyms in parentheses\ncountries = [\n    "Albania       (AL)", "Armenia        (AM)", "Austria          (AT)", "Azerbaijan (AZ)",\n    "Belarus       (BY)", "Belgium        (BE)", "Bosnia and Herz. (BA)", "Bulgaria   (BG)",\n    "Croatia       (HR)", "Cyprus         (CY)", "Czech Republic   (CZ)", "Denmark    (DK)",\n    "Estonia       (EE)", "Finland        (FI)", "France           (FR)", "Georgia    (GE)",\n    "Germany       (DE)", "Greece         (EL)", "Hungary          (HU)", "Iceland    (IS)",\n    "Ireland       (IE)", "Italy          (IT)", "Kosovo           (XK)", "Latvia     (LV)",\n    "Lithuania     (LT)", "Luxembourg     (LU)", "Malta            (MT)", "Moldova    (MD)",\n    "Montenegro    (ME)", "Netherlands    (NL)", "North Macedonia  (MK)", "Norway     (NO)",\n    "Poland        (PL)", "Portugal       (PT)", "Romania          (RO)", "Russia     (RU)",\n    "Russia Legacy (RU)", "Serbia         (RS)", "Slovakia         (SK)", "Slovenia   (SI)",\n    "Spain         (ES)", "Sweden         (SE)", "Switzerland      (CH)", "Turkey     (TR)",\n    "Ukraine       (UA)", "United Kingdom (UK)"\n]\n# Set the path where you want to create the folders\nbase_path = \'/home/ray/Dispa-SET_Unleash/Database_PyPSA/Suficiency_Scenario/PowerPlants\'\n# Ensure the base path exists\nos.makedirs(base_path, exist_ok=True)\n# Loop through the list of countries\nfor country_string in countries:\n    # Use a regular expression to find the acronym inside the parentheses\n    match = re.search(r\'\\((.*?)\\)\', country_string)\n    # If a match is found, extract the acronym\n    if match:\n        acronym = match.group(1).strip()  # Use strip() to remove any extra whitespace\n        folder_path = os.path.join(base_path, acronym)\n        # Check if the folder already exists to avoid errors\n        if not os.path.exists(folder_path):\n            os.makedirs(folder_path)\n            print(f"Created folder: {folder_path}")\n        else:\n            print(f"Folder already exists: {folder_path}")\n    else:\n        print(f"Could not extract acronym from: {country_string}")\nprint("\nAll folders created successfully!")\n'

# %% [markdown]
# <div style= "background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099; " >
#  <span style= "font-weight: bold; font-size: 16px; " >
# Section A Overview: Configuration & Environment Setup
#  </span >
#  <div style= "border-top: 1px solid #000099; padding: 10px; " >
# This section establishes the foundational configuration for the demand processing pipeline. <br>It defines the directory structures, selects the target PyPSA scenario, configures the Virtual Power Plant (VPP) mode flag, sets the target time step (e.g., 1h), and specifies the geographical zones and target year for the simulation.
#  </div >
#  </div >
#  <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#     A-01. Dispa-SET Unleash Folder Path
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#     This step dynamically determines the <b>zone_folder_path</b> by locating the <i>"Dispa-SET_Unleash"</i> directory relative to your current workspace.
#     </div>
# </div>

# %%
### Get the directory two levels up from the current working directory
dispaSET_unleash_folder_path = Path.cwd().parent.parent
print(f"{"dispaSET_unleash_folder_path:":<55} {dispaSET_unleash_folder_path}")
# Out:
# dispaSET_unleash_folder_path:                           /home/ray/Dispa-SET_Unleash

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#        A-02. PyPSA Source Scenario
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         There are two primary scenarios available as sources for the PyPSA raw data:<br>
#     <div style="margin-left: 2em; font-size: 12px">
#     <li> <b> Reference_Scenario   </b></li>
#     <li> <b> Sufficiency_Scenario </b></li>
#     </div>
#     </div>
# </div>

# %%
### Set the configuration
# =============================================================================
#pypsa_scenario = "Reference_Scenario"
pypsa_scenario = "Sufficiency_Scenario"
# =============================================================================
print(f"{"PyPSA Chosen Scenario:":<55} {pypsa_scenario}")
# Out:
# PyPSA Chosen Scenario:                                  Sufficiency_Scenario

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         A-03. VPP (Virtual Power Plant) Mode Flag
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         The <b>VPP flag</b> controls whether the model operates in <b>Virtual Power Plant mode</b>. When enabled, additional carriers (e.g., resistive heaters) are activated to model sector-coupling and demand-side flexibility.<br>
#     <b>Flag Logic:</b><br>
#         <div style="margin-left: 2em; font-size: 12px">
#         <li> <b> VPP = True</b>: Activates VPP mode, appending resistive heater carriers (e.g., <b>residential rural resistive heater</b>) to the <b>power_units_carriers</b> list.<br>
#         <li> <b> VPP = False</b>: Disables VPP mode, limiting the model to core generation and storage technologies.<br>
#         </div>
#         The flag is used throughout the workflow to conditionally include sector-coupling components and enable multi-energy system modeling.<br>
#         Toggling this flag allows for rapid scenario switching between a pure power-sector model and a fully integrated multi-energy system with heat, transport, and industry components.
#     </div>
# </div>

# %%
# VPP FLAG
# =============================================================================
VPP = True
#VPP = False
# =============================================================================

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#            A-04. Secondary Folders Path
#         </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         The internal architecture of the <i>Dispa-SET Unleash</i> directory contains several subfolders that must be mapped to specific path variables for accurate data retrieval.
#     </div>
# </div>

# %%
### Convert the string path into a Path object
dispaSET_unleash_folder_path = Path(dispaSET_unleash_folder_path)
### Base Power Plants Data
pypsa_raw_data_folder_path = dispaSET_unleash_folder_path / "RawData_PyPSA"
print(f"{'pypsa_raw_data_folder_path:':<45} {pypsa_raw_data_folder_path}")
print("—" * 140)
### PyPSA Raw Data
loads_pypsa_raw_data_folder_path = (
    dispaSET_unleash_folder_path
    / "RawData_PyPSA"
    / pypsa_scenario
    / "Load_RealTime"
)
print(f"{'loads_pypsa_raw_data_folder_path:':<45} {loads_pypsa_raw_data_folder_path}")
print("—" * 140)
### PyPSA Formatted Data
loads_pypsa_formated_data_folder_path = (
    dispaSET_unleash_folder_path
    / "Database_PyPSA"
    / pypsa_scenario
    / "Load_RealTime"
)
print(f"{'loads_pypsa_formated_data_folder_path:':<45} {loads_pypsa_formated_data_folder_path}")
print("—" * 140)
### PyPSA Formatted Data with VPP
vpp_scenario_folder = f"{pypsa_scenario}________VPP" 
vpp_loads_pypsa_formated_data_folder_path = (
    dispaSET_unleash_folder_path / "Database_PyPSA"
    / vpp_scenario_folder
    / "Load_RealTime"
)
print(f"{'vpp_loads_pypsa_formated_data_folder_path:':<45} {vpp_loads_pypsa_formated_data_folder_path}")
print("—" * 140)
### PyPSA VPP Features Data
vpp_features_data_folder_path = (
    dispaSET_unleash_folder_path
    / "Database_PyPSA"
    / vpp_scenario_folder
    / "VPP_data" / "VPP_features"
)
print(f"{'vpp_features_data_folder_path:':<45} {vpp_features_data_folder_path}")
print("—" * 140)
### PyPSA VPP Demand Data
vpp_demand_data_folder_path = (
    dispaSET_unleash_folder_path
    / "Database_PyPSA"
    / vpp_scenario_folder
    / "VPP_data"
    / "VPP_demand"
)
print(f"{'vpp_demand_data_folder_path:':<45} {vpp_demand_data_folder_path}")
print("—" * 140)
### POWER PLANTS DATA
power_plants_pypsa_formated_data_folder_path = (
    dispaSET_unleash_folder_path
    / "Database_PyPSA"
    / pypsa_scenario
    / "PowerPlants"
)
print(f"{'power_plants_pypsa_formated_data_folder_path:':<45} {power_plants_pypsa_formated_data_folder_path}")
# PyPSA Data Formatted Data with VPP
#vpp_scenario_folder = f"{pypsa_scenario}________VPP" 
#vpp_data_pypsa_formated_data_folder_path = (
#    dispaSET_unleash_folder_path / "Database_PyPSA" / vpp_scenario_folder / "VPP_data"
#)
#print(f"{'vpp_data_pypsa_formated_data_folder_path:':<55} {vpp_data_pypsa_formated_data_folder_path}")
#print("—" * 140)
# Out:
# pypsa_raw_data_folder_path:                   /home/ray/Dispa-SET_Unleash/RawData_PyPSA
# ————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# loads_pypsa_raw_data_folder_path:             /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/Load_RealTime
# ————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# loads_pypsa_formated_data_folder_path:        /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario/Load_RealTime
# ————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# vpp_loads_pypsa_formated_data_folder_path:    /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario________VPP/Load_RealTime
# ————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# vpp_features_data_folder_path:                /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario________VPP/VPP_data/VPP_features
# ————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# vpp_demand_data_folder_path:                  /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario________VPP/VPP_data/VPP_demand
# ————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————————
# power_plants_pypsa_formated_data_folder_path: /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario/PowerPlants

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#        A-05. Dispa-SET Time Step
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         The time series data must be resampled to a predetermined time step.
#         <br>
#         The UNLEASH project utilizes three levels of granularity:
#         <div style="margin-left: 2em; font-size: 12px">
#             <li>One hour (1h)</li>
#             <li>Thirty minutes (30min)</li>
#             <li>Fifteen minutes (15min)</li>
#         </div>
#     </div>
# </div>

# %%
### Set the time step to which data is formating to 
data_target_time_step = '1h'
# data_target_time_step = '15min'
# data_target_time_step = '30min'
print(f"{"Selected time step:":<55} {data_target_time_step}")
# Out:
# Selected time step:                                     1h

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         A-06. Zone(s) Configuration
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         Define the target geographical zone(s) for data processing. This selection determines which regional datasets will be accessed and where the resulting formatted files will be stored.
#         <br>
#         Use <b>ISO 3166-1 alpha-2</b> standard codes for European countries (e.g., <i>AT, BE, BG, CH, DE, FR</i>).
#     </div>
# </div>

# %%
# =============================================================================
all_zones = [
    "AL", "AM", "AT", "AZ", "BY", "BE", "BA", "BG", "HR", "CY", "CZ", "DK",
    "EE", "FI", "FR", "GE", "DE", "EL", "HU", "IS", "IE", "IT", "XK", "LV",
    "LT", "LU", "MT", "MD", "ME", "NL", "MK", "NO", "PL", "PT", "RO", "RU",
    "RS", "SK", "SI", "ES", "SE", "CH", "TR", "UA", "UK"
]
# =============================================================================
active_selection = {"BE", "FR", "DE", "NL", "UK"}
# =============================================================================
vpp_active_selection = {"BE"}
# =============================================================================
filter_zones = lambda selected: [z for z in all_zones if z in selected]
zone_names = filter_zones(active_selection)
vpp_zone_names = filter_zones(vpp_active_selection)
print("Selected Zones:", zone_names)
print("VPP Selected Zones:", vpp_zone_names)
# Out:
# Selected Zones: ['BE', 'FR', 'DE', 'NL', 'UK']
# VPP Selected Zones: ['BE']

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 12px; text-align: right; color: #000099;">
#     <span style="text-transform: uppercase;">
#     <b>International Nomenclature</b>
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px">
#         The following dictionary maps <b>standardized country codes</b> to their various synonyms, aliases, or alternative naming conventions used across international databases
#     <br>
#     (e.g., ENTSO-E, Eurostat, or ISO variants).
#     <br>
#     <b>Purpose:</b> This ensures the script can correctly identify and link data even when source files use inconsistent regional identifiers (e.g., <i>UK</i> vs. <i>GB</i> or <i>EL</i> vs. <i>GR</i>).
#     </div>
# </div>

# %%
### Define a clean base dictionary (no messy padding or unnecessary lists)
# =============================================================================
raw_countries = {
    "AL": ("Albania",            ""),  "AM": ("Armenia",          ""),  "AT": ("Austria",          ""),
    "AZ": ("Azerbaijan",         ""),  "BY": ("Belarus",          ""),  "BE": ("Belgium",          ""),
    "BA": ("Bosnia and Herz.",   ""),  "BG": ("Bulgaria",         ""),  "HR": ("Croatia",          ""),
    "CY": ("Cyprus",             ""),  "CZ": ("Czech Republic",   ""),  "DK": ("Denmark",          ""),
    "EE": ("Estonia",            ""),  "FI": ("Finland",          ""),  "FR": ("France",           ""),
    "GE": ("Georgia",            ""),  "DE": ("Germany",          ""),  "EL": ("Greece",         "GR"),
    "HU": ("Hungary",            ""),  "IS": ("Iceland",          ""),  "IE": ("Ireland",          ""),
    "IT": ("Italy",              ""),  "XK": ("Kosovo",           ""),  "LV": ("Latvia",           ""),
    "LT": ("Lithuania",          ""),  "LU": ("Luxembourg",       ""),  "MT": ("Malta",            ""),
    "MD": ("Moldova",            ""),  "ME": ("Montenegro",       ""),  "NL": ("Netherlands",      ""),
    "MK": ("North Macedonia",    ""),  "NO": ("Norway",           ""),  "PL": ("Poland",           ""),
    "PT": ("Portugal",           ""),  "RO": ("Romania",          ""),  "RU": ("Russia",           ""),
    "RS": ("Serbia",             ""),  "SK": ("Slovakia",         ""),  "SI": ("Slovenia",         ""),
    "ES": ("Spain",              ""),  "SE": ("Sweden",           ""),  "CH": ("Switzerland",      ""),
    "TR": ("Turkey",             ""),  "UA": ("Ukraine",          ""),  "UK": ("United Kingdom", "GB")
}
# =============================================================================
### Constructing dicctionary
zone_names_equivalences_dict = {
    code: {"Acronym": [acronym if acronym else " "], "name": [name]}
    for code, (name, acronym) in raw_countries.items()
}
### Filter the dictionary using only the keys present in zone_names
selected_zone_names_equivalences_dict = {
    k: zone_names_equivalences_dict[k] 
    for k in zone_names 
    if k in zone_names_equivalences_dict
}
### Print only the zones that have a valid alternative acronym
for key, value in selected_zone_names_equivalences_dict.items():
    acronym = value["Acronym"][0].strip()
    if acronym:  # Evaluates to True only if the acronym is not empty or spaces
        print(f"Key: {key};    Acronym: {value['Acronym']};    Name: {value['name']}\n")
# Out:
# Key: UK;    Acronym: ['GB'];    Name: ['United Kingdom']

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         A-07. Data Reference Year
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#             Define the <b>target temporal scope</b> for the processing workflow. This variable determines which yearly dataset will be filtered, formatted, and exported.
#     </div>
# </div>

# %%
### Year to which data is formatting to
# =============================================================================
data_target_year = "2030"
#data_target_year = "2040"
#data_target_year = "2050"
# =============================================================================
print(f"Selected Year: {data_target_year}")
# Out:
# Selected Year: 2030

# %% [markdown]
# <div style= "background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099; " >
#  <span style= "font-weight: bold; font-size: 16px; " >
# Section B Overview: Electric Load Extraction & Aggregation
#  </span >
#  <div style= "border-top: 1px solid #000099; padding: 10px; " >
# This section handles the initial extraction of baseline electricity demands.<br> It loads the raw PyPSA load time series, splits them by country using international nomenclature equivalences, extracts specific node-level electric loads (including agriculture and industry), and aggregates them into a single total electric load profile per country.
#  </div >
#  </div >
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#        B-01. Loading and Splitting Load Time Series by Country
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process loads the <b>load time series</b> CSV file and splits the columns into separate DataFrames for each country.<br> It uses country codes and their <b>acronym equivalents</b> (e.g., <b>UK ↔ GB</b>) to match the correct columns.<br>
#     <b>Loading Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         The script constructs the file path: <b>{loads_pypsa_raw_data_folder_path}/loads_{scenario}_{year}.csv</b>.
#             <br>If the file exists, it loads the full time series with the first column as index.
#             <br>It then iterates through each zone, using both the primary code and its acronym to match columns in the DataFrame. Matching columns are stored in a dictionary keyed by the zone code.
#         </div>
#     </div>
# </div>

# %%
### Filter dictionary for requested zones
selected_zone_names_equivalences_dict = {
    k: zone_names_equivalences_dict[k] 
    for k in zone_names 
    if k in zone_names_equivalences_dict
}
### 3. Construct target CSV file path using Path / operator
file_path = loads_pypsa_raw_data_folder_path / f"loads_{pypsa_scenario}_{data_target_year}.csv"
### Initialize single-level dictionary: raw_data_dict["UK"] = DataFrame
raw_data_dict = {}
if file_path.exists():
    ### Load full load time series
    df = pd.read_csv(file_path, index_col=0)
    ### 4. Split columns into country dictionary
    for zone_key, metadata in selected_zone_names_equivalences_dict.items():
        ### Search patterns for primary code (e.g. "UK") and acronym (e.g. "GB")
        search_codes = [zone_key]
        alt_acronym = metadata["Acronym"][0].strip()
        if alt_acronym:
            search_codes.append(alt_acronym)
        ### Match columns containing any of the country codes
        matching_cols = [
            col for col in df.columns 
            if any(col.startswith(code) or f"_{code}" in col or f" {code}" in col for code in search_codes)
        ]
        if matching_cols:
            raw_data_dict[zone_key] = df[matching_cols].copy()
        else:
            print(f"⚠️ No matching columns found for '{zone_key}' ({search_codes})")
    print(f"✅ `raw_data_dict` populated successfully from:\n   {file_path}\n")
    ### Check and print dictionary population status
    if raw_data_dict:
        print(f"📊 Dictionary Summary ({len(raw_data_dict)} zones populated):")
        print("-" * 50)
        for zone, data in raw_data_dict.items():
            print(f"  • Zone: {zone:<4} | Columns: {len(data.columns):<3} | Shape: {data.shape}")
        print("-" * 50)
    else:
        print("⚠️ Warning: `raw_data_dict` is empty! No matching columns were found for any zone.")
else:
    print(f"❌ File not found at: {file_path}")
# Out:
# ✅ `raw_data_dict` populated successfully from:
#    /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/Load_RealTime/loads_Sufficiency_Scenario_2030.csv
#
# 📊 Dictionary Summary (5 zones populated):
# --------------------------------------------------
#   • Zone: BE   | Columns: 23  | Shape: (8760, 23)
#   • Zone: FR   | Columns: 23  | Shape: (8760, 23)
#   • Zone: DE   | Columns: 23  | Shape: (8760, 23)
#   • Zone: NL   | Columns: 23  | Shape: (8760, 23)
#   • Zone: UK   | Columns: 46  | Shape: (8760, 46)
# --------------------------------------------------

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#      B-02. Extracting Electric Load Data by Node and Technology
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process extracts <b>electric load time series</b> from the raw load data, organized by <b>node</b> and <b>technology type</b>.<br> It separates base electricity loads from sector-specific loads (e.g., agriculture, industry) and creates a structured dictionary of DataFrames per country.<br>
#     <b>Extraction Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each country, the script identifies unique node prefixes (e.g., <b>"BE1 0"</b>, <b>"BE1 1"</b>). For each node, it extracts:
#         <div style="margin-left: 2em;">
#             <li><b>Base Electricity Load</b> → Exact node match (e.g., <b>"BE1 0"</b>)<br>
#             <li><b>Sector-Specific Loads</b> → Columns starting with the node and ending with specific technology suffixes (e.g., <b>"agriculture electricity"</b>, <b>"industry electricity"</b>)
#         </div>
#         Extracted columns are renamed with a <b>_low voltage</b> suffix for consistency.
#     </div>
# </div>

# %%
### 1. Define the suffix-based technologies to extract
# =============================================================================
load_technologies = [
    "agriculture electricity",
    "industry electricity"
]
# =============================================================================
### Initialize single-level dictionary: electric_loads["BE"] = DataFrame
electric_loads = {}
### 2. Iterate through each country DataFrame in raw_data_dict
for zone_key, df_zone in raw_data_dict.items():
    if df_zone.empty:
        continue
    extracted_columns = {}
    ### Extract unique node prefixes for THIS specific country (e.g., 'BE1 0', 'BE1 1')
    nodes = df_zone.columns.str.split(" ").str[:2].str.join(" ").unique()
    for node in nodes:
        ### --- 1. Extract Base Electricity Load (Exact node match, e.g., "BE1 0") ---
        if node in df_zone.columns:
            col_name = f"{node}_low voltage"
            extracted_columns[col_name] = df_zone[node]
        ### --- 2. Extract Sector-Specific Technologies (Prefix + Suffix match) ---
        for tech in load_technologies:
            matching_columns = [
                col for col in df_zone.columns 
                if col.startswith(node) and col.endswith(tech)
            ]
            if matching_columns:
                original_col = matching_columns[0]
                col_name = f"{node} {tech}_low voltage"
                extracted_columns[col_name] = df_zone[original_col]   
    ### If matching profiles were found, build the country DataFrame
    if extracted_columns:
        electric_loads[zone_key] = pd.DataFrame(extracted_columns, index=df_zone.index)
### Summary Check
print("✅ `electric_loads` dictionary created successfully.\n")
print("📊 Summary of extracted DataFrames per country:")
print("-" * 65)
for zone, df_res in electric_loads.items():
    print(f"  • Country: {zone:<4} | Columns: {len(df_res.columns):<3} | Shape: {df_res.shape}")
    print(f"    Sample Columns: {list(df_res.columns[:3])} ...")
print("-" * 65)
# Out:
# ✅ `electric_loads` dictionary created successfully.
#
# 📊 Summary of extracted DataFrames per country:
# -----------------------------------------------------------------
#   • Country: BE   | Columns: 3   | Shape: (8760, 3)
#     Sample Columns: ['BE1 0_low voltage', 'BE1 0 agriculture electricity_low voltage', 'BE1 0 industry electricity_low voltage'] ...
#   • Country: FR   | Columns: 3   | Shape: (8760, 3)
#     Sample Columns: ['FR1 0_low voltage', 'FR1 0 agriculture electricity_low voltage', 'FR1 0 industry electricity_low voltage'] ...
#   • Country: DE   | Columns: 3   | Shape: (8760, 3)
#     Sample Columns: ['DE1 0_low voltage', 'DE1 0 agriculture electricity_low voltage', 'DE1 0 industry electricity_low voltage'] ...
#   • Country: NL   | Columns: 3   | Shape: (8760, 3)
#     Sample Columns: ['NL1 0_low voltage', 'NL1 0 agriculture electricity_low voltage', 'NL1 0 industry electricity_low voltage'] ...
#   • Country: UK   | Columns: 6   | Shape: (8760, 6)
#     Sample Columns: ['GB0 0_low voltage', 'GB0 0 agriculture electricity_low voltage', 'GB0 0 industry electricity_low voltage'] ...
# -----------------------------------------------------------------

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         B-03. Summing All Electric Load Columns
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process aggregates all electric load columns for each country into a <b>single total time series</b>.<br>
#     The resulting DataFrame contains one column per country (<b>total_electric_load</b>) representing the <b>total electric load</b> at each snapshot.<br>
#     <b>Aggregation Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each country, the script sums all columns of the DataFrame <b>horizontally</b> (along the column axis) using <b>df.sum(axis=1)</b>. <br>
#         This produces a single Series where each value is the sum of all electric load components at that snapshot. <br>
#         The Series is then converted to a DataFrame with a single column named <b>"total_electric_load"</b>, preserving the snapshot as the index.<br>
#         The resulting dictionary, <b>total_electric_loads</b>, contains one DataFrame per country with a single column representing the total electric load. This aggregated profile is ready for Dispa-SET load formatting.
#     </div>
# </div>

# %%
total_electric_loads = {}
for country, df in electric_loads.items():
    total_load = df.sum(axis=1)
    total_electric_loads[country] = total_load.to_frame(
        name="total_electric_load"
    )
    total_electric_loads[country].index.name = "snapshot"
print("\nProcess completed.")
for country, df in total_electric_loads.items():
    print(
        f"{country}: {len(df)} snapshots processed, "
        f"column = '{df.columns[0]}'"
        )
# Out:
# Process completed.
# BE: 8760 snapshots processed, column = 'total_electric_load'
# FR: 8760 snapshots processed, column = 'total_electric_load'
# DE: 8760 snapshots processed, column = 'total_electric_load'
# NL: 8760 snapshots processed, column = 'total_electric_load'
# UK: 8760 snapshots processed, column = 'total_electric_load'

# %% [markdown]
# <div style= "background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099; " >
#  <span style= "font-weight: bold; font-size: 16px; " >
# Section C Overview: Generators & Links Electric Consumption
#  </span >
#  <div style= "border-top: 1px solid #000099; padding: 10px; " >
# This section processes the electric consumption profiles from generators and multi-bus links (e.g., EV chargers, batteries, H2 electrolysis, DAC). <br>It correctly assigns normal and reversed inter-node pipeline flows to their respective zones, filters by active technologies, and calculates the net total electric consumption by summing positive loads and subtracting generation/injections.
#  </div >
#  </div >
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#       C-01.  Loading Generators & Links Electric Consumption (with Automatic Date Parsing)
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process loads the <b>generators and links electric consumption</b> CSV file with automatic date parsing.<br> The <b>"snapshot"</b> column is explicitly parsed as dates and set as the DataFrame index, ensuring that the time series data is properly formatted for time-based operations.<br>
#     <b>Loading Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         The script constructs the filename: <b>generators_links_electric_consumption_{scenario}_{year}.csv</b>.
#         <br>
#         It uses <b>Path</b> for cross-platform path handling, loads the CSV with <b>parse_dates=["snapshot"]</b> to automatically convert the snapshot column to datetime, and sets it as the index with <b>index_col="snapshot"</b>.
#     </div>
# </div>

# %%
### LOAD ALL GENERATORS/LINKS ELECTRIC CONSUMPTION
# _____________________________________________________
### Construct the filename dynamicallyfile_path = (
file_path = (    
    Path(loads_pypsa_raw_data_folder_path)
    / f"generators_links_electric_consumption_{pypsa_scenario}_{data_target_year}.csv"
)
generators_links_electric_consumption = pd.read_csv(
    file_path,
    parse_dates=["snapshot"],
    index_col="snapshot"
    )
print(
    f"✅ Successfully loaded DataFrame from: {file_path}"
)
print(
    f"Shape: {generators_links_electric_consumption.shape}"
)
print(
    generators_links_electric_consumption.head()
)
# Out:
# ✅ Successfully loaded DataFrame from: /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/Load_RealTime/generators_links_electric_consumption_Sufficiency_Scenario_2030.csv
# Shape: (8760, 252)
#                      BE1 0 V2G  BE1 0 EV charger  BE1 0 battery charger-2030  \
# snapshot
# 2013-01-01 00:00:00   0.011218         93.487263                 2435.294258
# 2013-01-01 01:00:00   0.022696         70.984045                 1839.203081
# 2013-01-01 02:00:00   0.010801         66.806194                 1514.313385
# 2013-01-01 03:00:00   0.009618         84.318170                    0.187689
# 2013-01-01 04:00:00   0.016963        161.198454                    0.083405
#
#                      BE1 0 battery discharger-2030  \
# snapshot
# 2013-01-01 00:00:00                       0.086739
# 2013-01-01 01:00:00                       0.087023
# 2013-01-01 02:00:00                       0.088308
# 2013-01-01 03:00:00                       0.168109
# 2013-01-01 04:00:00                     746.805713
#
#                      gas pipeline BE1 0 -> FR1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                          0.006591
# 2013-01-01 01:00:00                          0.006591
# 2013-01-01 02:00:00                          0.006587
# 2013-01-01 03:00:00                          0.006098
# 2013-01-01 04:00:00                          0.005613
#
#                      gas pipeline BE1 0 -> NL1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                          0.008634
# 2013-01-01 01:00:00                          0.008631
# 2013-01-01 02:00:00                          0.008625
# 2013-01-01 03:00:00                          0.008013
# 2013-01-01 04:00:00                          0.007390
#
#                      gas pipeline BE1 0 <-> FR1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                           0.006605
# 2013-01-01 01:00:00                           0.006605
# 2013-01-01 02:00:00                           0.006601
# 2013-01-01 03:00:00                           0.006110
# 2013-01-01 04:00:00                           0.005624
#
#                      gas pipeline BE1 0 <-> NL1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                           0.014659
# 2013-01-01 01:00:00                           0.014653
# 2013-01-01 02:00:00                           0.014642
# 2013-01-01 03:00:00                           0.013621
# 2013-01-01 04:00:00                           0.012552
#
#                      gas pipeline DE1 0 -> BE1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                   0.006112
# 2013-01-01 01:00:00                                   0.006111
# 2013-01-01 02:00:00                                   0.006110
# 2013-01-01 03:00:00                                   0.005673
# 2013-01-01 04:00:00                                   0.005239
#
#                      gas pipeline FR1 0 <-> BE1 0-reversed-2030  ...  \
# snapshot                                                         ...
# 2013-01-01 00:00:00                                    0.004852  ...
# 2013-01-01 01:00:00                                    0.004856  ...
# 2013-01-01 02:00:00                                    0.004858  ...
# 2013-01-01 03:00:00                                    0.004523  ...
# 2013-01-01 04:00:00                                    0.004193  ...
#
#                      NL1 0 residential rural ground heat pump-2015  \
# snapshot
# 2013-01-01 00:00:00                                      17.473184
# 2013-01-01 01:00:00                                      17.450529
# 2013-01-01 02:00:00                                      17.650817
# 2013-01-01 03:00:00                                      18.577066
# 2013-01-01 04:00:00                                      29.512068
#
#                      NL1 0 residential rural ground heat pump-2019  \
# snapshot
# 2013-01-01 00:00:00                                      14.202195
# 2013-01-01 01:00:00                                      14.187659
# 2013-01-01 02:00:00                                      14.316092
# 2013-01-01 03:00:00                                      14.908654
# 2013-01-01 04:00:00                                      22.714849
#
#                      NL1 0 residential urban decentral resistive heater-2030  \
# snapshot
# 2013-01-01 00:00:00                                           0.016034
# 2013-01-01 01:00:00                                           0.016029
# 2013-01-01 02:00:00                                           0.016107
# 2013-01-01 03:00:00                                           0.016369
# 2013-01-01 04:00:00                                         341.804696
#
#                      NL1 0 residential urban decentral resistive heater-2015  \
# snapshot
# 2013-01-01 00:00:00                                           0.026653
# 2013-01-01 01:00:00                                           0.026710
# 2013-01-01 02:00:00                                           0.026763
# 2013-01-01 03:00:00                                           0.026784
# 2013-01-01 04:00:00                                           8.432103
#
#                      NL1 0 residential urban decentral resistive heater-2019  \
# snapshot
# 2013-01-01 00:00:00                                           0.027154
# 2013-01-01 01:00:00                                           0.027210
# 2013-01-01 02:00:00                                           0.027262
# 2013-01-01 03:00:00                                           0.027282
# 2013-01-01 04:00:00                                           6.747545
#
#                      NL1 0 residential urban decentral air heat pump-2030  \
# snapshot
# 2013-01-01 00:00:00                                        2113.763815
# 2013-01-01 01:00:00                                        2100.569524
# 2013-01-01 02:00:00                                        2265.078412
# 2013-01-01 03:00:00                                        2934.475585
# 2013-01-01 04:00:00                                        4037.275501
#
#                      NL1 0 residential urban decentral air heat pump-2015  \
# snapshot
# 2013-01-01 00:00:00                                          41.177205
# 2013-01-01 01:00:00                                          41.172424
# 2013-01-01 02:00:00                                          41.241384
# 2013-01-01 03:00:00                                          41.612434
# 2013-01-01 04:00:00                                          84.111381
#
#                      NL1 0 residential urban decentral air heat pump-2019  \
# snapshot
# 2013-01-01 00:00:00                                          32.943609
# 2013-01-01 01:00:00                                          32.940550
# 2013-01-01 02:00:00                                          32.984673
# 2013-01-01 03:00:00                                          33.222091
# 2013-01-01 04:00:00                                          67.288324
#
#                      NL1 0 load  NL1 0 low voltage load
# snapshot
# 2013-01-01 00:00:00    0.000057                0.000048
# 2013-01-01 01:00:00    0.000057                0.000048
# 2013-01-01 02:00:00    0.000057                0.000048
# 2013-01-01 03:00:00    0.000057                0.000048
# 2013-01-01 04:00:00    0.000057                0.000048
#
# [5 rows x 252 columns]

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#       C-02. Building Country-Level Dictionary with Normal and Reversed Inter-Node Links
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process creates a <b>country-level dictionary</b> of generator and link electric consumption data, with advanced handling for <b>normal</b> and <b>reversed</b> inter-node links (e.g., gas pipelines, H2 pipelines). <br>It identifies all nodes in a column header, determines ownership based on the column's direction, and assigns the column to the correct zone.<br>
#     <b>Assignment Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each column, the script identifies <b>all nodes</b> appearing in the header and preserves their order. It then determines ownership based on the column type:
#             <div style="margin-left: 2em;">
#             <li><b>Normal Column</b> (no "reversed" in name) → <b>First node</b> owns the column (source node).<br>
#             <li><b>Reversed Column</b> (contains "reversed") → <b>Second node</b> owns the column (destination node in reverse flow).
#             </div>
#         This ensures that bi-directional pipeline flows are correctly assigned to the appropriate zone.
#     </div>
# </div>

# %%
### MASTER DICTIONARY
generators_links_electric_consumption_dict = {}
# GET ALL COLUMN NAMES
all_columns = generators_links_electric_consumption.columns
# BUILD ZONE PREFIXES
zone_prefixes_dict = {}
for zone in zone_names:
    prefixes = [zone]
    if zone in zone_names_equivalences_dict:
        alt_acronym = (
            zone_names_equivalences_dict[zone]["Acronym"][0]
            .strip()
        )
        if alt_acronym:
            prefixes.append(alt_acronym)
    zone_prefixes_dict[zone] = prefixes
# SPLIT COLUMNS BY ZONE
for zone in zone_names:
    # Get valid prefixes for this zone
    prefixes = zone_prefixes_dict[zone]
    matching_cols = []
    # CHECK EVERY COLUMN
    for col in all_columns:
        col_str = str(col)
        # CASE 1:
        # COLUMN STARTS WITH THIS ZONE/PREFIX
        starts_with_zone = any(
            col_str.startswith(prefix)
            for prefix in prefixes
        )
        if starts_with_zone:
            matching_cols.append(col)
            continue
        # CASE 2:
        # COLUMN DOES NOT START WITH A ZONE
        # Find ALL nodes appearing in the column header
        # and preserve their order.
        found_nodes = []
        for candidate_zone in zone_names:
            candidate_prefixes = zone_prefixes_dict[
                candidate_zone
            ]
            for prefix in candidate_prefixes:
                # Search for every occurrence of this
                # prefix in the column name
                search_start = 0
                while True:
                    position = col_str.find(
                        prefix,
                        search_start
                    )
                    if position == -1:
                        break
                    # Make sure the prefix is followed by
                    # the expected node structure.
                    if (
                        position + len(prefix)
                        < len(col_str)
                    ):
                        next_character = col_str[
                            position + len(prefix)
                        ]
                        if not (
                            next_character == " "
                            or next_character.isdigit()
                        ):
                            search_start = (
                                position + len(prefix)
                            )
                            continue
                    # Store node and its position
                    found_nodes.append(
                        (
                            position,
                            candidate_zone
                        )
                    )
                    # Continue searching after this
                    # occurrence
                    search_start = (
                        position + len(prefix)
                    )
        # SORT NODES BY THEIR POSITION IN THE HEADER
        found_nodes.sort(
            key=lambda x: x[0]
        )
        # Remove duplicate detections at the same
        # position, keeping the first one
        ordered_zones = []
        previous_position = None
        for position, found_zone in found_nodes:
            if position != previous_position:
                ordered_zones.append(found_zone)
                previous_position = position
        # DETERMINE WHICH NODE OWNS THE COLUMN
        column_lower = col_str.lower()
        # NORMAL COLUMN
        # First node owns the column.
        # Example:
        # H2 pipeline BE1 0 -> NL1 0-2030
        #        BE  ->  NL
        #        ↑
        #      OWNER
        if "reversed" not in column_lower:
            if len(ordered_zones) >= 1:
                selected_zone = ordered_zones[0]
            else:
                selected_zone = None
        # REVERSED COLUMN
        # Second node owns the column.
        # Example:
        # H2 pipeline BE1 0 -> NL1 0-reversed-2030
        #        BE  ->  NL
        #              ↑
        #            OWNER
        else:
            if len(ordered_zones) >= 2:
                selected_zone = ordered_zones[1]
            else:
                selected_zone = None
        # ASSIGN COLUMN TO CURRENT ZONE
        if selected_zone == zone:
            matching_cols.append(col)
    # CREATE ZONE DATAFRAME
    if matching_cols:
        generators_links_electric_consumption_dict[
            zone
        ] = (
            generators_links_electric_consumption[
                matching_cols
            ].copy()
        )
    else:
        generators_links_electric_consumption_dict[
            zone
        ] = pd.DataFrame(
            index=generators_links_electric_consumption.index
        )
# INSPECTION
print(
    "✅ Successfully built country-level dictionary "
    "with normal and reversed inter-node links!\n"
)
for zone, zone_df in (
    generators_links_electric_consumption_dict.items()
):
    print(
        f"  • Zone key: '{zone}' | "
        f"Columns: {len(zone_df.columns):<3} | "
        f"Shape: {zone_df.shape}"
    )
# CHECK PIPELINES
print("\n" + "=" * 70)
print("PIPELINE ASSIGNMENT CHECK")
print("=" * 70)
for zone, zone_df in (
    generators_links_electric_consumption_dict.items()
):
    pipeline_columns = [
        col
        for col in zone_df.columns
        if "pipeline" in str(col).lower()
    ]
    if pipeline_columns:
        print(f"\n{zone}:")
        for col in pipeline_columns:
            print(f"  {col}")
# Out:
# ✅ Successfully built country-level dictionary with normal and reversed inter-node links!
#
#   • Zone key: 'BE' | Columns: 41  | Shape: (8760, 41)
#   • Zone key: 'FR' | Columns: 47  | Shape: (8760, 47)
#   • Zone key: 'DE' | Columns: 42  | Shape: (8760, 42)
#   • Zone key: 'NL' | Columns: 46  | Shape: (8760, 46)
#   • Zone key: 'UK' | Columns: 76  | Shape: (8760, 76)
#
# ======================================================================
# PIPELINE ASSIGNMENT CHECK
# ======================================================================
#
# BE:
#   gas pipeline BE1 0 -> FR1 0-2030
#   gas pipeline BE1 0 -> NL1 0-2030
#   gas pipeline BE1 0 <-> FR1 0-2030
#   gas pipeline BE1 0 <-> NL1 0-2030
#   gas pipeline DE1 0 -> BE1 0-reversed-2030
#   gas pipeline FR1 0 <-> BE1 0-reversed-2030
#   gas pipeline GB0 0 <-> BE1 0-reversed-2030
#   gas pipeline NL1 0 -> BE1 0-reversed-2030
#   H2 pipeline BE1 0 -> DE1 0-2030
#   H2 pipeline BE1 0 -> FR1 0-2030
#   H2 pipeline BE1 0 -> GB0 0-2030
#   H2 pipeline BE1 0 -> NL1 0-2030
#
# FR:
#   gas pipeline FR1 0 -> DE1 0-2030
#   gas pipeline FR1 0 <-> BE1 0-2030
#   gas pipeline BE1 0 -> FR1 0-reversed-2030
#   gas pipeline BE1 0 <-> FR1 0-reversed-2030
#   gas pipeline DE1 0 -> FR1 0-reversed-2030
#   H2 pipeline FR1 0 -> GB0 0-2030
#   H2 pipeline BE1 0 -> FR1 0-reversed-2030
#   H2 pipeline DE1 0 -> FR1 0-reversed-2030
#
# DE:
#   gas pipeline DE1 0 -> BE1 0-2030
#   gas pipeline DE1 0 -> FR1 0-2030
#   gas pipeline DE1 0 -> NL1 0-2030
#   gas pipeline DE1 0 <-> NL1 0-2030
#   gas pipeline FR1 0 -> DE1 0-reversed-2030
#   gas pipeline NL1 0 -> DE1 0-reversed-2030
#   gas pipeline NL1 0 <-> DE1 0-reversed-2030
#   H2 pipeline DE1 0 -> FR1 0-2030
#   H2 pipeline DE1 0 -> GB0 0-2030
#   H2 pipeline DE1 0 -> NL1 0-2030
#   H2 pipeline BE1 0 -> DE1 0-reversed-2030
#
# NL:
#   gas pipeline NL1 0 -> BE1 0-2030
#   gas pipeline NL1 0 -> DE1 0-2030
#   gas pipeline NL1 0 -> GB0 0-2030
#   gas pipeline NL1 0 <-> DE1 0-2030
#   gas pipeline NL1 0 <-> GB0 0-2030
#   gas pipeline BE1 0 -> NL1 0-reversed-2030
#   gas pipeline BE1 0 <-> NL1 0-reversed-2030
#   gas pipeline DE1 0 -> NL1 0-reversed-2030
#   gas pipeline DE1 0 <-> NL1 0-reversed-2030
#   gas pipeline GB0 0 -> NL1 0-reversed-2030
#   H2 pipeline BE1 0 -> NL1 0-reversed-2030
#   H2 pipeline DE1 0 -> NL1 0-reversed-2030
#   H2 pipeline GB0 0 -> NL1 0-reversed-2030
#
# UK:
#   gas pipeline GB0 0 -> NL1 0-2030
#   gas pipeline GB0 0 <-> BE1 0-2030
#   gas pipeline GB2 0 -> GB0 0-reversed-2030
#   gas pipeline NL1 0 -> GB0 0-reversed-2030
#   gas pipeline NL1 0 <-> GB0 0-reversed-2030
#   H2 pipeline GB0 0 -> GB2 0-2030
#   H2 pipeline GB0 0 -> NL1 0-2030
#   H2 pipeline BE1 0 -> GB0 0-reversed-2030
#   H2 pipeline DE1 0 -> GB0 0-reversed-2030
#   H2 pipeline FR1 0 -> GB0 0-reversed-2030
#   gas pipeline GB2 0 -> GB0 0-2030
#   H2 pipeline GB0 0 -> GB2 0-reversed-2030

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         C-03. Link Technologies (with Commented-Out Heat Pumps and Resistive Heaters)
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process defines the <b>link technologies</b> used in the model.<br>
#         In this version, <b>heat pumps and resistive heaters have been commented out</b>, meaning they are excluded from the link technologies list.<br>
#         Only the core technologies (V2G, EV chargers, battery chargers/dischargers, gas pipelines, H2 technologies, and DAC) are included.<br>
#     <b>Filtering Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
# The script defines a <b>base list</b> of link technologies that excludes both heat pumps and resistive heaters. The active list includes only:
#         <div style="margin-left: 2em;">
#         <li><b>Vehicle-to-Grid:</b> V2G<br>
#         <li><b>Electric Vehicles:</b> EV charger<br>
#         <li><b>Battery Storage:</b> battery charger, battery discharger<br>
#         <li><b>Gas Pipelines:</b> gas pipeline, gas pipeline new<br>
#         <li><b>Synthetic Fuels:</b> methanolisation, Haber-Bosch<br>
#         <li><b>Hydrogen:</b> H2 Electrolysis, H2 pipeline, H2 pipeline retrofitted<br>
#         <li><b>Carbon Capture:</b> DAC
#         </div>
#         <b>All heat pumps</b> (air and ground heat pumps) are commented out and excluded.
#         <br>The conditional addition of resistive heaters has also been commented out, so they are excluded regardless of VPP mode.
#     </div>
# </div>

# %%
### TECHNOLOGY LISTS
# =====================================================
link_technologies = [
    "V2G",
    "EV charger",
    "battery charger",
    "battery discharger",
    "gas pipeline",
    "gas pipeline new",
    "methanolisation",
    "Haber-Bosch",
    "H2 Electrolysis",
    "H2 pipeline",
    "H2 pipeline retrofitted",
    "DAC",
    #"urban central air heat pump",
    #"services urban decentral air heat pump",
    #"services rural air heat pump",
    #"services rural ground heat pump",
    #"residential rural air heat pump",
    #"residential rural ground heat pump",
    #"residential urban decentral air heat pump",
    ]
'''if not VPP:
    link_technologies += [
            "urban central resistive heater",
            "services urban decentral resistive heater",
            "services rural resistive heater",
            "residential rural resistive heater",
            "residential urban decentral resistive heater",
        ]'''
# =====================================================
generator_technologies = ["load"]
print(f"Number of link technologies: {len(link_technologies)}")
print("Link technologies:")
for tech in link_technologies:
    print(f"  - {tech}")
# Out:
# Number of link technologies: 12
# Link technologies:
#   - V2G
#   - EV charger
#   - battery charger
#   - battery discharger
#   - gas pipeline
#   - gas pipeline new
#   - methanolisation
#   - Haber-Bosch
#   - H2 Electrolysis
#   - H2 pipeline
#   - H2 pipeline retrofitted
#   - DAC

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         C-04. Filtering Generator and Link Electric Consumption Columns by Technology
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process filters the generator and link electric consumption DataFrames to retain only columns that match the <b>technology lists</b> (link_technologies and generator_technologies). It removes unwanted columns, converts the snapshot to a DatetimeIndex, and stores the filtered DataFrames in a new dictionary.<br>
#     <b>Filtering Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each zone, the script performs the following steps:
#             <div style="margin-left: 2em;">
#         <b>1.</b> Removes any unwanted column named <b>"0"</b> (accidentally imported from CSV)<br>
#         <b>2.</b> Identifies the snapshot (either as a column or as the index)<br>
#         <b>3.</b> Filters columns to retain only those containing any technology name from <b>technologies_to_select</b><br>
#         <b>4.</b> Converts the snapshot to a <b>DatetimeIndex</b> and sets it as the DataFrame index<br>
#         <b>5.</b> Stores the cleaned DataFrame in a new dictionary
#             </div>
#         </div>
#     </div>
# </div>

# %%
### COMBINE TECHNOLOGY LISTS
technologies_to_select = (
    link_technologies
    + generator_technologies
)
### CREATE NEW NESTED DICTIONARY
generators_links_electric_consumption_dict_selected = {}
### FILTER EACH ZONE DATAFRAME
for zone, df in (
    generators_links_electric_consumption_dict.items()
):
    print(f"\n--- Processing {zone} ---")
    ### REMOVE UNWANTED INDEX COLUMN IF IT EXISTS
    ### Remove a column named "0" if it was accidentally
    ### imported from a previous CSV export.
    df_clean = df.drop(
        columns=["0"],
        errors="ignore"
    ).copy()
    ### IDENTIFY SNAPSHOT
    if "snapshot" in df_clean.columns:
        ### Snapshot is a regular column
        snapshot_data = df_clean["snapshot"]
        data_columns = [
            column
            for column in df_clean.columns
            if column != "snapshot"
        ]
    else:
        ### Snapshot is already the DataFrame index
        snapshot_data = df_clean.index
        data_columns = df_clean.columns.tolist()
    ### SELECT TECHNOLOGY COLUMNS
    selected_columns = []
    for column in data_columns:
        column_name = str(column)
        if any(
            technology in column_name
            for technology in technologies_to_select
        ):
            selected_columns.append(column)
    ### BUILD SELECTED DATAFRAME
    selected_df = df_clean[
        selected_columns
    ].copy()
    ### KEEP SNAPSHOT AS INDEX
    if "snapshot" in df_clean.columns:
        selected_df.index = pd.to_datetime(
            snapshot_data
        )
    else:
        selected_df.index = snapshot_data
    selected_df.index.name = "snapshot"
    ### STORE IN NEW DICTIONARY
    generators_links_electric_consumption_dict_selected[
        zone
    ] = selected_df
    ### INSPECTION
    print(
        f"  Selected asset columns: "
        f"{len(selected_columns)}"
    )
    print(
        f"  Final shape: "
        f"{selected_df.shape}"
    )
### FINAL INSPECTION
print("\n" + "=" * 70)
print(
    "SUCCESSFULLY CREATED:"
)
print(
    "'generators_links_electric_consumption_dict_selected'"
)
print("=" * 70)
print(
    f"Total zones: "
    f"{len(generators_links_electric_consumption_dict_selected)}"
)
for zone, df in (
    generators_links_electric_consumption_dict_selected.items()
):
    print("\n" + "-" * 60)
    print(f"Zone: {zone}")
    print(
        f"Shape: {df.shape}"
    )
    print(
        f"Number of asset columns: "
        f"{len(df.columns)}"
    )
    print("\nColumns:")
    print(df.columns.tolist())
    print("\nFirst 2 rows:")
    print(df.head(2))
# Out:
# --- Processing BE ---
#   Selected asset columns: 21
#   Final shape: (8760, 21)
#
# --- Processing FR ---
#   Selected asset columns: 17
#   Final shape: (8760, 17)
#
# --- Processing DE ---
#   Selected asset columns: 20
#   Final shape: (8760, 20)
#
# --- Processing NL ---
#   Selected asset columns: 22
#   Final shape: (8760, 22)
#
# --- Processing UK ---
#   Selected asset columns: 30
#   Final shape: (8760, 30)
#
# ======================================================================
# SUCCESSFULLY CREATED:
# 'generators_links_electric_consumption_dict_selected'
# ======================================================================
# Total zones: 5
#
# ------------------------------------------------------------
# Zone: BE
# Shape: (8760, 21)
# Number of asset columns: 21
#
# Columns:
# ['BE1 0 V2G', 'BE1 0 EV charger', 'BE1 0 battery charger-2030', 'BE1 0 battery discharger-2030', 'gas pipeline BE1 0 -> FR1 0-2030', 'gas pipeline BE1 0 -> NL1 0-2030', 'gas pipeline BE1 0 <-> FR1 0-2030', 'gas pipeline BE1 0 <-> NL1 0-2030', 'gas pipeline DE1 0 -> BE1 0-reversed-2030', 'gas pipeline FR1 0 <-> BE1 0-reversed-2030', 'gas pipeline GB0 0 <-> BE1 0-reversed-2030', 'gas pipeline NL1 0 -> BE1 0-reversed-2030', 'BE1 0 methanolisation-2030', 'BE1 0 Haber-Bosch-2030', 'BE1 0 H2 Electrolysis-2030', 'H2 pipeline BE1 0 -> DE1 0-2030', 'H2 pipeline BE1 0 -> FR1 0-2030', 'H2 pipeline BE1 0 -> GB0 0-2030', 'H2 pipeline BE1 0 -> NL1 0-2030', 'BE1 0 load', 'BE1 0 low voltage load']
#
# First 2 rows:
#                      BE1 0 V2G  BE1 0 EV charger  BE1 0 battery charger-2030  \
# snapshot
# 2013-01-01 00:00:00   0.011218         93.487263                 2435.294258
# 2013-01-01 01:00:00   0.022696         70.984045                 1839.203081
#
#                      BE1 0 battery discharger-2030  \
# snapshot
# 2013-01-01 00:00:00                       0.086739
# 2013-01-01 01:00:00                       0.087023
#
#                      gas pipeline BE1 0 -> FR1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                          0.006591
# 2013-01-01 01:00:00                          0.006591
#
#                      gas pipeline BE1 0 -> NL1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                          0.008634
# 2013-01-01 01:00:00                          0.008631
#
#                      gas pipeline BE1 0 <-> FR1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                           0.006605
# 2013-01-01 01:00:00                           0.006605
#
#                      gas pipeline BE1 0 <-> NL1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                           0.014659
# 2013-01-01 01:00:00                           0.014653
#
#                      gas pipeline DE1 0 -> BE1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                   0.006112
# 2013-01-01 01:00:00                                   0.006111
#
#                      gas pipeline FR1 0 <-> BE1 0-reversed-2030  ...  \
# snapshot                                                         ...
# 2013-01-01 00:00:00                                    0.004852  ...
# 2013-01-01 01:00:00                                    0.004856  ...
#
#                      gas pipeline NL1 0 -> BE1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                   0.005623
# 2013-01-01 01:00:00                                   0.005624
#
#                      BE1 0 methanolisation-2030  BE1 0 Haber-Bosch-2030  \
# snapshot
# 2013-01-01 00:00:00                    8.928244                0.007471
# 2013-01-01 01:00:00                    8.928364                0.007471
#
#                      BE1 0 H2 Electrolysis-2030  \
# snapshot
# 2013-01-01 00:00:00                  144.180688
# 2013-01-01 01:00:00                  144.136586
#
#                      H2 pipeline BE1 0 -> DE1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                              0.0
# 2013-01-01 01:00:00                              0.0
#
#                      H2 pipeline BE1 0 -> FR1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                              0.0
# 2013-01-01 01:00:00                              0.0
#
#                      H2 pipeline BE1 0 -> GB0 0-2030  \
# snapshot
# 2013-01-01 00:00:00                              0.0
# 2013-01-01 01:00:00                              0.0
#
#                      H2 pipeline BE1 0 -> NL1 0-2030  BE1 0 load  \
# snapshot
# 2013-01-01 00:00:00                              0.0    0.000058
# 2013-01-01 01:00:00                              0.0    0.000058
#
#                      BE1 0 low voltage load
# snapshot
# 2013-01-01 00:00:00                0.000050
# 2013-01-01 01:00:00                0.000049
#
# [2 rows x 21 columns]
#
# ------------------------------------------------------------
# Zone: FR
# Shape: (8760, 17)
# Number of asset columns: 17
#
# Columns:
# ['FR1 0 V2G', 'FR1 0 EV charger', 'FR1 0 battery charger-2030', 'FR1 0 battery discharger-2030', 'gas pipeline FR1 0 -> DE1 0-2030', 'gas pipeline FR1 0 <-> BE1 0-2030', 'gas pipeline BE1 0 -> FR1 0-reversed-2030', 'gas pipeline BE1 0 <-> FR1 0-reversed-2030', 'gas pipeline DE1 0 -> FR1 0-reversed-2030', 'FR1 0 methanolisation-2030', 'FR1 0 Haber-Bosch-2030', 'FR1 0 H2 Electrolysis-2030', 'H2 pipeline FR1 0 -> GB0 0-2030', 'H2 pipeline BE1 0 -> FR1 0-reversed-2030', 'H2 pipeline DE1 0 -> FR1 0-reversed-2030', 'FR1 0 load', 'FR1 0 low voltage load']
#
# First 2 rows:
#                      FR1 0 V2G  FR1 0 EV charger  FR1 0 battery charger-2030  \
# snapshot
# 2013-01-01 00:00:00   0.017662        416.849064                 2011.902117
# 2013-01-01 01:00:00   0.017603        316.436926                 2011.902612
#
#                      FR1 0 battery discharger-2030  \
# snapshot
# 2013-01-01 00:00:00                       0.044753
# 2013-01-01 01:00:00                       0.044433
#
#                      gas pipeline FR1 0 -> DE1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                          0.003648
# 2013-01-01 01:00:00                          0.003647
#
#                      gas pipeline FR1 0 <-> BE1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                           0.006625
# 2013-01-01 01:00:00                           0.006625
#
#                      gas pipeline BE1 0 -> FR1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                   0.007086
# 2013-01-01 01:00:00                                   0.007088
#
#                      gas pipeline BE1 0 <-> FR1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                    0.007040
# 2013-01-01 01:00:00                                    0.007042
#
#                      gas pipeline DE1 0 -> FR1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                   0.004041
# 2013-01-01 01:00:00                                   0.004040
#
#                      FR1 0 methanolisation-2030  FR1 0 Haber-Bosch-2030  \
# snapshot
# 2013-01-01 00:00:00                    0.014413                0.012661
# 2013-01-01 01:00:00                    0.014373                0.012662
#
#                      FR1 0 H2 Electrolysis-2030  \
# snapshot
# 2013-01-01 00:00:00                    0.038341
# 2013-01-01 01:00:00                    0.038384
#
#                      H2 pipeline FR1 0 -> GB0 0-2030  \
# snapshot
# 2013-01-01 00:00:00                         0.000425
# 2013-01-01 01:00:00                         0.000426
#
#                      H2 pipeline BE1 0 -> FR1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                       0.0
# 2013-01-01 01:00:00                                       0.0
#
#                      H2 pipeline DE1 0 -> FR1 0-reversed-2030  FR1 0 load  \
# snapshot
# 2013-01-01 00:00:00                                  0.001004    0.000055
# 2013-01-01 01:00:00                                  0.001004    0.000055
#
#                      FR1 0 low voltage load
# snapshot
# 2013-01-01 00:00:00                 0.00005
# 2013-01-01 01:00:00                 0.00005
#
# ------------------------------------------------------------
# Zone: DE
# Shape: (8760, 20)
# Number of asset columns: 20
#
# Columns:
# ['DE1 0 V2G', 'DE1 0 EV charger', 'DE1 0 battery charger-2030', 'DE1 0 battery discharger-2030', 'gas pipeline DE1 0 -> BE1 0-2030', 'gas pipeline DE1 0 -> FR1 0-2030', 'gas pipeline DE1 0 -> NL1 0-2030', 'gas pipeline DE1 0 <-> NL1 0-2030', 'gas pipeline FR1 0 -> DE1 0-reversed-2030', 'gas pipeline NL1 0 -> DE1 0-reversed-2030', 'gas pipeline NL1 0 <-> DE1 0-reversed-2030', 'DE1 0 methanolisation-2030', 'DE1 0 Haber-Bosch-2030', 'DE1 0 H2 Electrolysis-2030', 'H2 pipeline DE1 0 -> FR1 0-2030', 'H2 pipeline DE1 0 -> GB0 0-2030', 'H2 pipeline DE1 0 -> NL1 0-2030', 'H2 pipeline BE1 0 -> DE1 0-reversed-2030', 'DE1 0 load', 'DE1 0 low voltage load']
#
# First 2 rows:
#                      DE1 0 V2G  DE1 0 EV charger  DE1 0 battery charger-2030  \
# snapshot
# 2013-01-01 00:00:00   0.017055        602.306108                  104.529524
# 2013-01-01 01:00:00   0.016779        457.217644                  104.402281
#
#                      DE1 0 battery discharger-2030  \
# snapshot
# 2013-01-01 00:00:00                       0.049169
# 2013-01-01 01:00:00                       0.062977
#
#                      gas pipeline DE1 0 -> BE1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                          0.007341
# 2013-01-01 01:00:00                          0.007221
#
#                      gas pipeline DE1 0 -> FR1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                          0.005656
# 2013-01-01 01:00:00                          0.005582
#
#                      gas pipeline DE1 0 -> NL1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                          0.010875
# 2013-01-01 01:00:00                          0.010690
#
#                      gas pipeline DE1 0 <-> NL1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                           0.005669
# 2013-01-01 01:00:00                           0.005590
#
#                      gas pipeline FR1 0 -> DE1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                   0.005851
# 2013-01-01 01:00:00                                   0.005778
#
#                      gas pipeline NL1 0 -> DE1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                   0.006492
# 2013-01-01 01:00:00                                   0.006387
#
#                      gas pipeline NL1 0 <-> DE1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                    0.005502
# 2013-01-01 01:00:00                                    0.005420
#
#                      DE1 0 methanolisation-2030  DE1 0 Haber-Bosch-2030  \
# snapshot
# 2013-01-01 00:00:00                    0.013011                0.007621
# 2013-01-01 01:00:00                    0.013017                0.007619
#
#                      DE1 0 H2 Electrolysis-2030  \
# snapshot
# 2013-01-01 00:00:00                    0.020572
# 2013-01-01 01:00:00                    0.019877
#
#                      H2 pipeline DE1 0 -> FR1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                         0.001116
# 2013-01-01 01:00:00                         0.001113
#
#                      H2 pipeline DE1 0 -> GB0 0-2030  \
# snapshot
# 2013-01-01 00:00:00                         0.000437
# 2013-01-01 01:00:00                         0.000437
#
#                      H2 pipeline DE1 0 -> NL1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                         0.001201
# 2013-01-01 01:00:00                         0.001199
#
#                      H2 pipeline BE1 0 -> DE1 0-reversed-2030  DE1 0 load  \
# snapshot
# 2013-01-01 00:00:00                                       0.0    0.000057
# 2013-01-01 01:00:00                                       0.0    0.000057
#
#                      DE1 0 low voltage load
# snapshot
# 2013-01-01 00:00:00                0.000049
# 2013-01-01 01:00:00                0.000049
#
# ------------------------------------------------------------
# Zone: NL
# Shape: (8760, 22)
# Number of asset columns: 22
#
# Columns:
# ['NL1 0 V2G', 'NL1 0 EV charger', 'NL1 0 battery charger-2030', 'NL1 0 battery discharger-2030', 'gas pipeline NL1 0 -> BE1 0-2030', 'gas pipeline NL1 0 -> DE1 0-2030', 'gas pipeline NL1 0 -> GB0 0-2030', 'gas pipeline NL1 0 <-> DE1 0-2030', 'gas pipeline NL1 0 <-> GB0 0-2030', 'gas pipeline BE1 0 -> NL1 0-reversed-2030', 'gas pipeline BE1 0 <-> NL1 0-reversed-2030', 'gas pipeline DE1 0 -> NL1 0-reversed-2030', 'gas pipeline DE1 0 <-> NL1 0-reversed-2030', 'gas pipeline GB0 0 -> NL1 0-reversed-2030', 'NL1 0 methanolisation-2030', 'NL1 0 Haber-Bosch-2030', 'NL1 0 H2 Electrolysis-2030', 'H2 pipeline BE1 0 -> NL1 0-reversed-2030', 'H2 pipeline DE1 0 -> NL1 0-reversed-2030', 'H2 pipeline GB0 0 -> NL1 0-reversed-2030', 'NL1 0 load', 'NL1 0 low voltage load']
#
# First 2 rows:
#                      NL1 0 V2G  NL1 0 EV charger  NL1 0 battery charger-2030  \
# snapshot
# 2013-01-01 00:00:00   0.021945         96.224617                 6009.459285
# 2013-01-01 01:00:00   0.021782         73.050800                 4690.431066
#
#                      NL1 0 battery discharger-2030  \
# snapshot
# 2013-01-01 00:00:00                       0.106904
# 2013-01-01 01:00:00                       0.104956
#
#                      gas pipeline NL1 0 -> BE1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                          0.006656
# 2013-01-01 01:00:00                          0.006659
#
#                      gas pipeline NL1 0 -> DE1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                          0.006140
# 2013-01-01 01:00:00                          0.006144
#
#                      gas pipeline NL1 0 -> GB0 0-2030  \
# snapshot
# 2013-01-01 00:00:00                          0.016414
# 2013-01-01 01:00:00                          0.016401
#
#                      gas pipeline NL1 0 <-> DE1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                           0.004653
# 2013-01-01 01:00:00                           0.004667
#
#                      gas pipeline NL1 0 <-> GB0 0-2030  \
# snapshot
# 2013-01-01 00:00:00                           0.006415
# 2013-01-01 01:00:00                           0.006415
#
#                      gas pipeline BE1 0 -> NL1 0-reversed-2030  ...  \
# snapshot                                                        ...
# 2013-01-01 00:00:00                                   0.008982  ...
# 2013-01-01 01:00:00                                   0.008989  ...
#
#                      gas pipeline DE1 0 <-> NL1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                    0.003803
# 2013-01-01 01:00:00                                    0.003836
#
#                      gas pipeline GB0 0 -> NL1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                   0.011890
# 2013-01-01 01:00:00                                   0.011865
#
#                      NL1 0 methanolisation-2030  NL1 0 Haber-Bosch-2030  \
# snapshot
# 2013-01-01 00:00:00                   23.362374                0.009621
# 2013-01-01 01:00:00                   23.362529                0.009619
#
#                      NL1 0 H2 Electrolysis-2030  \
# snapshot
# 2013-01-01 00:00:00                    0.077301
# 2013-01-01 01:00:00                    0.077292
#
#                      H2 pipeline BE1 0 -> NL1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                       0.0
# 2013-01-01 01:00:00                                       0.0
#
#                      H2 pipeline DE1 0 -> NL1 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                  0.001134
# 2013-01-01 01:00:00                                  0.001132
#
#                      H2 pipeline GB0 0 -> NL1 0-reversed-2030  NL1 0 load  \
# snapshot
# 2013-01-01 00:00:00                                  0.000325    0.000057
# 2013-01-01 01:00:00                                  0.000326    0.000057
#
#                      NL1 0 low voltage load
# snapshot
# 2013-01-01 00:00:00                0.000048
# 2013-01-01 01:00:00                0.000048
#
# [2 rows x 22 columns]
#
# ------------------------------------------------------------
# Zone: UK
# Shape: (8760, 30)
# Number of asset columns: 30
#
# Columns:
# ['GB0 0 V2G', 'GB0 0 EV charger', 'GB0 0 battery charger-2030', 'GB0 0 battery discharger-2030', 'gas pipeline GB0 0 -> NL1 0-2030', 'gas pipeline GB0 0 <-> BE1 0-2030', 'gas pipeline GB2 0 -> GB0 0-reversed-2030', 'gas pipeline NL1 0 -> GB0 0-reversed-2030', 'gas pipeline NL1 0 <-> GB0 0-reversed-2030', 'GB0 0 methanolisation-2030', 'GB0 0 Haber-Bosch-2030', 'GB0 0 H2 Electrolysis-2030', 'H2 pipeline GB0 0 -> GB2 0-2030', 'H2 pipeline GB0 0 -> NL1 0-2030', 'H2 pipeline BE1 0 -> GB0 0-reversed-2030', 'H2 pipeline DE1 0 -> GB0 0-reversed-2030', 'H2 pipeline FR1 0 -> GB0 0-reversed-2030', 'GB0 0 load', 'GB0 0 low voltage load', 'GB2 0 V2G', 'GB2 0 EV charger', 'GB2 0 battery charger-2030', 'GB2 0 battery discharger-2030', 'gas pipeline GB2 0 -> GB0 0-2030', 'GB2 0 methanolisation-2030', 'GB2 0 Haber-Bosch-2030', 'GB2 0 H2 Electrolysis-2030', 'H2 pipeline GB0 0 -> GB2 0-reversed-2030', 'GB2 0 load', 'GB2 0 low voltage load']
#
# First 2 rows:
#                      GB0 0 V2G  GB0 0 EV charger  GB0 0 battery charger-2030  \
# snapshot
# 2013-01-01 00:00:00   0.019383        541.390963                    0.113713
# 2013-01-01 01:00:00   0.019187        365.794891                    0.113170
#
#                      GB0 0 battery discharger-2030  \
# snapshot
# 2013-01-01 00:00:00                     797.776420
# 2013-01-01 01:00:00                     690.211477
#
#                      gas pipeline GB0 0 -> NL1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                          0.011611
# 2013-01-01 01:00:00                          0.011625
#
#                      gas pipeline GB0 0 <-> BE1 0-2030  \
# snapshot
# 2013-01-01 00:00:00                           0.005630
# 2013-01-01 01:00:00                           0.005633
#
#                      gas pipeline GB2 0 -> GB0 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                   0.014870
# 2013-01-01 01:00:00                                   0.014868
#
#                      gas pipeline NL1 0 -> GB0 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                   0.016302
# 2013-01-01 01:00:00                                   0.016307
#
#                      gas pipeline NL1 0 <-> GB0 0-reversed-2030  \
# snapshot
# 2013-01-01 00:00:00                                    0.005585
# 2013-01-01 01:00:00                                    0.005589
#
#                      GB0 0 methanolisation-2030  ...  GB2 0 EV charger  \
# snapshot                                         ...
# 2013-01-01 00:00:00                    0.014856  ...         15.410486
# 2013-01-01 01:00:00                    0.014838  ...         10.428650
#
#                      GB2 0 battery charger-2030  \
# snapshot
# 2013-01-01 00:00:00                    0.074658
# 2013-01-01 01:00:00                    0.083315
#
#                      GB2 0 battery discharger-2030  \
# snapshot
# 2013-01-01 00:00:00                       0.318943
# 2013-01-01 01:00:00                       0.289515
#
#                      gas pipeline GB2 0 -> GB0 0-2030  \
# snapshot
# 2013-01-01 00:00:00                          0.003432
# 2013-01-01 01:00:00                          0.003419
#
#                      GB2 0 methanolisation-2030  GB2 0 Haber-Bosch-2030  \
# snapshot
# 2013-01-01 00:00:00                    0.022358              121.946493
# 2013-01-01 01:00:00                    0.022402              121.946491
#
#                      GB2 0 H2 Electrolysis-2030  \
# snapshot
# 2013-01-01 00:00:00                 5794.522542
# 2013-01-01 01:00:00                 5843.251388
#
#                      H2 pipeline GB0 0 -> GB2 0-reversed-2030  GB2 0 load  \
# snapshot
# 2013-01-01 00:00:00                                 11.940442    0.000057
# 2013-01-01 01:00:00                                 11.940442    0.000057
#
#                      GB2 0 low voltage load
# snapshot
# 2013-01-01 00:00:00                0.000049
# 2013-01-01 01:00:00                0.000049
#
# [2 rows x 30 columns]

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         C-05. Calculating Total Electric Consumption (with Commented-Out Positive Technologies)
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process calculates the <b>total electric consumption</b> for each zone by summing positive contributions (consumption) and subtracting negative contributions (generation or injection). In this version, <b>heat pumps and resistive heaters have been commented out</b> from the positive technologies list, meaning they are not included in the total electric consumption calculation.<br>
#     <b>Calculation Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         The script categorizes technologies into <b>positive</b> (consuming electricity) and <b>negative</b> (generating or injecting electricity). <br>The positive technologies list currently includes only EV chargers, battery chargers, gas pipelines, H2 technologies, and DAC.<br> <b>Heat pumps and resistive heaters are commented out</b> and therefore excluded from the calculation.
#         <br>
#         For each zone, it iterates through all technology categories, sums the values of all matching columns, and applies the appropriate sign:
#             <div style="text-align: center; font-size:14px;">
#         <b>Total = Σ(Positive Technologies) - Σ(Negative Technologies)</b>
#             </div>
#         The results are stored in a <b>new dictionary</b> (<b>total_electric_consumption</b>) with a single column named <b>"Total_Electric_Consumption"</b> per zone.<br>
#         A warning is issued if any columns remain unassigned.
#     </div>
# </div>

# %%
### CALCULATE TOTAL ELECTRIC CONSUMPTION
# _____________________________________________________
### Technologies with POSITIVE contribution
# =====================================================
positive_technologies = [
    "EV charger",
    "battery charger",
    "gas pipeline",
    "gas pipeline new",
    "methanolisation",
    "Haber-Bosch",
    "H2 Electrolysis",
    "H2 pipeline",
    "urban central DAC",
    #"urban central air heat pump",
    #"services urban decentral air heat pump",
    #"services rural air heat pump",
    #"services rural ground heat pump",
    #"residential rural air heat pump",
    #"residential rural ground heat pump",
    #"residential urban decentral air heat pump",
]
'''if not VPP:
    positive_technologies += [
        "urban central resistive heater",
        "services urban decentral resistive heater",
        "services rural resistive heater",
        "residential rural resistive heater",
        "residential urban decentral resistive heater",
]'''
# =====================================================
### Technologies with NEGATIVE contribution
# =====================================================
negative_technologies = [
    "V2G",
    "battery discharger",
    # "H2 turbine",
    # "H2 Fuel Cell",
    "load",
    "low voltage load",
]
# =====================================================
### CREATE NEW DICTIONARY
total_electric_consumption = {}
### APPLY FORMULA TO EVERY DATAFRAME
for zone, df in generators_links_electric_consumption_dict_selected.items():
    print(f"\n--- Processing {zone} ---")
    ### Start with zero
    total_electric_consumption_series = pd.Series(
        0.0,
        index=df.index
    )
    ### Keep track of columns already assigned
    assigned_columns = set()
    ### POSITIVE CONTRIBUTIONS
    for technology in positive_technologies:
        matching_columns = [
            column
            for column in df.columns
            if (
                technology in str(column)
                and column not in assigned_columns
            )
        ]
        if matching_columns:
            print(
                f"  + {technology}: "
                f"{len(matching_columns)} column(s)"
            )
            total_electric_consumption_series = (
                total_electric_consumption_series
                + df[matching_columns].sum(axis=1)
            )
            assigned_columns.update(matching_columns)
    ### NEGATIVE CONTRIBUTIONS
    for technology in negative_technologies:
        matching_columns = [
            column
            for column in df.columns
            if (
                technology in str(column)
                and column not in assigned_columns
            )
        ]
        if matching_columns:
            print(
                f"  - {technology}: "
                f"{len(matching_columns)} column(s)"
            )
            total_electric_consumption_series = (
                total_electric_consumption_series
                - df[matching_columns].sum(axis=1)
            )
            assigned_columns.update(matching_columns)
    ### CHECK FOR UNASSIGNED TECHNOLOGY COLUMNS
    unassigned_columns = [
        column
        for column in df.columns
        if column not in assigned_columns
        and column != "snapshot"
    ]
    if unassigned_columns:
        print("\n  WARNING: Unassigned columns:")
        for column in unassigned_columns:
            print(f"    {column}")
    ### CREATE DATAFRAME FOR THIS ZONE
    total_electric_consumption[zone] = (
        total_electric_consumption_series.to_frame(
            name="Total_Electric_Consumption"
        )
    )
    total_electric_consumption[zone].index.name = "snapshot"
    ### INSPECTION
    print(
        "  Created: Total_Electric_Consumption"
    )
    print(
        f"  Final shape: "
        f"{total_electric_consumption[zone].shape}"
    )
    print(
        "  First values:"
    )
    print(
        total_electric_consumption[zone][
            "Total_Electric_Consumption"
        ].head(2)
    )
### FINAL MESSAGE
print("\n" + "=" * 70)
print(
    "Successfully calculated "
    "'Total_Electric_Consumption' "
    "for all zones."
)
print(
    "Results stored in the new dictionary:"
    " 'total_electric_consumption'"
)
print("=" * 70)
# Out:
# --- Processing BE ---
#   + EV charger: 1 column(s)
#   + battery charger: 1 column(s)
#   + gas pipeline: 8 column(s)
#   + methanolisation: 1 column(s)
#   + Haber-Bosch: 1 column(s)
#   + H2 Electrolysis: 1 column(s)
#   + H2 pipeline: 4 column(s)
#   - V2G: 1 column(s)
#   - battery discharger: 1 column(s)
#   - load: 2 column(s)
#   Created: Total_Electric_Consumption
#   Final shape: (8760, 1)
#   First values:
# snapshot
# 2013-01-01 00:00:00    2681.858458
# 2013-01-01 01:00:00    2063.208315
# Name: Total_Electric_Consumption, dtype: float64
#
# --- Processing FR ---
#   + EV charger: 1 column(s)
#   + battery charger: 1 column(s)
#   + gas pipeline: 5 column(s)
#   + methanolisation: 1 column(s)
#   + Haber-Bosch: 1 column(s)
#   + H2 Electrolysis: 1 column(s)
#   + H2 pipeline: 3 column(s)
#   - V2G: 1 column(s)
#   - battery discharger: 1 column(s)
#   - load: 2 column(s)
#   Created: Total_Electric_Consumption
#   Final shape: (8760, 1)
#   First values:
# snapshot
# 2013-01-01 00:00:00    2428.783944
# 2013-01-01 01:00:00    2328.372687
# Name: Total_Electric_Consumption, dtype: float64
#
# --- Processing DE ---
#   + EV charger: 1 column(s)
#   + battery charger: 1 column(s)
#   + gas pipeline: 7 column(s)
#   + methanolisation: 1 column(s)
#   + Haber-Bosch: 1 column(s)
#   + H2 Electrolysis: 1 column(s)
#   + H2 pipeline: 4 column(s)
#   - V2G: 1 column(s)
#   - battery discharger: 1 column(s)
#   - load: 2 column(s)
#   Created: Total_Electric_Consumption
#   Final shape: (8760, 1)
#   First values:
# snapshot
# 2013-01-01 00:00:00    706.860649
# 2013-01-01 01:00:00    561.629993
# Name: Total_Electric_Consumption, dtype: float64
#
# --- Processing NL ---
#   + EV charger: 1 column(s)
#   + battery charger: 1 column(s)
#   + gas pipeline: 10 column(s)
#   + methanolisation: 1 column(s)
#   + Haber-Bosch: 1 column(s)
#   + H2 Electrolysis: 1 column(s)
#   + H2 pipeline: 3 column(s)
#   - V2G: 1 column(s)
#   - battery discharger: 1 column(s)
#   - load: 2 column(s)
#   Created: Total_Electric_Consumption
#   Final shape: (8760, 1)
#   First values:
# snapshot
# 2013-01-01 00:00:00    6129.096863
# 2013-01-01 01:00:00    4786.897107
# Name: Total_Electric_Consumption, dtype: float64
#
# --- Processing UK ---
#   + EV charger: 2 column(s)
#   + battery charger: 2 column(s)
#   + gas pipeline: 6 column(s)
#   + methanolisation: 2 column(s)
#   + Haber-Bosch: 2 column(s)
#   + H2 Electrolysis: 2 column(s)
#   + H2 pipeline: 6 column(s)
#   - V2G: 2 column(s)
#   - battery discharger: 2 column(s)
#   - load: 4 column(s)
#   Created: Total_Electric_Consumption
#   Final shape: (8760, 1)
#   First values:
# snapshot
# 2013-01-01 00:00:00    5687.399806
# 2013-01-01 01:00:00    5663.155241
# Name: Total_Electric_Consumption, dtype: float64
#
# ======================================================================
# Successfully calculated 'Total_Electric_Consumption' for all zones.
# Results stored in the new dictionary: 'total_electric_consumption'
# ======================================================================

# %% [markdown]
# <div style= "background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099; " >
#  <span style= "font-weight: bold; font-size: 16px; " >
# Section D Overview: Heat Loads, Thermal Efficiencies & Equivalencies
#  </span >
#  <div style= "border-top: 1px solid #000099; padding: 10px; " >
# This section builds the complete thermal demand picture.<br>
#      It extracts heat load time series, integrates generator and link outputs (boilers, water tanks, solar thermal), and calculates the net heat balance.<br>
#      It then allocates these balances to individual assets using fractional contributions, applies time-varying COPs or static efficiencies, and calculates the final electric equivalency required to meet the thermal demands.<br>
#         The main target of this section is calculating the <b>electric equivalent of heat consumption</b> for heater units by accounting for their <b>thermal efficiency</b> or <b>Coefficient of Performance (COP)</b>, depending on the unit type. <br>The resulting profiles represent the electricity required to produce the allocated heat output.<br>
#     <b>Calculation Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each heater unit, the script identifies the <b>heat proportion</b> column and retrieves the corresponding efficiency or COP value from the metadata. The electric equivalent consumption is then calculated as:
#     <div style="text-align: center; font-size: 14px;">
#         <b>Electric Equivalent = Heat Proportion / Efficiency (or COP)</b>
#         </div >
#         This conversion ensures that the electrical input required for heat generation is correctly modeled for each unit type (e.g., resistive heaters use efficiency, heat pumps use COP).<br>
#         The resulting electric equivalent profiles are stored as new columns (e.g., <b>{asset_name}_/ThermEfficiency</b>) and are ready for integration into the Dispa-SET load profiles.
#         </div >
#  </div >
# </div >
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#      D-01. Extracting Heat Load Time Series from CSV
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process extracts <b>heat load time series</b> from a master CSV file and organizes them into a <b>nested dictionary</b> by country and heat load category.<br> Each heat load category can have multiple associated load types (e.g., urban central heat + low-temperature heat for industry).<br>
#     <b>Extraction Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each heat load category, the script maps it to one or more load string targets.<br> It then iterates through all countries, builds a list of search prefixes (primary code + acronyms), and finds columns in the master DataFrame that match both the <b>country prefix</b> and the <b>load string</b>.<br>
#         Matching columns are stored in a nested dictionary: <b>country_loads_time_series[country][heat_load]</b>.
#         </div>
#     </div>
# </div>

# %%
### LOAD ALL LOAD TIME SERIES FROM CSV
# _____________________________________________________________________________
### Build the input CSV path
loads_file = os.path.join(
    loads_pypsa_raw_data_folder_path,
    f"loads_{pypsa_scenario}_{data_target_year}.csv"
)
### Load the master load time-series DataFrame
master_loads_ts = pd.read_csv(loads_file, index_col=0)
print(f"Loaded load time series from:")
print(loads_file)
print(f"Shape: {master_loads_ts.shape}")
### INITIALIZE MASTER DICTIONARY
country_loads_time_series = {}
### Define all possible heat load categories to loop through
# =============================================================================
all_heat_loads = [
    'urban central heat',
    'services urban decentral heat',
    'services rural heat',
    'residential rural heat',
    'residential urban decentral heat',
]
# =============================================================================
### Initialize country keys in our master dictionary
for country in zone_names:
    country_loads_time_series[country] = {}
### EXTRACT THE REQUIRED TIME SERIES
# _____________________________________________________________________________
### Process each heat load configuration group sequentially
for current_heat_load in all_heat_loads:
    print(f"\n--- Extracting Time Series for: {current_heat_load} ---")
    ### 1. Map current heat load to its corresponding string targets
    if current_heat_load == 'urban central heat':
        loads_list = [
            'urban central heat',
            'low-temperature heat for industry'
        ]
    elif current_heat_load == 'services urban decentral heat':
        loads_list = [
            'services urban decentral heat'
        ]
    elif current_heat_load == 'services rural heat':
        loads_list = [
            'services rural heat',
            'agriculture heat'
        ]
    elif current_heat_load == 'residential rural heat':
        loads_list = [
            'residential rural heat'
        ]
    elif current_heat_load == 'residential urban decentral heat':
        loads_list = [
            'residential urban decentral heat'
        ]
    else:
        loads_list = []
    ### 2. Loop through countries
    for country in zone_names:
        ### Determine the search prefixes for this country
        ### Example: ['UK', 'GB']
        search_prefixes = [country]
        if country in zone_names_equivalences_dict:
            acronyms = zone_names_equivalences_dict[country]["Acronym"]
            clean_acronyms = [
                acr.strip()
                for acr in acronyms
                if acr.strip()
            ]
            search_prefixes.extend(clean_acronyms)
        ### 3. Find matching columns
        matching_columns = [
            col
            for col in master_loads_ts.columns
            if any(prefix in col for prefix in search_prefixes)
            and any(ld in col for ld in loads_list)
        ]
        ### 4. Extract matching time series
        if matching_columns:
            ### Keep all matching load columns side-by-side
            ts_dataframe = master_loads_ts[matching_columns].copy()
            ### Store inside nested dictionary
            country_loads_time_series[country][current_heat_load] = ts_dataframe
            print(
                f"  [{country}] Extracted "
                f"{len(matching_columns)} distinct load columns "
                f"into dictionary entry."
            )
        else:
            ### Empty DataFrame if no matching loads exist
            country_loads_time_series[country][current_heat_load] = pd.DataFrame()
            print(
                f"  [{country}] No matching load columns found."
            )
### CHECK RESULT
print(
    "\nAll time-series DataFrames have been collected into "
    "'country_loads_time_series' with separate columns!"
)
### Show dictionary structure
for country, loads in country_loads_time_series.items():
    print(country, type(loads))
    for load_name, df in loads.items():
        print("  ", load_name, type(df))
### Show the actual columns assigned to each entry
for country, loads in country_loads_time_series.items():
    print(f"\nCountry: {country}")
    for load_name, df in loads.items():
        print(f"  Load: {load_name}")
        print(f"  Columns: {df.columns.tolist()}")
# Out:
# Loaded load time series from:
# /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/Load_RealTime/loads_Sufficiency_Scenario_2030.csv
# Shape: (8760, 139)
#
# --- Extracting Time Series for: urban central heat ---
#   [BE] Extracted 2 distinct load columns into dictionary entry.
#   [FR] Extracted 2 distinct load columns into dictionary entry.
#   [DE] Extracted 2 distinct load columns into dictionary entry.
#   [NL] Extracted 2 distinct load columns into dictionary entry.
#   [UK] Extracted 4 distinct load columns into dictionary entry.
#
# --- Extracting Time Series for: services urban decentral heat ---
#   [BE] Extracted 1 distinct load columns into dictionary entry.
#   [FR] Extracted 1 distinct load columns into dictionary entry.
#   [DE] Extracted 1 distinct load columns into dictionary entry.
#   [NL] Extracted 1 distinct load columns into dictionary entry.
#   [UK] Extracted 2 distinct load columns into dictionary entry.
#
# --- Extracting Time Series for: services rural heat ---
#   [BE] Extracted 2 distinct load columns into dictionary entry.
#   [FR] Extracted 2 distinct load columns into dictionary entry.
#   [DE] Extracted 2 distinct load columns into dictionary entry.
#   [NL] Extracted 2 distinct load columns into dictionary entry.
#   [UK] Extracted 4 distinct load columns into dictionary entry.
#
# --- Extracting Time Series for: residential rural heat ---
#   [BE] Extracted 1 distinct load columns into dictionary entry.
#   [FR] Extracted 1 distinct load columns into dictionary entry.
#   [DE] Extracted 1 distinct load columns into dictionary entry.
#   [NL] Extracted 1 distinct load columns into dictionary entry.
#   [UK] Extracted 2 distinct load columns into dictionary entry.
#
# --- Extracting Time Series for: residential urban decentral heat ---
#   [BE] Extracted 1 distinct load columns into dictionary entry.
#   [FR] Extracted 1 distinct load columns into dictionary entry.
#   [DE] Extracted 1 distinct load columns into dictionary entry.
#   [NL] Extracted 1 distinct load columns into dictionary entry.
#   [UK] Extracted 2 distinct load columns into dictionary entry.
#
# All time-series DataFrames have been collected into 'country_loads_time_series' with separate columns!
# BE <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
# FR <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
# DE <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
# NL <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
# UK <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
#
# Country: BE
#   Load: urban central heat
#   Columns: ['BE1 0 urban central heat', 'BE1 0 low-temperature heat for industry']
#   Load: services urban decentral heat
#   Columns: ['BE1 0 services urban decentral heat']
#   Load: services rural heat
#   Columns: ['BE1 0 services rural heat', 'BE1 0 agriculture heat']
#   Load: residential rural heat
#   Columns: ['BE1 0 residential rural heat']
#   Load: residential urban decentral heat
#   Columns: ['BE1 0 residential urban decentral heat']
#
# Country: FR
#   Load: urban central heat
#   Columns: ['FR1 0 urban central heat', 'FR1 0 low-temperature heat for industry']
#   Load: services urban decentral heat
#   Columns: ['FR1 0 services urban decentral heat']
#   Load: services rural heat
#   Columns: ['FR1 0 services rural heat', 'FR1 0 agriculture heat']
#   Load: residential rural heat
#   Columns: ['FR1 0 residential rural heat']
#   Load: residential urban decentral heat
#   Columns: ['FR1 0 residential urban decentral heat']
#
# Country: DE
#   Load: urban central heat
#   Columns: ['DE1 0 urban central heat', 'DE1 0 low-temperature heat for industry']
#   Load: services urban decentral heat
#   Columns: ['DE1 0 services urban decentral heat']
#   Load: services rural heat
#   Columns: ['DE1 0 services rural heat', 'DE1 0 agriculture heat']
#   Load: residential rural heat
#   Columns: ['DE1 0 residential rural heat']
#   Load: residential urban decentral heat
#   Columns: ['DE1 0 residential urban decentral heat']
#
# Country: NL
#   Load: urban central heat
#   Columns: ['NL1 0 urban central heat', 'NL1 0 low-temperature heat for industry']
#   Load: services urban decentral heat
#   Columns: ['NL1 0 services urban decentral heat']
#   Load: services rural heat
#   Columns: ['NL1 0 services rural heat', 'NL1 0 agriculture heat']
#   Load: residential rural heat
#   Columns: ['NL1 0 residential rural heat']
#   Load: residential urban decentral heat
#   Columns: ['NL1 0 residential urban decentral heat']
#
# Country: UK
#   Load: urban central heat
#   Columns: ['GB0 0 urban central heat', 'GB2 0 urban central heat', 'GB0 0 low-temperature heat for industry', 'GB2 0 low-temperature heat for industry']
#   Load: services urban decentral heat
#   Columns: ['GB0 0 services urban decentral heat', 'GB2 0 services urban decentral heat']
#   Load: services rural heat
#   Columns: ['GB0 0 services rural heat', 'GB2 0 services rural heat', 'GB0 0 agriculture heat', 'GB2 0 agriculture heat']
#   Load: residential rural heat
#   Columns: ['GB0 0 residential rural heat', 'GB2 0 residential rural heat']
#   Load: residential urban decentral heat
#   Columns: ['GB0 0 residential urban decentral heat', 'GB2 0 residential urban decentral heat']

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#       D-02. Adding Generator-Based Heat Profiles to Load Dictionary
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process integrates <b>generator-based heat profiles</b> (e.g., solar thermal collectors, heat loads) into the existing <b>country_loads_time_series</b> dictionary. <br>It loads a master generator time-series CSV and appends matching columns to the appropriate heat load category for each country.<br>
#     <b>Integration Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each heat load category, the script maps it to corresponding generator load strings (e.g., <b>urban central solar thermal collector</b>, <b>urban central heat load</b>). It then iterates through all countries, builds search prefixes (primary code + acronyms), and finds matching columns in the <b>master_generators_ts</b> DataFrame. Matching columns are appended to the existing DataFrame for that country and heat load using <b>pd.concat()</b>.
#         </div>
#     </div>
# </div>

# %%
### Build the input CSV path
loads_file = os.path.join(
    loads_pypsa_raw_data_folder_path,
    f"master_generators_ts_{pypsa_scenario}_{data_target_year}.csv"
)
### Load the master generator time-series DataFrame
master_generators_ts = pd.read_csv(loads_file, index_col=0)
print(f"Loaded generators time series from:")
print(loads_file)
print(f"Shape: {master_generators_ts.shape}")
### Master generator time-series DataFrame from the PyPSA network
### Process each heat load configuration group sequentially
for current_heat_load in all_heat_loads:
    print(f"\n--- Extracting Generator Columns for: {current_heat_load} ---")    
    ### 1. Map current heat load to its corresponding generator string targets
    if current_heat_load == 'urban central heat':
        generator_loads_list = ['urban central solar thermal collector', 'urban central heat load']
    elif current_heat_load == 'services urban decentral heat':
        generator_loads_list = ['services urban decentral solar thermal collector', 'services urban decentral heat load']
    elif current_heat_load == 'services rural heat':
        generator_loads_list = ['services rural solar thermal collector', 'services rural heat load']
    elif current_heat_load == 'residential rural heat':
        generator_loads_list = ['residential rural solar thermal collector', 'residential rural heat load']
    elif current_heat_load == 'residential urban decentral heat':
        ### Note: Keeps the slight typo 'resiential' intact just in case your PyPSA network naming uses it
        generator_loads_list = ['residential urban decentral solar thermal collector', 'residential urban decentral heat load']
    else:
        generator_loads_list = []
    ### 2. Loop through countries to find and append the generator columns
    for country in zone_names:
        ### Determine the search prefixes for this country (e.g., ['UK', 'GB'])
        search_prefixes = [country]
        if country in zone_names_equivalences_dict:
            acronyms = zone_names_equivalences_dict[country]["Acronym"]
            clean_acronyms = [acr.strip() for acr in acronyms if acr.strip()]
            search_prefixes.extend(clean_acronyms)
        ### 3. Find matching individual columns in the GENERATOR time-series matrix
        matching_gen_columns = [
            col for col in master_generators_ts.columns
            if any(prefix in col for prefix in search_prefixes) and 
               any(gen_ld in col for gen_ld in generator_loads_list)
        ]
        ### 4. If matching generator columns are found, copy them into the existing dictionary DataFrame
        if matching_gen_columns:
            ### Extract the matching generator columns
            gen_ts_dataframe = master_generators_ts[matching_gen_columns].copy()   
            ### Retrieve the already existing loads DataFrame from your dictionary
            existing_df = country_loads_time_series[country][current_heat_load]
            ### Use pd.concat along axis=1 to attach the generator columns side-by-side
            if not existing_df.empty:
                updated_df = pd.concat([existing_df, gen_ts_dataframe], axis=1)
            else:
                updated_df = gen_ts_dataframe
            ### Put the expanded DataFrame back into the dictionary
            country_loads_time_series[country][current_heat_load] = updated_df
            print(f"  [{country}] Added {len(matching_gen_columns)} generator columns to the existing collection.")
        else:
            ### No matching generators found for this group/country; leave existing data untouched
            pass
print("\nSuccessfully integrated all generator-based heat profiles into 'country_loads_time_series'!")
for country, loads in country_loads_time_series.items():
    print(country, type(loads))
    for load_name, df in loads.items():
        print("  ", load_name, type(df))
for country, loads in country_loads_time_series.items():
    print(f"\nCountry: {country}")
    for load_name, df in loads.items():
        print(f"  Load: {load_name}")
        print(f"  Columns: {df.columns.tolist()}")
# Out:
# Loaded generators time series from:
# /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/Load_RealTime/master_generators_ts_Sufficiency_Scenario_2030.csv
# Shape: (8760, 352)
#
# --- Extracting Generator Columns for: urban central heat ---
#   [BE] Added 2 generator columns to the existing collection.
#   [FR] Added 2 generator columns to the existing collection.
#   [DE] Added 2 generator columns to the existing collection.
#   [NL] Added 2 generator columns to the existing collection.
#   [UK] Added 4 generator columns to the existing collection.
#
# --- Extracting Generator Columns for: services urban decentral heat ---
#   [BE] Added 2 generator columns to the existing collection.
#   [FR] Added 2 generator columns to the existing collection.
#   [DE] Added 2 generator columns to the existing collection.
#   [NL] Added 2 generator columns to the existing collection.
#   [UK] Added 4 generator columns to the existing collection.
#
# --- Extracting Generator Columns for: services rural heat ---
#   [BE] Added 2 generator columns to the existing collection.
#   [FR] Added 2 generator columns to the existing collection.
#   [DE] Added 2 generator columns to the existing collection.
#   [NL] Added 2 generator columns to the existing collection.
#   [UK] Added 4 generator columns to the existing collection.
#
# --- Extracting Generator Columns for: residential rural heat ---
#   [BE] Added 2 generator columns to the existing collection.
#   [FR] Added 2 generator columns to the existing collection.
#   [DE] Added 2 generator columns to the existing collection.
#   [NL] Added 2 generator columns to the existing collection.
#   [UK] Added 4 generator columns to the existing collection.
#
# --- Extracting Generator Columns for: residential urban decentral heat ---
#   [BE] Added 2 generator columns to the existing collection.
#   [FR] Added 2 generator columns to the existing collection.
#   [DE] Added 2 generator columns to the existing collection.
#   [NL] Added 2 generator columns to the existing collection.
#   [UK] Added 4 generator columns to the existing collection.
#
# Successfully integrated all generator-based heat profiles into 'country_loads_time_series'!
# BE <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
# FR <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
# DE <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
# NL <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
# UK <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
#
# Country: BE
#   Load: urban central heat
#   Columns: ['BE1 0 urban central heat', 'BE1 0 low-temperature heat for industry', 'BE1 0 urban central solar thermal collector-2030', 'BE1 0 urban central heat load']
#   Load: services urban decentral heat
#   Columns: ['BE1 0 services urban decentral heat', 'BE1 0 services urban decentral solar thermal collector-2030', 'BE1 0 services urban decentral heat load']
#   Load: services rural heat
#   Columns: ['BE1 0 services rural heat', 'BE1 0 agriculture heat', 'BE1 0 services rural solar thermal collector-2030', 'BE1 0 services rural heat load']
#   Load: residential rural heat
#   Columns: ['BE1 0 residential rural heat', 'BE1 0 residential rural solar thermal collector-2030', 'BE1 0 residential rural heat load']
#   Load: residential urban decentral heat
#   Columns: ['BE1 0 residential urban decentral heat', 'BE1 0 residential urban decentral solar thermal collector-2030', 'BE1 0 residential urban decentral heat load']
#
# Country: FR
#   Load: urban central heat
#   Columns: ['FR1 0 urban central heat', 'FR1 0 low-temperature heat for industry', 'FR1 0 urban central solar thermal collector-2030', 'FR1 0 urban central heat load']
#   Load: services urban decentral heat
#   Columns: ['FR1 0 services urban decentral heat', 'FR1 0 services urban decentral solar thermal collector-2030', 'FR1 0 services urban decentral heat load']
#   Load: services rural heat
#   Columns: ['FR1 0 services rural heat', 'FR1 0 agriculture heat', 'FR1 0 services rural solar thermal collector-2030', 'FR1 0 services rural heat load']
#   Load: residential rural heat
#   Columns: ['FR1 0 residential rural heat', 'FR1 0 residential rural solar thermal collector-2030', 'FR1 0 residential rural heat load']
#   Load: residential urban decentral heat
#   Columns: ['FR1 0 residential urban decentral heat', 'FR1 0 residential urban decentral solar thermal collector-2030', 'FR1 0 residential urban decentral heat load']
#
# Country: DE
#   Load: urban central heat
#   Columns: ['DE1 0 urban central heat', 'DE1 0 low-temperature heat for industry', 'DE1 0 urban central solar thermal collector-2030', 'DE1 0 urban central heat load']
#   Load: services urban decentral heat
#   Columns: ['DE1 0 services urban decentral heat', 'DE1 0 services urban decentral solar thermal collector-2030', 'DE1 0 services urban decentral heat load']
#   Load: services rural heat
#   Columns: ['DE1 0 services rural heat', 'DE1 0 agriculture heat', 'DE1 0 services rural solar thermal collector-2030', 'DE1 0 services rural heat load']
#   Load: residential rural heat
#   Columns: ['DE1 0 residential rural heat', 'DE1 0 residential rural solar thermal collector-2030', 'DE1 0 residential rural heat load']
#   Load: residential urban decentral heat
#   Columns: ['DE1 0 residential urban decentral heat', 'DE1 0 residential urban decentral solar thermal collector-2030', 'DE1 0 residential urban decentral heat load']
#
# Country: NL
#   Load: urban central heat
#   Columns: ['NL1 0 urban central heat', 'NL1 0 low-temperature heat for industry', 'NL1 0 urban central solar thermal collector-2030', 'NL1 0 urban central heat load']
#   Load: services urban decentral heat
#   Columns: ['NL1 0 services urban decentral heat', 'NL1 0 services urban decentral solar thermal collector-2030', 'NL1 0 services urban decentral heat load']
#   Load: services rural heat
#   Columns: ['NL1 0 services rural heat', 'NL1 0 agriculture heat', 'NL1 0 services rural solar thermal collector-2030', 'NL1 0 services rural heat load']
#   Load: residential rural heat
#   Columns: ['NL1 0 residential rural heat', 'NL1 0 residential rural solar thermal collector-2030', 'NL1 0 residential rural heat load']
#   Load: residential urban decentral heat
#   Columns: ['NL1 0 residential urban decentral heat', 'NL1 0 residential urban decentral solar thermal collector-2030', 'NL1 0 residential urban decentral heat load']
#
# Country: UK
#   Load: urban central heat
#   Columns: ['GB0 0 urban central heat', 'GB2 0 urban central heat', 'GB0 0 low-temperature heat for industry', 'GB2 0 low-temperature heat for industry', 'GB0 0 urban central solar thermal collector-2030', 'GB2 0 urban central solar thermal collector-2030', 'GB0 0 urban central heat load', 'GB2 0 urban central heat load']
#   Load: services urban decentral heat
#   Columns: ['GB0 0 services urban decentral heat', 'GB2 0 services urban decentral heat', 'GB0 0 services urban decentral solar thermal collector-2030', 'GB2 0 services urban decentral solar thermal collector-2030', 'GB0 0 services urban decentral heat load', 'GB2 0 services urban decentral heat load']
#   Load: services rural heat
#   Columns: ['GB0 0 services rural heat', 'GB2 0 services rural heat', 'GB0 0 agriculture heat', 'GB2 0 agriculture heat', 'GB0 0 services rural solar thermal collector-2030', 'GB2 0 services rural solar thermal collector-2030', 'GB0 0 services rural heat load', 'GB2 0 services rural heat load']
#   Load: residential rural heat
#   Columns: ['GB0 0 residential rural heat', 'GB2 0 residential rural heat', 'GB0 0 residential rural solar thermal collector-2030', 'GB2 0 residential rural solar thermal collector-2030', 'GB0 0 residential rural heat load', 'GB2 0 residential rural heat load']
#   Load: residential urban decentral heat
#   Columns: ['GB0 0 residential urban decentral heat', 'GB2 0 residential urban decentral heat', 'GB0 0 residential urban decentral solar thermal collector-2030', 'GB2 0 residential urban decentral solar thermal collector-2030', 'GB0 0 residential urban decentral heat load', 'GB2 0 residential urban decentral heat load']

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#        D-03. Loading PyPSA Links Data
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process loads the <b>PyPSA links</b> CSV files for all selected zones.<br> Links represent multi-component energy system elements (e.g., CHP plants, H2 pipelines, battery chargers/dischargers, heat pumps) that connect multiple buses and have directional flows.<br>
#     <b>Loading Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each country in <b>zone_names</b>, the script constructs the file path using the scenario, year, and country: <b>{base_path}/{scenario}/PowerPlants/{year}/{country}/{country}_links.csv</b>. The CSV is loaded into a DataFrame and stored in a dictionary keyed by the country code.
#         </div>
#     </div>
# </div>

# %%
### LOAD PYPSA LINKS FOR ALL SELECTED ZONES
links_pypsa_dictionary = {}
for country in zone_names:
    links_file = os.path.join(
        pypsa_raw_data_folder_path,
        pypsa_scenario,
        "PowerPlants",
        data_target_year,
        country,
        f"{country}_links.csv"
    )
    print(f"\nLoading links for {country}...")
    print(f"File: {links_file}")
    links_df = pd.read_csv(links_file)
    links_pypsa_dictionary[country] = links_df
    print(
        f"{country} | "
        f"Rows: {len(links_df):,} | "
        f"Columns: {len(links_df.columns):,}"
    )
### SUMMARY
print("\n" + "=" * 80)
print("PYPSA LINKS LOADED")
print("=" * 80)
print(f"Scenario: {pypsa_scenario}")
print(f"Year:     {data_target_year}")
print(f"Zones:    {zone_names}")
print("\nLoaded DataFrames:")
for country, df in links_pypsa_dictionary.items():
    print(
        f"{country} | "
        f"Rows: {len(df):,} | "
        f"Columns: {len(df.columns):,}"
    )
# Out:
# Loading links for BE...
# File: /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/BE/BE_links.csv
# BE | Rows: 100 | Columns: 61
#
# Loading links for FR...
# File: /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/FR/FR_links.csv
# FR | Rows: 118 | Columns: 61
#
# Loading links for DE...
# File: /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/DE/DE_links.csv
# DE | Rows: 134 | Columns: 61
#
# Loading links for NL...
# File: /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/NL/NL_links.csv
# NL | Rows: 101 | Columns: 61
#
# Loading links for UK...
# File: /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/UK/UK_links.csv
# UK | Rows: 203 | Columns: 61
#
# ================================================================================
# PYPSA LINKS LOADED
# ================================================================================
# Scenario: Sufficiency_Scenario
# Year:     2030
# Zones:    ['BE', 'FR', 'DE', 'NL', 'UK']
#
# Loaded DataFrames:
# BE | Rows: 100 | Columns: 61
# FR | Rows: 118 | Columns: 61
# DE | Rows: 134 | Columns: 61
# NL | Rows: 101 | Columns: 61
# UK | Rows: 203 | Columns: 61

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         D-04. Loading Relevant Link Time Series
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process loads the <b>relevant link time series</b> CSV file, which contains the operational time series data for link components (e.g., CHP, H2 pipelines, EV chargers, heat pumps) in the PyPSA network.<br> These time series include flows, consumption, and generation profiles.<br>
#     <b>Loading Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         The script constructs the file path: <b>{base_path}/{scenario}/Load_RealTime/relevant_links_timeseries_{scenario}_{year}.csv</b>. The CSV is loaded into a DataFrame, and a summary report displays the number of rows, columns, column names, and a preview of the first rows.
#         </div>
#     </div>
# </div>

# %%
### LOAD RELEVANT LINK TIME SERIES
relevant_links_timeseries_file = os.path.join(
    pypsa_raw_data_folder_path,
    pypsa_scenario,
    "Load_RealTime",
    f"relevant_links_timeseries_{pypsa_scenario}_{data_target_year}.csv"
)
print("Loading relevant link time series...")
print(f"File: {relevant_links_timeseries_file}")
relevant_links_timeseries_df = pd.read_csv(
    relevant_links_timeseries_file
)
print(
    f"Rows: {len(relevant_links_timeseries_df):,} | "
    f"Columns: {len(relevant_links_timeseries_df.columns):,}"
)
print("\nColumns:")
print(relevant_links_timeseries_df.columns.tolist())
print("\nFirst rows:")
print(relevant_links_timeseries_df.head())
# Out:
# Loading relevant link time series...
# File: /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/Load_RealTime/relevant_links_timeseries_Sufficiency_Scenario_2030.csv
# Rows: 1,804,560 | Columns: 6
#
# Columns:
# ['snapshot', 'link', 'country', 'heat_load', 'port', 'value']
#
# First rows:
#               snapshot                                     link country  \
# 0  2013-01-01 00:00:00  BE1 0 urban central water tanks charger      BE
# 1  2013-01-01 01:00:00  BE1 0 urban central water tanks charger      BE
# 2  2013-01-01 02:00:00  BE1 0 urban central water tanks charger      BE
# 3  2013-01-01 03:00:00  BE1 0 urban central water tanks charger      BE
# 4  2013-01-01 04:00:00  BE1 0 urban central water tanks charger      BE
#
#             heat_load port        value
# 0  urban central heat   p0  1133.509055
# 1  urban central heat   p0  1417.968956
# 2  urban central heat   p0  1209.269046
# 3  urban central heat   p0   933.492907
# 4  urban central heat   p0  2103.536583

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         D-05. Link Technologies Associated with Each Heat-Load Group
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This dictionary defines the <b>link technologies</b> associated with each <b>heat-load group</b>.<br> It maps each heat load category to a list of link technologies that contribute to or consume heat in that sector.<br> These include boilers (gas, oil, biomass), water tank storage (chargers/dischargers), DAC, and Fischer-Tropsch processes.<br>
#     <b>Mapping Logic:</b><br>
#         Each heat load category is assigned a list of link technologies that are relevant to that sector:
#         <div style="margin-left: 2em; font-size: 12px;">
#         <li><b>Urban Central Heat</b> → gas boiler, Fischer-Tropsch, water tanks, DAC<br>
#         <li><b>Services Urban Decentral Heat</b> → oil, biomass, gas boilers, water tanks<br>
#         <li><b>Services Rural Heat</b> → biomass, gas, oil boilers, water tanks<br>
#         <li><b>Residential Rural Heat</b> → biomass, oil, gas boilers, water tanks<br>
#         <li><b>Residential Urban Decentral Heat</b> → gas, oil, biomass boilers, water tanks
#     </div>
# </div>

# %%
### LINK TECHNOLOGIES ASSOCIATED WITH EACH HEAT-LOAD GROUP
# =============================================================================
links_loads_list = {
    'urban central heat': [
        'urban central gas boiler',
        'Fischer-Tropsch',
        'urban central water tanks charger',
        'urban central water tanks discharger',
        'urban central DAC'
    ],
    'services urban decentral heat': [
        'services urban decentral oil boiler',
        'services urban decentral biomass boiler',
        'services urban decentral gas boiler',
        'services urban decentral water tanks charger',
        'services urban decentral water tanks discharger'
    ],
    'services rural heat': [
        'services rural biomass boiler',
        'services rural gas boiler',
        'services rural oil boiler',
        'services rural water tanks charger',
        'services rural water tanks discharger'
    ],
    'residential rural heat': [
        'residential rural biomass boiler',
        'residential rural oil boiler',
        'residential rural gas boiler',
        'residential rural water tanks charger',
        'residential rural water tanks discharger'
    ],
    'residential urban decentral heat': [
        'residential urban decentral gas boiler',
        'residential urban decentral oil boiler',
        'residential urban decentral biomass boiler',
        'residential urban decentral water tanks charger',
        'residential urban decentral water tanks discharger'
    ]
}
# =============================================================================

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         D-06. Adding Relevant Link Time Series to Load Dictionary
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process integrates <b>link time series</b> (e.g., boiler outputs, water tank flows, DAC, Fischer-Tropsch) into the existing <b>country_loads_time_series</b> dictionary. <br>It matches links to their corresponding heat load category by identifying the correct bus and port, then appends the time series to the existing DataFrame.<br>
#     <b>Integration Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each heat load category and country, the script finds matching links from <b>links_pypsa_dictionary</b> based on technology names. For each candidate link, it identifies which bus (bus0–bus4) contains the heat load string, retrieves the corresponding time series from <b>relevant_links_timeseries_df</b>, and appends it to the existing DataFrame using <b>pd.concat(axis=1)</b>.
#         </div>
#     </div>
# </div>

# %%
### ADD RELEVANT LINK TIME SERIES TO THE EXISTING COUNTRY LOAD TIME SERIES
for current_heat_load, technology_list in links_loads_list.items():
    print(
        f"\n--- Processing link outputs for: "
        f"{current_heat_load} ---"
    )
    for country in zone_names:
        ### Existing dataframe
        existing_df = country_loads_time_series[
            country
        ][
            current_heat_load
        ]
        links_df = links_pypsa_dictionary[country]
        extracted_link_columns = {}
        ### Find candidate links
        matching_links = links_df[
            links_df["name"].astype(str).apply(
                lambda name:
                    any(
                        technology in name
                        for technology in technology_list
                    )
            )
        ]
        ### Process each candidate link
        for _, link_row in matching_links.iterrows():
            link_name = link_row["name"]
            target_port = None
            ### Find which bus contains the current heat-load bus
            for bus_number in range(5):
                bus_column = f"bus{bus_number}"
                if bus_column in links_df.columns:
                    bus_value = link_row[bus_column]
                    if pd.notna(bus_value):
                        bus_name = str(bus_value)
                        if current_heat_load in bus_name:
                            target_port = f"p{bus_number}"
                            break
            ### If no heat-load bus was found, skip this link
            if target_port is None:
                continue
            ### Retrieve the corresponding saved time series
            matching_ts = relevant_links_timeseries_df[
                (relevant_links_timeseries_df["country"] == country)
                &
                (relevant_links_timeseries_df["link"] == link_name)
                &
                (relevant_links_timeseries_df["heat_load"] == current_heat_load)
                &
                (relevant_links_timeseries_df["port"] == target_port)
            ]
            if matching_ts.empty:
                continue
            ### Convert long-format time series to a Series
            link_series = (
                matching_ts
                .set_index("snapshot")["value"]
                .rename(link_name)
            )
            extracted_link_columns[link_name] = link_series
        ### Add the link time series to the EXISTING dataframe
        if extracted_link_columns:
            links_ts_dataframe = pd.DataFrame(
                extracted_link_columns
            )
            ### IMPORTANT:
            ### Keep the existing load time series and append the links.
            country_loads_time_series[
                country
            ][
                current_heat_load
            ] = pd.concat(
                [
                    existing_df,
                    links_ts_dataframe
                ],
                axis=1
            )
        ### Report result
        print(
            f"{country} | "
            f"Existing columns: {len(existing_df.columns):,} | "
            f"Link columns added: {len(extracted_link_columns):,} | "
            f"Final columns: "
            f"{len(country_loads_time_series[country][current_heat_load].columns):,}"
        )
# Out:
# --- Processing link outputs for: urban central heat ---
# BE | Existing columns: 4 | Link columns added: 4 | Final columns: 8
# FR | Existing columns: 4 | Link columns added: 4 | Final columns: 8
# DE | Existing columns: 4 | Link columns added: 4 | Final columns: 8
# NL | Existing columns: 4 | Link columns added: 4 | Final columns: 8
# UK | Existing columns: 8 | Link columns added: 8 | Final columns: 16
#
# --- Processing link outputs for: services urban decentral heat ---
# BE | Existing columns: 3 | Link columns added: 8 | Final columns: 11
# FR | Existing columns: 3 | Link columns added: 8 | Final columns: 11
# DE | Existing columns: 3 | Link columns added: 8 | Final columns: 11
# NL | Existing columns: 3 | Link columns added: 6 | Final columns: 9
# UK | Existing columns: 6 | Link columns added: 14 | Final columns: 20
#
# --- Processing link outputs for: services rural heat ---
# BE | Existing columns: 4 | Link columns added: 8 | Final columns: 12
# FR | Existing columns: 4 | Link columns added: 8 | Final columns: 12
# DE | Existing columns: 4 | Link columns added: 8 | Final columns: 12
# NL | Existing columns: 4 | Link columns added: 6 | Final columns: 10
# UK | Existing columns: 8 | Link columns added: 14 | Final columns: 22
#
# --- Processing link outputs for: residential rural heat ---
# BE | Existing columns: 3 | Link columns added: 8 | Final columns: 11
# FR | Existing columns: 3 | Link columns added: 8 | Final columns: 11
# DE | Existing columns: 3 | Link columns added: 8 | Final columns: 11
# NL | Existing columns: 3 | Link columns added: 6 | Final columns: 9
# UK | Existing columns: 6 | Link columns added: 16 | Final columns: 22
#
# --- Processing link outputs for: residential urban decentral heat ---
# BE | Existing columns: 3 | Link columns added: 8 | Final columns: 11
# FR | Existing columns: 3 | Link columns added: 8 | Final columns: 11
# DE | Existing columns: 3 | Link columns added: 8 | Final columns: 11
# NL | Existing columns: 3 | Link columns added: 8 | Final columns: 11
# UK | Existing columns: 6 | Link columns added: 16 | Final columns: 22

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         D-07. Adding Relevant Link Time Series to Load Dictionary
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process integrates <b>link time series</b> (e.g., boiler outputs, water tank flows, DAC, Fischer-Tropsch) into the existing <b>country_loads_time_series</b> dictionary. <br>It matches links to their corresponding heat load category by identifying the correct bus and port, then appends the time series to the existing DataFrame.<br>
#     <b>Integration Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each heat load category and country, the script finds matching links from <b>links_pypsa_dictionary</b> based on technology names. For each candidate link, it identifies which bus (bus0–bus4) contains the heat load string, retrieves the corresponding time series from <b>relevant_links_timeseries_df</b>, and appends it to the existing DataFrame using <b>pd.concat(axis=1)</b>.
#         </div>
#     </div>
# </div>

# %%
### CALCULATE NET HEAT BALANCE
for country in zone_names:
    print(
        f"\n--- Calculating Energy Balances for Country: "
        f"{country} ---"
    )
    for current_heat_load in links_loads_list:
        df = country_loads_time_series[
            country
        ][
            current_heat_load
        ]
        ### Skip empty dataframes
        if df.empty:
            print(
                f"  [{current_heat_load}] Empty dataframe - skipped."
            )
            continue
        ### Helper function
        ### Finds all columns containing the requested technology/asset name
        ### and returns the row-wise sum of their absolute values.
        def get_val(substring):
            matched_cols = [
                column
                for column in df.columns
                if substring in column
            ]
            if matched_cols:
                return (
                    df[matched_cols]
                    .abs()
                    .sum(axis=1)
                )
            return 0.0
        ### URBAN CENTRAL HEAT
        if current_heat_load == 'urban central heat':
        # =====================================================================
            net_balance = (
                get_val('urban central heat')
                + get_val('low-temperature heat for industry')
                - get_val('urban central gas boiler')
                - get_val('urban central solar thermal collector')
                - get_val('Fischer-Tropsch')
                - get_val('urban central heat load')
                + get_val('urban central water tanks charger')
                - get_val('urban central water tanks discharger')
                + get_val('urban central DAC')
            )
        # =====================================================================
        ### SERVICES URBAN DECENTRAL HEAT
        elif current_heat_load == 'services urban decentral heat':
        # =====================================================================
            net_balance = (
                get_val('services urban decentral heat')
                - get_val('services urban decentral oil boiler')
                - get_val('services urban decentral solar thermal collector')
                - get_val('services urban decentral biomass boiler')
                - get_val('services urban decentral heat load')
                - get_val('services urban decentral gas boiler')
                + get_val('services urban decentral water tanks charger')
                - get_val('services urban decentral water tanks discharger')
            )
        # =====================================================================
        ### SERVICES RURAL HEAT
        elif current_heat_load == 'services rural heat':
        # =====================================================================
            net_balance = (
                get_val('services rural heat')
                + get_val('agriculture heat')
                - get_val('services rural biomass boiler')
                - get_val('services rural solar thermal collector')
                - get_val('services rural oil boiler')
                - get_val('services rural heat load')
                - get_val('services rural gas boiler')
                + get_val('services rural water tanks charger')
                - get_val('services rural water tanks discharger')
            )
        # =====================================================================
        ### RESIDENTIAL RURAL HEAT
        elif current_heat_load == 'residential rural heat':
        # =====================================================================
            net_balance = (
                get_val('residential rural heat')
                - get_val('residential rural biomass boiler')
                - get_val('residential rural solar thermal collector')
                - get_val('residential rural oil boiler')
                - get_val('residential rural heat load')
                - get_val('residential rural gas boiler')
                + get_val('residential rural water tanks charger')
                - get_val('residential rural water tanks discharger')
            )
        # =====================================================================
        ### RESIDENTIAL URBAN DECENTRAL HEAT
        elif current_heat_load == 'residential urban decentral heat':
        # =====================================================================
            net_balance = (
                get_val('residential urban decentral heat')
                - get_val('residential urban decentral gas boiler')
                - get_val('residential urban decentral solar thermal collector')
                - get_val('residential urban decentral oil boiler')
                - get_val('residential urban decentral heat load')
                - get_val('residential urban decentral biomass boiler')
                + get_val('residential urban decentral water tanks charger')
                - get_val('residential urban decentral water tanks discharger')
            )
        # =====================================================================
        else:
            net_balance = None
        ### Add calculated balance to the EXISTING dataframe
        if net_balance is not None:
            df['net_heat_balance'] = net_balance
            print(
                f"  [{current_heat_load}] "
                f"Successfully appended 'net_heat_balance'."
            )
### COMPLETION MESSAGE
print(
    "\nAll custom equation calculations are complete!"
)
### CHECK DICTIONARY STRUCTURE
for country, loads in country_loads_time_series.items():
    print(
        f"\nCountry: {country}"
    )
    print(
        f"Dictionary type: {type(loads)}"
    )
    for load_name, df in loads.items():
        print(
            f"  Load: {load_name}"
        )
        print(
            f"  Type: {type(df)}"
        )
        print(
            f"  Rows: {len(df):,}"
        )
        print(
            f"  Columns: {len(df.columns):,}"
        )
        print(
            f"  Columns: {df.columns.tolist()}"
        )
# Out:
# --- Calculating Energy Balances for Country: BE ---
#   [urban central heat] Successfully appended 'net_heat_balance'.
#   [services urban decentral heat] Successfully appended 'net_heat_balance'.
#   [services rural heat] Successfully appended 'net_heat_balance'.
#   [residential rural heat] Successfully appended 'net_heat_balance'.
#   [residential urban decentral heat] Successfully appended 'net_heat_balance'.
#
# --- Calculating Energy Balances for Country: FR ---
#   [urban central heat] Successfully appended 'net_heat_balance'.
#   [services urban decentral heat] Successfully appended 'net_heat_balance'.
#   [services rural heat] Successfully appended 'net_heat_balance'.
#   [residential rural heat] Successfully appended 'net_heat_balance'.
#   [residential urban decentral heat] Successfully appended 'net_heat_balance'.
#
# --- Calculating Energy Balances for Country: DE ---
#   [urban central heat] Successfully appended 'net_heat_balance'.
#   [services urban decentral heat] Successfully appended 'net_heat_balance'.
#   [services rural heat] Successfully appended 'net_heat_balance'.
#   [residential rural heat] Successfully appended 'net_heat_balance'.
#   [residential urban decentral heat] Successfully appended 'net_heat_balance'.
#
# --- Calculating Energy Balances for Country: NL ---
#   [urban central heat] Successfully appended 'net_heat_balance'.
#   [services urban decentral heat] Successfully appended 'net_heat_balance'.
#   [services rural heat] Successfully appended 'net_heat_balance'.
#   [residential rural heat] Successfully appended 'net_heat_balance'.
#   [residential urban decentral heat] Successfully appended 'net_heat_balance'.
#
# --- Calculating Energy Balances for Country: UK ---
#   [urban central heat] Successfully appended 'net_heat_balance'.
#   [services urban decentral heat] Successfully appended 'net_heat_balance'.
#   [services rural heat] Successfully appended 'net_heat_balance'.
#   [residential rural heat] Successfully appended 'net_heat_balance'.
#   [residential urban decentral heat] Successfully appended 'net_heat_balance'.
#
# All custom equation calculations are complete!
#
# Country: BE
# Dictionary type: <class 'dict'>
#   Load: urban central heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 9
#   Columns: ['BE1 0 urban central heat', 'BE1 0 low-temperature heat for industry', 'BE1 0 urban central solar thermal collector-2030', 'BE1 0 urban central heat load', 'BE1 0 urban central water tanks charger', 'BE1 0 urban central water tanks discharger', 'BE1 0 urban central gas boiler-2030', 'BE1 0 Fischer-Tropsch-2030', 'net_heat_balance']
#   Load: services urban decentral heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 12
#   Columns: ['BE1 0 services urban decentral heat', 'BE1 0 services urban decentral solar thermal collector-2030', 'BE1 0 services urban decentral heat load', 'BE1 0 services urban decentral water tanks charger', 'BE1 0 services urban decentral water tanks discharger', 'BE1 0 services urban decentral gas boiler-2030', 'BE1 0 services urban decentral biomass boiler-2030', 'BE1 0 services urban decentral gas boiler-2015', 'BE1 0 services urban decentral oil boiler-2015', 'BE1 0 services urban decentral gas boiler-2019', 'BE1 0 services urban decentral oil boiler-2019', 'net_heat_balance']
#   Load: services rural heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 13
#   Columns: ['BE1 0 services rural heat', 'BE1 0 agriculture heat', 'BE1 0 services rural solar thermal collector-2030', 'BE1 0 services rural heat load', 'BE1 0 services rural water tanks charger', 'BE1 0 services rural water tanks discharger', 'BE1 0 services rural gas boiler-2030', 'BE1 0 services rural biomass boiler-2030', 'BE1 0 services rural gas boiler-2015', 'BE1 0 services rural oil boiler-2015', 'BE1 0 services rural gas boiler-2019', 'BE1 0 services rural oil boiler-2019', 'net_heat_balance']
#   Load: residential rural heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 12
#   Columns: ['BE1 0 residential rural heat', 'BE1 0 residential rural solar thermal collector-2030', 'BE1 0 residential rural heat load', 'BE1 0 residential rural water tanks charger', 'BE1 0 residential rural water tanks discharger', 'BE1 0 residential rural gas boiler-2030', 'BE1 0 residential rural biomass boiler-2030', 'BE1 0 residential rural gas boiler-2015', 'BE1 0 residential rural oil boiler-2015', 'BE1 0 residential rural gas boiler-2019', 'BE1 0 residential rural oil boiler-2019', 'net_heat_balance']
#   Load: residential urban decentral heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 12
#   Columns: ['BE1 0 residential urban decentral heat', 'BE1 0 residential urban decentral solar thermal collector-2030', 'BE1 0 residential urban decentral heat load', 'BE1 0 residential urban decentral water tanks charger', 'BE1 0 residential urban decentral water tanks discharger', 'BE1 0 residential urban decentral gas boiler-2030', 'BE1 0 residential urban decentral biomass boiler-2030', 'BE1 0 residential urban decentral gas boiler-2015', 'BE1 0 residential urban decentral oil boiler-2015', 'BE1 0 residential urban decentral gas boiler-2019', 'BE1 0 residential urban decentral oil boiler-2019', 'net_heat_balance']
#
# Country: FR
# Dictionary type: <class 'dict'>
#   Load: urban central heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 9
#   Columns: ['FR1 0 urban central heat', 'FR1 0 low-temperature heat for industry', 'FR1 0 urban central solar thermal collector-2030', 'FR1 0 urban central heat load', 'FR1 0 urban central water tanks charger', 'FR1 0 urban central water tanks discharger', 'FR1 0 urban central gas boiler-2030', 'FR1 0 Fischer-Tropsch-2030', 'net_heat_balance']
#   Load: services urban decentral heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 12
#   Columns: ['FR1 0 services urban decentral heat', 'FR1 0 services urban decentral solar thermal collector-2030', 'FR1 0 services urban decentral heat load', 'FR1 0 services urban decentral water tanks charger', 'FR1 0 services urban decentral water tanks discharger', 'FR1 0 services urban decentral gas boiler-2030', 'FR1 0 services urban decentral biomass boiler-2030', 'FR1 0 services urban decentral gas boiler-2015', 'FR1 0 services urban decentral oil boiler-2015', 'FR1 0 services urban decentral gas boiler-2019', 'FR1 0 services urban decentral oil boiler-2019', 'net_heat_balance']
#   Load: services rural heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 13
#   Columns: ['FR1 0 services rural heat', 'FR1 0 agriculture heat', 'FR1 0 services rural solar thermal collector-2030', 'FR1 0 services rural heat load', 'FR1 0 services rural water tanks charger', 'FR1 0 services rural water tanks discharger', 'FR1 0 services rural gas boiler-2030', 'FR1 0 services rural biomass boiler-2030', 'FR1 0 services rural gas boiler-2015', 'FR1 0 services rural oil boiler-2015', 'FR1 0 services rural gas boiler-2019', 'FR1 0 services rural oil boiler-2019', 'net_heat_balance']
#   Load: residential rural heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 12
#   Columns: ['FR1 0 residential rural heat', 'FR1 0 residential rural solar thermal collector-2030', 'FR1 0 residential rural heat load', 'FR1 0 residential rural water tanks charger', 'FR1 0 residential rural water tanks discharger', 'FR1 0 residential rural gas boiler-2030', 'FR1 0 residential rural biomass boiler-2030', 'FR1 0 residential rural gas boiler-2015', 'FR1 0 residential rural oil boiler-2015', 'FR1 0 residential rural gas boiler-2019', 'FR1 0 residential rural oil boiler-2019', 'net_heat_balance']
#   Load: residential urban decentral heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 12
#   Columns: ['FR1 0 residential urban decentral heat', 'FR1 0 residential urban decentral solar thermal collector-2030', 'FR1 0 residential urban decentral heat load', 'FR1 0 residential urban decentral water tanks charger', 'FR1 0 residential urban decentral water tanks discharger', 'FR1 0 residential urban decentral gas boiler-2030', 'FR1 0 residential urban decentral biomass boiler-2030', 'FR1 0 residential urban decentral gas boiler-2015', 'FR1 0 residential urban decentral oil boiler-2015', 'FR1 0 residential urban decentral gas boiler-2019', 'FR1 0 residential urban decentral oil boiler-2019', 'net_heat_balance']
#
# Country: DE
# Dictionary type: <class 'dict'>
#   Load: urban central heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 9
#   Columns: ['DE1 0 urban central heat', 'DE1 0 low-temperature heat for industry', 'DE1 0 urban central solar thermal collector-2030', 'DE1 0 urban central heat load', 'DE1 0 urban central water tanks charger', 'DE1 0 urban central water tanks discharger', 'DE1 0 urban central gas boiler-2030', 'DE1 0 Fischer-Tropsch-2030', 'net_heat_balance']
#   Load: services urban decentral heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 12
#   Columns: ['DE1 0 services urban decentral heat', 'DE1 0 services urban decentral solar thermal collector-2030', 'DE1 0 services urban decentral heat load', 'DE1 0 services urban decentral water tanks charger', 'DE1 0 services urban decentral water tanks discharger', 'DE1 0 services urban decentral gas boiler-2030', 'DE1 0 services urban decentral biomass boiler-2030', 'DE1 0 services urban decentral gas boiler-2015', 'DE1 0 services urban decentral oil boiler-2015', 'DE1 0 services urban decentral gas boiler-2019', 'DE1 0 services urban decentral oil boiler-2019', 'net_heat_balance']
#   Load: services rural heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 13
#   Columns: ['DE1 0 services rural heat', 'DE1 0 agriculture heat', 'DE1 0 services rural solar thermal collector-2030', 'DE1 0 services rural heat load', 'DE1 0 services rural water tanks charger', 'DE1 0 services rural water tanks discharger', 'DE1 0 services rural gas boiler-2030', 'DE1 0 services rural biomass boiler-2030', 'DE1 0 services rural gas boiler-2015', 'DE1 0 services rural oil boiler-2015', 'DE1 0 services rural gas boiler-2019', 'DE1 0 services rural oil boiler-2019', 'net_heat_balance']
#   Load: residential rural heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 12
#   Columns: ['DE1 0 residential rural heat', 'DE1 0 residential rural solar thermal collector-2030', 'DE1 0 residential rural heat load', 'DE1 0 residential rural water tanks charger', 'DE1 0 residential rural water tanks discharger', 'DE1 0 residential rural gas boiler-2030', 'DE1 0 residential rural biomass boiler-2030', 'DE1 0 residential rural gas boiler-2015', 'DE1 0 residential rural oil boiler-2015', 'DE1 0 residential rural gas boiler-2019', 'DE1 0 residential rural oil boiler-2019', 'net_heat_balance']
#   Load: residential urban decentral heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 12
#   Columns: ['DE1 0 residential urban decentral heat', 'DE1 0 residential urban decentral solar thermal collector-2030', 'DE1 0 residential urban decentral heat load', 'DE1 0 residential urban decentral water tanks charger', 'DE1 0 residential urban decentral water tanks discharger', 'DE1 0 residential urban decentral gas boiler-2030', 'DE1 0 residential urban decentral biomass boiler-2030', 'DE1 0 residential urban decentral gas boiler-2015', 'DE1 0 residential urban decentral oil boiler-2015', 'DE1 0 residential urban decentral gas boiler-2019', 'DE1 0 residential urban decentral oil boiler-2019', 'net_heat_balance']
#
# Country: NL
# Dictionary type: <class 'dict'>
#   Load: urban central heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 9
#   Columns: ['NL1 0 urban central heat', 'NL1 0 low-temperature heat for industry', 'NL1 0 urban central solar thermal collector-2030', 'NL1 0 urban central heat load', 'NL1 0 urban central water tanks charger', 'NL1 0 urban central water tanks discharger', 'NL1 0 urban central gas boiler-2030', 'NL1 0 Fischer-Tropsch-2030', 'net_heat_balance']
#   Load: services urban decentral heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 10
#   Columns: ['NL1 0 services urban decentral heat', 'NL1 0 services urban decentral solar thermal collector-2030', 'NL1 0 services urban decentral heat load', 'NL1 0 services urban decentral water tanks charger', 'NL1 0 services urban decentral water tanks discharger', 'NL1 0 services urban decentral gas boiler-2030', 'NL1 0 services urban decentral biomass boiler-2030', 'NL1 0 services urban decentral gas boiler-2015', 'NL1 0 services urban decentral gas boiler-2019', 'net_heat_balance']
#   Load: services rural heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 11
#   Columns: ['NL1 0 services rural heat', 'NL1 0 agriculture heat', 'NL1 0 services rural solar thermal collector-2030', 'NL1 0 services rural heat load', 'NL1 0 services rural water tanks charger', 'NL1 0 services rural water tanks discharger', 'NL1 0 services rural gas boiler-2030', 'NL1 0 services rural biomass boiler-2030', 'NL1 0 services rural gas boiler-2015', 'NL1 0 services rural gas boiler-2019', 'net_heat_balance']
#   Load: residential rural heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 10
#   Columns: ['NL1 0 residential rural heat', 'NL1 0 residential rural solar thermal collector-2030', 'NL1 0 residential rural heat load', 'NL1 0 residential rural water tanks charger', 'NL1 0 residential rural water tanks discharger', 'NL1 0 residential rural gas boiler-2030', 'NL1 0 residential rural biomass boiler-2030', 'NL1 0 residential rural gas boiler-2015', 'NL1 0 residential rural gas boiler-2019', 'net_heat_balance']
#   Load: residential urban decentral heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 12
#   Columns: ['NL1 0 residential urban decentral heat', 'NL1 0 residential urban decentral solar thermal collector-2030', 'NL1 0 residential urban decentral heat load', 'NL1 0 residential urban decentral water tanks charger', 'NL1 0 residential urban decentral water tanks discharger', 'NL1 0 residential urban decentral gas boiler-2030', 'NL1 0 residential urban decentral biomass boiler-2030', 'NL1 0 residential urban decentral gas boiler-2015', 'NL1 0 residential urban decentral oil boiler-2015', 'NL1 0 residential urban decentral gas boiler-2019', 'NL1 0 residential urban decentral oil boiler-2019', 'net_heat_balance']
#
# Country: UK
# Dictionary type: <class 'dict'>
#   Load: urban central heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 17
#   Columns: ['GB0 0 urban central heat', 'GB2 0 urban central heat', 'GB0 0 low-temperature heat for industry', 'GB2 0 low-temperature heat for industry', 'GB0 0 urban central solar thermal collector-2030', 'GB2 0 urban central solar thermal collector-2030', 'GB0 0 urban central heat load', 'GB2 0 urban central heat load', 'GB0 0 urban central water tanks charger', 'GB2 0 urban central water tanks charger', 'GB0 0 urban central water tanks discharger', 'GB2 0 urban central water tanks discharger', 'GB0 0 urban central gas boiler-2030', 'GB2 0 urban central gas boiler-2030', 'GB0 0 Fischer-Tropsch-2030', 'GB2 0 Fischer-Tropsch-2030', 'net_heat_balance']
#   Load: services urban decentral heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 21
#   Columns: ['GB0 0 services urban decentral heat', 'GB2 0 services urban decentral heat', 'GB0 0 services urban decentral solar thermal collector-2030', 'GB2 0 services urban decentral solar thermal collector-2030', 'GB0 0 services urban decentral heat load', 'GB2 0 services urban decentral heat load', 'GB0 0 services urban decentral water tanks charger', 'GB2 0 services urban decentral water tanks charger', 'GB0 0 services urban decentral water tanks discharger', 'GB2 0 services urban decentral water tanks discharger', 'GB0 0 services urban decentral gas boiler-2030', 'GB2 0 services urban decentral gas boiler-2030', 'GB0 0 services urban decentral biomass boiler-2030', 'GB2 0 services urban decentral biomass boiler-2030', 'GB0 0 services urban decentral gas boiler-2015', 'GB2 0 services urban decentral gas boiler-2015', 'GB0 0 services urban decentral oil boiler-2015', 'GB0 0 services urban decentral gas boiler-2019', 'GB2 0 services urban decentral gas boiler-2019', 'GB0 0 services urban decentral oil boiler-2019', 'net_heat_balance']
#   Load: services rural heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 23
#   Columns: ['GB0 0 services rural heat', 'GB2 0 services rural heat', 'GB0 0 agriculture heat', 'GB2 0 agriculture heat', 'GB0 0 services rural solar thermal collector-2030', 'GB2 0 services rural solar thermal collector-2030', 'GB0 0 services rural heat load', 'GB2 0 services rural heat load', 'GB0 0 services rural water tanks charger', 'GB2 0 services rural water tanks charger', 'GB0 0 services rural water tanks discharger', 'GB2 0 services rural water tanks discharger', 'GB0 0 services rural gas boiler-2030', 'GB2 0 services rural gas boiler-2030', 'GB0 0 services rural biomass boiler-2030', 'GB2 0 services rural biomass boiler-2030', 'GB0 0 services rural gas boiler-2015', 'GB2 0 services rural gas boiler-2015', 'GB0 0 services rural oil boiler-2015', 'GB0 0 services rural gas boiler-2019', 'GB2 0 services rural gas boiler-2019', 'GB0 0 services rural oil boiler-2019', 'net_heat_balance']
#   Load: residential rural heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 23
#   Columns: ['GB0 0 residential rural heat', 'GB2 0 residential rural heat', 'GB0 0 residential rural solar thermal collector-2030', 'GB2 0 residential rural solar thermal collector-2030', 'GB0 0 residential rural heat load', 'GB2 0 residential rural heat load', 'GB0 0 residential rural water tanks charger', 'GB2 0 residential rural water tanks charger', 'GB0 0 residential rural water tanks discharger', 'GB2 0 residential rural water tanks discharger', 'GB0 0 residential rural gas boiler-2030', 'GB2 0 residential rural gas boiler-2030', 'GB0 0 residential rural biomass boiler-2030', 'GB2 0 residential rural biomass boiler-2030', 'GB0 0 residential rural gas boiler-2015', 'GB2 0 residential rural gas boiler-2015', 'GB0 0 residential rural oil boiler-2015', 'GB2 0 residential rural oil boiler-2015', 'GB0 0 residential rural gas boiler-2019', 'GB2 0 residential rural gas boiler-2019', 'GB0 0 residential rural oil boiler-2019', 'GB2 0 residential rural oil boiler-2019', 'net_heat_balance']
#   Load: residential urban decentral heat
#   Type: <class 'pandas.core.frame.DataFrame'>
#   Rows: 8,760
#   Columns: 23
#   Columns: ['GB0 0 residential urban decentral heat', 'GB2 0 residential urban decentral heat', 'GB0 0 residential urban decentral solar thermal collector-2030', 'GB2 0 residential urban decentral solar thermal collector-2030', 'GB0 0 residential urban decentral heat load', 'GB2 0 residential urban decentral heat load', 'GB0 0 residential urban decentral water tanks charger', 'GB2 0 residential urban decentral water tanks charger', 'GB0 0 residential urban decentral water tanks discharger', 'GB2 0 residential urban decentral water tanks discharger', 'GB0 0 residential urban decentral gas boiler-2030', 'GB2 0 residential urban decentral gas boiler-2030', 'GB0 0 residential urban decentral biomass boiler-2030', 'GB2 0 residential urban decentral biomass boiler-2030', 'GB0 0 residential urban decentral gas boiler-2015', 'GB2 0 residential urban decentral gas boiler-2015', 'GB0 0 residential urban decentral oil boiler-2015', 'GB2 0 residential urban decentral oil boiler-2015', 'GB0 0 residential urban decentral gas boiler-2019', 'GB2 0 residential urban decentral gas boiler-2019', 'GB0 0 residential urban decentral oil boiler-2019', 'GB2 0 residential urban decentral oil boiler-2019', 'net_heat_balance']

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         D-08. Allocating Net Heat Balances Using Fractions from Power-Plant CSV
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process allocates the <b>net heat balance</b> (net_heat_balance) across individual power-plant assets using their <b>fractional contributions</b> from the PyPSA power-plant CSV files. Each asset receives a proportional share of the net heat balance based on its fraction value.<br>
#     <b>Allocation Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each country and heat load category, the script loads the power-plant DataFrame and checks for the existence of the fraction column (e.g., <b>urban central heat_fraction</b>). It then selects assets with a positive fraction and creates a new column for each asset: <b>{asset_name}_proportion</b> = net_heat_balance × fraction_value. These allocated columns are appended to the existing time-series DataFrame.
#         </div>
#     </div>
# </div>

# %%
### ALLOCATE NET HEAT BALANCES USING FRACTIONS FROM PYPSA POWER-PLANT CSV FILES
for country in zone_names:
    print(f"\n--- Allocating Net Balances via Fractions for Country: {country} ---")
    ### Build the path to the country's power-plant CSV
    power_plants_file = os.path.join(
        pypsa_raw_data_folder_path,
        pypsa_scenario,
        "PowerPlants",
        data_target_year,
        country,
        f"pypsa_power_plants_{country}_{data_target_year}.csv"
    )
    print(f"  Loading power-plant data:")
    print(f"  {power_plants_file}")
    ### Load the country's power-plant dataframe
    master_df = pd.read_csv(power_plants_file)
    ### Use 'name' as the asset identifier
    master_df = master_df.set_index("name")
    ### Process every heat-load category
    for current_heat_load in all_heat_loads:
        ### Example:
        ### 'urban central heat' ->
        ### 'urban central heat_fraction'
        fraction_col = f"{current_heat_load}_fraction"
        ### Check whether the fraction column exists
        if fraction_col not in master_df.columns:
            print(
                f"  [{current_heat_load}] "
                f"Fraction column '{fraction_col}' not found. Skipping."
            )
            continue
        ### Retrieve the existing time-series dataframe
        ts_df = country_loads_time_series[country][current_heat_load]
        ### Check whether net_heat_balance exists
        if ts_df.empty or "net_heat_balance" not in ts_df.columns:
            print(
                f"  [{current_heat_load}] "
                f"'net_heat_balance' not available. Skipping."
            )
            continue
        ### Select assets with a positive fraction
        active_assets = master_df[
            master_df[fraction_col] > 0
        ]
        allocated_columns = {}
        ### Allocate the net heat balance to each active asset
        for asset_name, row in active_assets.iterrows():
            fraction_value = float(row[fraction_col])
            ### New column name
            new_column_header = f"{asset_name}_proportion"
            ### Apply the fraction to the net heat balance
            allocated_columns[new_column_header] = (
                ts_df["net_heat_balance"] * fraction_value
            )
        ### Append the allocated profiles to the existing dataframe
        if allocated_columns:
            allocated_df = pd.DataFrame(
                allocated_columns,
                index=ts_df.index
            )
            country_loads_time_series[country][current_heat_load] = pd.concat(
                [
                    ts_df,
                    allocated_df
                ],
                axis=1
            )
            print(
                f"  [{current_heat_load}] "
                f"Distributed net balance across "
                f"{len(allocated_columns)} assets."
            )
### SUMMARY
print("\nAll fractional asset proportion columns successfully generated!")
for country, loads in country_loads_time_series.items():
    print(country, type(loads))
    for load_name, df in loads.items():
        print(
            "  ",
            load_name,
            type(df)
        )
for country, loads in country_loads_time_series.items():
    print(f"\nCountry: {country}")
    for load_name, df in loads.items():
        print(f"  Load: {load_name}")
        print(f"  Columns: {df.columns.tolist()}")
# Out:
# --- Allocating Net Balances via Fractions for Country: BE ---
#   Loading power-plant data:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/BE/pypsa_power_plants_BE_2030.csv
#   [urban central heat] Distributed net balance across 5 assets.
#   [services urban decentral heat] Distributed net balance across 4 assets.
#   [services rural heat] Distributed net balance across 3 assets.
#   [residential rural heat] Distributed net balance across 5 assets.
#   [residential urban decentral heat] Distributed net balance across 4 assets.
#
# --- Allocating Net Balances via Fractions for Country: FR ---
#   Loading power-plant data:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/FR/pypsa_power_plants_FR_2030.csv
#   [urban central heat] Distributed net balance across 5 assets.
#   [services urban decentral heat] Distributed net balance across 6 assets.
#   [services rural heat] Distributed net balance across 7 assets.
#   [residential rural heat] Distributed net balance across 7 assets.
#   [residential urban decentral heat] Distributed net balance across 6 assets.
#
# --- Allocating Net Balances via Fractions for Country: DE ---
#   Loading power-plant data:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/DE/pypsa_power_plants_DE_2030.csv
#   [urban central heat] Distributed net balance across 5 assets.
#   [services urban decentral heat] Distributed net balance across 4 assets.
#   [services rural heat] Distributed net balance across 5 assets.
#   [residential rural heat] Distributed net balance across 5 assets.
#   [residential urban decentral heat] Distributed net balance across 4 assets.
#
# --- Allocating Net Balances via Fractions for Country: NL ---
#   Loading power-plant data:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/NL/pypsa_power_plants_NL_2030.csv
#   [urban central heat] Distributed net balance across 5 assets.
#   [services urban decentral heat] Distributed net balance across 4 assets.
#   [services rural heat] Distributed net balance across 5 assets.
#   [residential rural heat] Distributed net balance across 5 assets.
#   [residential urban decentral heat] Distributed net balance across 6 assets.
#
# --- Allocating Net Balances via Fractions for Country: UK ---
#   Loading power-plant data:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/UK/pypsa_power_plants_UK_2030.csv
#   [urban central heat] Distributed net balance across 10 assets.
#   [services urban decentral heat] Distributed net balance across 7 assets.
#   [services rural heat] Distributed net balance across 10 assets.
#   [residential rural heat] Distributed net balance across 11 assets.
#   [residential urban decentral heat] Distributed net balance across 10 assets.
#
# All fractional asset proportion columns successfully generated!
# BE <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
# FR <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
# DE <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
# NL <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
# UK <class 'dict'>
#    urban central heat <class 'pandas.core.frame.DataFrame'>
#    services urban decentral heat <class 'pandas.core.frame.DataFrame'>
#    services rural heat <class 'pandas.core.frame.DataFrame'>
#    residential rural heat <class 'pandas.core.frame.DataFrame'>
#    residential urban decentral heat <class 'pandas.core.frame.DataFrame'>
#
# Country: BE
#   Load: urban central heat
#   Columns: ['BE1 0 urban central heat', 'BE1 0 low-temperature heat for industry', 'BE1 0 urban central solar thermal collector-2030', 'BE1 0 urban central heat load', 'BE1 0 urban central water tanks charger', 'BE1 0 urban central water tanks discharger', 'BE1 0 urban central gas boiler-2030', 'BE1 0 Fischer-Tropsch-2030', 'net_heat_balance', 'BE1 0 H2 Fuel Cell-2030_proportion', 'BE1 0 urban central air heat pump-2030_proportion', 'BE1 0 urban central resistive heater-2030_proportion', 'BE1 0 urban central gas CHP-2030_proportion', 'BE1 0 urban central solid biomass CHP-2030_proportion']
#   Load: services urban decentral heat
#   Columns: ['BE1 0 services urban decentral heat', 'BE1 0 services urban decentral solar thermal collector-2030', 'BE1 0 services urban decentral heat load', 'BE1 0 services urban decentral water tanks charger', 'BE1 0 services urban decentral water tanks discharger', 'BE1 0 services urban decentral gas boiler-2030', 'BE1 0 services urban decentral biomass boiler-2030', 'BE1 0 services urban decentral gas boiler-2015', 'BE1 0 services urban decentral oil boiler-2015', 'BE1 0 services urban decentral gas boiler-2019', 'BE1 0 services urban decentral oil boiler-2019', 'net_heat_balance', 'BE1 0 services urban decentral air heat pump-2030_proportion', 'BE1 0 services urban decentral resistive heater-2030_proportion', 'BE1 0 services urban decentral resistive heater-2015_proportion', 'BE1 0 services urban decentral resistive heater-2019_proportion']
#   Load: services rural heat
#   Columns: ['BE1 0 services rural heat', 'BE1 0 agriculture heat', 'BE1 0 services rural solar thermal collector-2030', 'BE1 0 services rural heat load', 'BE1 0 services rural water tanks charger', 'BE1 0 services rural water tanks discharger', 'BE1 0 services rural gas boiler-2030', 'BE1 0 services rural biomass boiler-2030', 'BE1 0 services rural gas boiler-2015', 'BE1 0 services rural oil boiler-2015', 'BE1 0 services rural gas boiler-2019', 'BE1 0 services rural oil boiler-2019', 'net_heat_balance', 'BE1 0 services rural ground heat pump-2030_proportion', 'BE1 0 services rural air heat pump-2030_proportion', 'BE1 0 services rural resistive heater-2030_proportion']
#   Load: residential rural heat
#   Columns: ['BE1 0 residential rural heat', 'BE1 0 residential rural solar thermal collector-2030', 'BE1 0 residential rural heat load', 'BE1 0 residential rural water tanks charger', 'BE1 0 residential rural water tanks discharger', 'BE1 0 residential rural gas boiler-2030', 'BE1 0 residential rural biomass boiler-2030', 'BE1 0 residential rural gas boiler-2015', 'BE1 0 residential rural oil boiler-2015', 'BE1 0 residential rural gas boiler-2019', 'BE1 0 residential rural oil boiler-2019', 'net_heat_balance', 'BE1 0 residential rural ground heat pump-2030_proportion', 'BE1 0 residential rural air heat pump-2030_proportion', 'BE1 0 residential rural resistive heater-2030_proportion', 'BE1 0 residential rural resistive heater-2015_proportion', 'BE1 0 residential rural resistive heater-2019_proportion']
#   Load: residential urban decentral heat
#   Columns: ['BE1 0 residential urban decentral heat', 'BE1 0 residential urban decentral solar thermal collector-2030', 'BE1 0 residential urban decentral heat load', 'BE1 0 residential urban decentral water tanks charger', 'BE1 0 residential urban decentral water tanks discharger', 'BE1 0 residential urban decentral gas boiler-2030', 'BE1 0 residential urban decentral biomass boiler-2030', 'BE1 0 residential urban decentral gas boiler-2015', 'BE1 0 residential urban decentral oil boiler-2015', 'BE1 0 residential urban decentral gas boiler-2019', 'BE1 0 residential urban decentral oil boiler-2019', 'net_heat_balance', 'BE1 0 residential urban decentral air heat pump-2030_proportion', 'BE1 0 residential urban decentral resistive heater-2030_proportion', 'BE1 0 residential urban decentral resistive heater-2015_proportion', 'BE1 0 residential urban decentral resistive heater-2019_proportion']
#
# Country: FR
#   Load: urban central heat
#   Columns: ['FR1 0 urban central heat', 'FR1 0 low-temperature heat for industry', 'FR1 0 urban central solar thermal collector-2030', 'FR1 0 urban central heat load', 'FR1 0 urban central water tanks charger', 'FR1 0 urban central water tanks discharger', 'FR1 0 urban central gas boiler-2030', 'FR1 0 Fischer-Tropsch-2030', 'net_heat_balance', 'FR1 0 H2 Fuel Cell-2030_proportion', 'FR1 0 urban central air heat pump-2030_proportion', 'FR1 0 urban central resistive heater-2030_proportion', 'FR1 0 urban central gas CHP-2030_proportion', 'FR1 0 urban central solid biomass CHP-2030_proportion']
#   Load: services urban decentral heat
#   Columns: ['FR1 0 services urban decentral heat', 'FR1 0 services urban decentral solar thermal collector-2030', 'FR1 0 services urban decentral heat load', 'FR1 0 services urban decentral water tanks charger', 'FR1 0 services urban decentral water tanks discharger', 'FR1 0 services urban decentral gas boiler-2030', 'FR1 0 services urban decentral biomass boiler-2030', 'FR1 0 services urban decentral gas boiler-2015', 'FR1 0 services urban decentral oil boiler-2015', 'FR1 0 services urban decentral gas boiler-2019', 'FR1 0 services urban decentral oil boiler-2019', 'net_heat_balance', 'FR1 0 services urban decentral air heat pump-2030_proportion', 'FR1 0 services urban decentral resistive heater-2030_proportion', 'FR1 0 services urban decentral air heat pump-2015_proportion', 'FR1 0 services urban decentral resistive heater-2015_proportion', 'FR1 0 services urban decentral air heat pump-2019_proportion', 'FR1 0 services urban decentral resistive heater-2019_proportion']
#   Load: services rural heat
#   Columns: ['FR1 0 services rural heat', 'FR1 0 agriculture heat', 'FR1 0 services rural solar thermal collector-2030', 'FR1 0 services rural heat load', 'FR1 0 services rural water tanks charger', 'FR1 0 services rural water tanks discharger', 'FR1 0 services rural gas boiler-2030', 'FR1 0 services rural biomass boiler-2030', 'FR1 0 services rural gas boiler-2015', 'FR1 0 services rural oil boiler-2015', 'FR1 0 services rural gas boiler-2019', 'FR1 0 services rural oil boiler-2019', 'net_heat_balance', 'FR1 0 services rural ground heat pump-2030_proportion', 'FR1 0 services rural air heat pump-2030_proportion', 'FR1 0 services rural resistive heater-2030_proportion', 'FR1 0 services rural ground heat pump-2015_proportion', 'FR1 0 services rural resistive heater-2015_proportion', 'FR1 0 services rural ground heat pump-2019_proportion', 'FR1 0 services rural resistive heater-2019_proportion']
#   Load: residential rural heat
#   Columns: ['FR1 0 residential rural heat', 'FR1 0 residential rural solar thermal collector-2030', 'FR1 0 residential rural heat load', 'FR1 0 residential rural water tanks charger', 'FR1 0 residential rural water tanks discharger', 'FR1 0 residential rural gas boiler-2030', 'FR1 0 residential rural biomass boiler-2030', 'FR1 0 residential rural gas boiler-2015', 'FR1 0 residential rural oil boiler-2015', 'FR1 0 residential rural gas boiler-2019', 'FR1 0 residential rural oil boiler-2019', 'net_heat_balance', 'FR1 0 residential rural ground heat pump-2030_proportion', 'FR1 0 residential rural air heat pump-2030_proportion', 'FR1 0 residential rural resistive heater-2030_proportion', 'FR1 0 residential rural ground heat pump-2015_proportion', 'FR1 0 residential rural resistive heater-2015_proportion', 'FR1 0 residential rural ground heat pump-2019_proportion', 'FR1 0 residential rural resistive heater-2019_proportion']
#   Load: residential urban decentral heat
#   Columns: ['FR1 0 residential urban decentral heat', 'FR1 0 residential urban decentral solar thermal collector-2030', 'FR1 0 residential urban decentral heat load', 'FR1 0 residential urban decentral water tanks charger', 'FR1 0 residential urban decentral water tanks discharger', 'FR1 0 residential urban decentral gas boiler-2030', 'FR1 0 residential urban decentral biomass boiler-2030', 'FR1 0 residential urban decentral gas boiler-2015', 'FR1 0 residential urban decentral oil boiler-2015', 'FR1 0 residential urban decentral gas boiler-2019', 'FR1 0 residential urban decentral oil boiler-2019', 'net_heat_balance', 'FR1 0 residential urban decentral air heat pump-2030_proportion', 'FR1 0 residential urban decentral resistive heater-2030_proportion', 'FR1 0 residential urban decentral air heat pump-2015_proportion', 'FR1 0 residential urban decentral resistive heater-2015_proportion', 'FR1 0 residential urban decentral air heat pump-2019_proportion', 'FR1 0 residential urban decentral resistive heater-2019_proportion']
#
# Country: DE
#   Load: urban central heat
#   Columns: ['DE1 0 urban central heat', 'DE1 0 low-temperature heat for industry', 'DE1 0 urban central solar thermal collector-2030', 'DE1 0 urban central heat load', 'DE1 0 urban central water tanks charger', 'DE1 0 urban central water tanks discharger', 'DE1 0 urban central gas boiler-2030', 'DE1 0 Fischer-Tropsch-2030', 'net_heat_balance', 'DE1 0 H2 Fuel Cell-2030_proportion', 'DE1 0 urban central air heat pump-2030_proportion', 'DE1 0 urban central resistive heater-2030_proportion', 'DE1 0 urban central gas CHP-2030_proportion', 'DE1 0 urban central solid biomass CHP-2030_proportion']
#   Load: services urban decentral heat
#   Columns: ['DE1 0 services urban decentral heat', 'DE1 0 services urban decentral solar thermal collector-2030', 'DE1 0 services urban decentral heat load', 'DE1 0 services urban decentral water tanks charger', 'DE1 0 services urban decentral water tanks discharger', 'DE1 0 services urban decentral gas boiler-2030', 'DE1 0 services urban decentral biomass boiler-2030', 'DE1 0 services urban decentral gas boiler-2015', 'DE1 0 services urban decentral oil boiler-2015', 'DE1 0 services urban decentral gas boiler-2019', 'DE1 0 services urban decentral oil boiler-2019', 'net_heat_balance', 'DE1 0 services urban decentral air heat pump-2030_proportion', 'DE1 0 services urban decentral resistive heater-2030_proportion', 'DE1 0 services urban decentral air heat pump-2015_proportion', 'DE1 0 services urban decentral air heat pump-2019_proportion']
#   Load: services rural heat
#   Columns: ['DE1 0 services rural heat', 'DE1 0 agriculture heat', 'DE1 0 services rural solar thermal collector-2030', 'DE1 0 services rural heat load', 'DE1 0 services rural water tanks charger', 'DE1 0 services rural water tanks discharger', 'DE1 0 services rural gas boiler-2030', 'DE1 0 services rural biomass boiler-2030', 'DE1 0 services rural gas boiler-2015', 'DE1 0 services rural oil boiler-2015', 'DE1 0 services rural gas boiler-2019', 'DE1 0 services rural oil boiler-2019', 'net_heat_balance', 'DE1 0 services rural ground heat pump-2030_proportion', 'DE1 0 services rural air heat pump-2030_proportion', 'DE1 0 services rural resistive heater-2030_proportion', 'DE1 0 services rural ground heat pump-2015_proportion', 'DE1 0 services rural ground heat pump-2019_proportion']
#   Load: residential rural heat
#   Columns: ['DE1 0 residential rural heat', 'DE1 0 residential rural solar thermal collector-2030', 'DE1 0 residential rural heat load', 'DE1 0 residential rural water tanks charger', 'DE1 0 residential rural water tanks discharger', 'DE1 0 residential rural gas boiler-2030', 'DE1 0 residential rural biomass boiler-2030', 'DE1 0 residential rural gas boiler-2015', 'DE1 0 residential rural oil boiler-2015', 'DE1 0 residential rural gas boiler-2019', 'DE1 0 residential rural oil boiler-2019', 'net_heat_balance', 'DE1 0 residential rural ground heat pump-2030_proportion', 'DE1 0 residential rural air heat pump-2030_proportion', 'DE1 0 residential rural resistive heater-2030_proportion', 'DE1 0 residential rural ground heat pump-2015_proportion', 'DE1 0 residential rural ground heat pump-2019_proportion']
#   Load: residential urban decentral heat
#   Columns: ['DE1 0 residential urban decentral heat', 'DE1 0 residential urban decentral solar thermal collector-2030', 'DE1 0 residential urban decentral heat load', 'DE1 0 residential urban decentral water tanks charger', 'DE1 0 residential urban decentral water tanks discharger', 'DE1 0 residential urban decentral gas boiler-2030', 'DE1 0 residential urban decentral biomass boiler-2030', 'DE1 0 residential urban decentral gas boiler-2015', 'DE1 0 residential urban decentral oil boiler-2015', 'DE1 0 residential urban decentral gas boiler-2019', 'DE1 0 residential urban decentral oil boiler-2019', 'net_heat_balance', 'DE1 0 residential urban decentral air heat pump-2030_proportion', 'DE1 0 residential urban decentral resistive heater-2030_proportion', 'DE1 0 residential urban decentral air heat pump-2015_proportion', 'DE1 0 residential urban decentral air heat pump-2019_proportion']
#
# Country: NL
#   Load: urban central heat
#   Columns: ['NL1 0 urban central heat', 'NL1 0 low-temperature heat for industry', 'NL1 0 urban central solar thermal collector-2030', 'NL1 0 urban central heat load', 'NL1 0 urban central water tanks charger', 'NL1 0 urban central water tanks discharger', 'NL1 0 urban central gas boiler-2030', 'NL1 0 Fischer-Tropsch-2030', 'net_heat_balance', 'NL1 0 H2 Fuel Cell-2030_proportion', 'NL1 0 urban central air heat pump-2030_proportion', 'NL1 0 urban central resistive heater-2030_proportion', 'NL1 0 urban central gas CHP-2030_proportion', 'NL1 0 urban central solid biomass CHP-2030_proportion']
#   Load: services urban decentral heat
#   Columns: ['NL1 0 services urban decentral heat', 'NL1 0 services urban decentral solar thermal collector-2030', 'NL1 0 services urban decentral heat load', 'NL1 0 services urban decentral water tanks charger', 'NL1 0 services urban decentral water tanks discharger', 'NL1 0 services urban decentral gas boiler-2030', 'NL1 0 services urban decentral biomass boiler-2030', 'NL1 0 services urban decentral gas boiler-2015', 'NL1 0 services urban decentral gas boiler-2019', 'net_heat_balance', 'NL1 0 services urban decentral air heat pump-2030_proportion', 'NL1 0 services urban decentral resistive heater-2030_proportion', 'NL1 0 services urban decentral air heat pump-2015_proportion', 'NL1 0 services urban decentral air heat pump-2019_proportion']
#   Load: services rural heat
#   Columns: ['NL1 0 services rural heat', 'NL1 0 agriculture heat', 'NL1 0 services rural solar thermal collector-2030', 'NL1 0 services rural heat load', 'NL1 0 services rural water tanks charger', 'NL1 0 services rural water tanks discharger', 'NL1 0 services rural gas boiler-2030', 'NL1 0 services rural biomass boiler-2030', 'NL1 0 services rural gas boiler-2015', 'NL1 0 services rural gas boiler-2019', 'net_heat_balance', 'NL1 0 services rural ground heat pump-2030_proportion', 'NL1 0 services rural air heat pump-2030_proportion', 'NL1 0 services rural resistive heater-2030_proportion', 'NL1 0 services rural ground heat pump-2015_proportion', 'NL1 0 services rural ground heat pump-2019_proportion']
#   Load: residential rural heat
#   Columns: ['NL1 0 residential rural heat', 'NL1 0 residential rural solar thermal collector-2030', 'NL1 0 residential rural heat load', 'NL1 0 residential rural water tanks charger', 'NL1 0 residential rural water tanks discharger', 'NL1 0 residential rural gas boiler-2030', 'NL1 0 residential rural biomass boiler-2030', 'NL1 0 residential rural gas boiler-2015', 'NL1 0 residential rural gas boiler-2019', 'net_heat_balance', 'NL1 0 residential rural ground heat pump-2030_proportion', 'NL1 0 residential rural air heat pump-2030_proportion', 'NL1 0 residential rural resistive heater-2030_proportion', 'NL1 0 residential rural ground heat pump-2015_proportion', 'NL1 0 residential rural ground heat pump-2019_proportion']
#   Load: residential urban decentral heat
#   Columns: ['NL1 0 residential urban decentral heat', 'NL1 0 residential urban decentral solar thermal collector-2030', 'NL1 0 residential urban decentral heat load', 'NL1 0 residential urban decentral water tanks charger', 'NL1 0 residential urban decentral water tanks discharger', 'NL1 0 residential urban decentral gas boiler-2030', 'NL1 0 residential urban decentral biomass boiler-2030', 'NL1 0 residential urban decentral gas boiler-2015', 'NL1 0 residential urban decentral oil boiler-2015', 'NL1 0 residential urban decentral gas boiler-2019', 'NL1 0 residential urban decentral oil boiler-2019', 'net_heat_balance', 'NL1 0 residential urban decentral air heat pump-2030_proportion', 'NL1 0 residential urban decentral resistive heater-2030_proportion', 'NL1 0 residential urban decentral air heat pump-2015_proportion', 'NL1 0 residential urban decentral resistive heater-2015_proportion', 'NL1 0 residential urban decentral air heat pump-2019_proportion', 'NL1 0 residential urban decentral resistive heater-2019_proportion']
#
# Country: UK
#   Load: urban central heat
#   Columns: ['GB0 0 urban central heat', 'GB2 0 urban central heat', 'GB0 0 low-temperature heat for industry', 'GB2 0 low-temperature heat for industry', 'GB0 0 urban central solar thermal collector-2030', 'GB2 0 urban central solar thermal collector-2030', 'GB0 0 urban central heat load', 'GB2 0 urban central heat load', 'GB0 0 urban central water tanks charger', 'GB2 0 urban central water tanks charger', 'GB0 0 urban central water tanks discharger', 'GB2 0 urban central water tanks discharger', 'GB0 0 urban central gas boiler-2030', 'GB2 0 urban central gas boiler-2030', 'GB0 0 Fischer-Tropsch-2030', 'GB2 0 Fischer-Tropsch-2030', 'net_heat_balance', 'GB0 0 H2 Fuel Cell-2030_proportion', 'GB2 0 H2 Fuel Cell-2030_proportion', 'GB0 0 urban central air heat pump-2030_proportion', 'GB2 0 urban central air heat pump-2030_proportion', 'GB0 0 urban central resistive heater-2030_proportion', 'GB2 0 urban central resistive heater-2030_proportion', 'GB0 0 urban central gas CHP-2030_proportion', 'GB2 0 urban central gas CHP-2030_proportion', 'GB0 0 urban central solid biomass CHP-2030_proportion', 'GB2 0 urban central solid biomass CHP-2030_proportion']
#   Load: services urban decentral heat
#   Columns: ['GB0 0 services urban decentral heat', 'GB2 0 services urban decentral heat', 'GB0 0 services urban decentral solar thermal collector-2030', 'GB2 0 services urban decentral solar thermal collector-2030', 'GB0 0 services urban decentral heat load', 'GB2 0 services urban decentral heat load', 'GB0 0 services urban decentral water tanks charger', 'GB2 0 services urban decentral water tanks charger', 'GB0 0 services urban decentral water tanks discharger', 'GB2 0 services urban decentral water tanks discharger', 'GB0 0 services urban decentral gas boiler-2030', 'GB2 0 services urban decentral gas boiler-2030', 'GB0 0 services urban decentral biomass boiler-2030', 'GB2 0 services urban decentral biomass boiler-2030', 'GB0 0 services urban decentral gas boiler-2015', 'GB2 0 services urban decentral gas boiler-2015', 'GB0 0 services urban decentral oil boiler-2015', 'GB0 0 services urban decentral gas boiler-2019', 'GB2 0 services urban decentral gas boiler-2019', 'GB0 0 services urban decentral oil boiler-2019', 'net_heat_balance', 'GB0 0 services urban decentral air heat pump-2030_proportion', 'GB2 0 services urban decentral air heat pump-2030_proportion', 'GB0 0 services urban decentral resistive heater-2030_proportion', 'GB2 0 services urban decentral resistive heater-2030_proportion', 'GB0 0 services urban decentral air heat pump-2015_proportion', 'GB0 0 services urban decentral resistive heater-2015_proportion', 'GB0 0 services urban decentral resistive heater-2019_proportion']
#   Load: services rural heat
#   Columns: ['GB0 0 services rural heat', 'GB2 0 services rural heat', 'GB0 0 agriculture heat', 'GB2 0 agriculture heat', 'GB0 0 services rural solar thermal collector-2030', 'GB2 0 services rural solar thermal collector-2030', 'GB0 0 services rural heat load', 'GB2 0 services rural heat load', 'GB0 0 services rural water tanks charger', 'GB2 0 services rural water tanks charger', 'GB0 0 services rural water tanks discharger', 'GB2 0 services rural water tanks discharger', 'GB0 0 services rural gas boiler-2030', 'GB2 0 services rural gas boiler-2030', 'GB0 0 services rural biomass boiler-2030', 'GB2 0 services rural biomass boiler-2030', 'GB0 0 services rural gas boiler-2015', 'GB2 0 services rural gas boiler-2015', 'GB0 0 services rural oil boiler-2015', 'GB0 0 services rural gas boiler-2019', 'GB2 0 services rural gas boiler-2019', 'GB0 0 services rural oil boiler-2019', 'net_heat_balance', 'GB0 0 services rural ground heat pump-2030_proportion', 'GB2 0 services rural ground heat pump-2030_proportion', 'GB0 0 services rural air heat pump-2030_proportion', 'GB2 0 services rural air heat pump-2030_proportion', 'GB0 0 services rural resistive heater-2030_proportion', 'GB2 0 services rural resistive heater-2030_proportion', 'GB0 0 services rural resistive heater-2015_proportion', 'GB2 0 services rural resistive heater-2015_proportion', 'GB0 0 services rural resistive heater-2019_proportion', 'GB2 0 services rural resistive heater-2019_proportion']
#   Load: residential rural heat
#   Columns: ['GB0 0 residential rural heat', 'GB2 0 residential rural heat', 'GB0 0 residential rural solar thermal collector-2030', 'GB2 0 residential rural solar thermal collector-2030', 'GB0 0 residential rural heat load', 'GB2 0 residential rural heat load', 'GB0 0 residential rural water tanks charger', 'GB2 0 residential rural water tanks charger', 'GB0 0 residential rural water tanks discharger', 'GB2 0 residential rural water tanks discharger', 'GB0 0 residential rural gas boiler-2030', 'GB2 0 residential rural gas boiler-2030', 'GB0 0 residential rural biomass boiler-2030', 'GB2 0 residential rural biomass boiler-2030', 'GB0 0 residential rural gas boiler-2015', 'GB2 0 residential rural gas boiler-2015', 'GB0 0 residential rural oil boiler-2015', 'GB2 0 residential rural oil boiler-2015', 'GB0 0 residential rural gas boiler-2019', 'GB2 0 residential rural gas boiler-2019', 'GB0 0 residential rural oil boiler-2019', 'GB2 0 residential rural oil boiler-2019', 'net_heat_balance', 'GB0 0 residential rural ground heat pump-2030_proportion', 'GB2 0 residential rural ground heat pump-2030_proportion', 'GB0 0 residential rural air heat pump-2030_proportion', 'GB2 0 residential rural air heat pump-2030_proportion', 'GB0 0 residential rural resistive heater-2030_proportion', 'GB2 0 residential rural resistive heater-2030_proportion', 'GB0 0 residential rural ground heat pump-2015_proportion', 'GB0 0 residential rural resistive heater-2015_proportion', 'GB2 0 residential rural resistive heater-2015_proportion', 'GB0 0 residential rural resistive heater-2019_proportion', 'GB2 0 residential rural resistive heater-2019_proportion']
#   Load: residential urban decentral heat
#   Columns: ['GB0 0 residential urban decentral heat', 'GB2 0 residential urban decentral heat', 'GB0 0 residential urban decentral solar thermal collector-2030', 'GB2 0 residential urban decentral solar thermal collector-2030', 'GB0 0 residential urban decentral heat load', 'GB2 0 residential urban decentral heat load', 'GB0 0 residential urban decentral water tanks charger', 'GB2 0 residential urban decentral water tanks charger', 'GB0 0 residential urban decentral water tanks discharger', 'GB2 0 residential urban decentral water tanks discharger', 'GB0 0 residential urban decentral gas boiler-2030', 'GB2 0 residential urban decentral gas boiler-2030', 'GB0 0 residential urban decentral biomass boiler-2030', 'GB2 0 residential urban decentral biomass boiler-2030', 'GB0 0 residential urban decentral gas boiler-2015', 'GB2 0 residential urban decentral gas boiler-2015', 'GB0 0 residential urban decentral oil boiler-2015', 'GB2 0 residential urban decentral oil boiler-2015', 'GB0 0 residential urban decentral gas boiler-2019', 'GB2 0 residential urban decentral gas boiler-2019', 'GB0 0 residential urban decentral oil boiler-2019', 'GB2 0 residential urban decentral oil boiler-2019', 'net_heat_balance', 'GB0 0 residential urban decentral air heat pump-2030_proportion', 'GB2 0 residential urban decentral air heat pump-2030_proportion', 'GB0 0 residential urban decentral resistive heater-2030_proportion', 'GB2 0 residential urban decentral resistive heater-2030_proportion', 'GB0 0 residential urban decentral air heat pump-2015_proportion', 'GB0 0 residential urban decentral resistive heater-2015_proportion', 'GB2 0 residential urban decentral resistive heater-2015_proportion', 'GB0 0 residential urban decentral air heat pump-2019_proportion', 'GB0 0 residential urban decentral resistive heater-2019_proportion', 'GB2 0 residential urban decentral resistive heater-2019_proportion']

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         D-09. Loading COP Time Series and Calculating Thermal Efficiencies for Heat Load Assets
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process loads the <b>COP (Coefficient of Performance) time series</b> for heat pump units and calculates the <b>thermal efficiency-adjusted</b> profiles for each heat load asset. It supports both <b>time-varying COP</b> (for heat pumps) and <b>static efficiency</b> (for resistive heaters and boilers).<br>
#     <b>Calculation Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each asset, the script first checks whether a <b>COP time series</b> exists in the loaded COP DataFrame. If available, it uses the time-varying COP to calculate the electric equivalent:_/
#                         <div style="text-align: center;">
#             <b>ThermEfficiency = proportion / COP</b>
#                         </div>
#         </div>
#             If no COP series is found, it falls back to the <b>static efficiency</b> from the power-plant metadata, usin the bus-to-efficiency mapping to find the correct efficiency value.
#     </div>
# </div>

# %%
### LOAD COP TIME SERIES
cop_file = os.path.join(
    loads_pypsa_raw_data_folder_path,
    f"COP_ts_{pypsa_scenario}_{data_target_year}.csv"
)
print("\n--- Loading COP Time Series ---")
print(f"File: {cop_file}")
cop_ts_df = pd.read_csv(cop_file)
### Convert snapshot to datetime
cop_ts_df["snapshot"] = pd.to_datetime(cop_ts_df["snapshot"])
### Use snapshot as index
cop_ts_df = cop_ts_df.set_index("snapshot")
print(
    f"COP time series loaded: "
    f"{len(cop_ts_df):,} snapshots | "
    f"{len(cop_ts_df.columns):,} COP series"
)
print("COP columns:")
for col in cop_ts_df.columns:
    print(f"  {col}")
### BUS -> EFFICIENCY COLUMN MAPPING
# =============================================================================
bus_to_eff_map = {
    'bus':  'efficiency',
    'bus0': 'efficiency',
    'bus1': 'efficiency',
    'bus2': 'efficiency2',
    'bus3': 'efficiency3',
    'bus4': 'efficiency4'
}
# =============================================================================
### CALCULATE THERMAL EFFICIENCIES
for country in zone_names:
    print(f"\n--- Calculating Thermal Efficiencies for Country: {country} ---")
    ### Load power-plant metadata
    power_plants_file = os.path.join(
        pypsa_raw_data_folder_path,
        pypsa_scenario,
        "PowerPlants",
        data_target_year,
        country,
        f"pypsa_power_plants_{country}_{data_target_year}.csv"
    )
    print(f"  Loading metadata from:")
    print(f"  {power_plants_file}")
    master_df = pd.read_csv(power_plants_file)
    master_df = master_df.set_index("name")
    ### Process each heat-load category
    for current_heat_load, ts_df in country_loads_time_series[country].items():
        if ts_df.empty:
            continue
        ### Identify proportion columns
        proportion_cols = [
            col
            for col in ts_df.columns
            if col.endswith("_proportion")
        ]

        if not proportion_cols:
            continue
        calculated_efficiencies = {}
        ### PROCESS EACH ASSET
        for col in proportion_cols:
            ### Remove "_proportion"
            asset_name = col[:-11]
            ### Check that asset exists in power-plant metadata
            if asset_name not in master_df.index:
                print(
                    f"  [{current_heat_load}] "
                    f"Asset '{asset_name}' not found in metadata. Skipping."
                )
                continue
            asset_row = master_df.loc[asset_name]
            ### FIRST: CHECK WHETHER THIS ASSET HAS A COP TIME SERIES
            if asset_name in cop_ts_df.columns:
                print(
                    f"  [{current_heat_load}] "
                    f"Using COP time series for '{asset_name}'."
                )
                cop_series = cop_ts_df[asset_name].reindex(ts_df.index)
                calculated_efficiencies[
                    f"{asset_name}_/ThermEfficiency"
                ] = ts_df[col] / cop_series
                continue
            ### OTHERWISE: USE STATIC THERMAL EFFICIENCY
            matched_eff_col = None
            for bus_col, eff_col in bus_to_eff_map.items():
                if bus_col not in asset_row:
                    continue
                bus_value = asset_row[bus_col]
                if pd.isna(bus_value):
                    continue
                if current_heat_load in str(bus_value):
                    matched_eff_col = eff_col
                    break
            ### No matching bus
            if matched_eff_col is None:
                print(
                    f"  [{current_heat_load}] "
                    f"No matching bus found for '{asset_name}'."
                )
                continue
            ### Obtain static efficiency
            divisor = None
            if matched_eff_col in asset_row:
                efficiency_value = asset_row[matched_eff_col]
                if pd.notna(efficiency_value):
                    efficiency_value = float(efficiency_value)
                    if efficiency_value != 0:
                        divisor = efficiency_value
            ### Calculate using static efficiency
            if divisor is not None:
                new_col = f"{asset_name}_/ThermEfficiency"
                calculated_efficiencies[new_col] = (
                    ts_df[col] / divisor
                )
            else:
                print(
                    f"  [{current_heat_load}] "
                    f"Could not find a valid efficiency for "
                    f"'{asset_name}'."
                )
        ### ADD CALCULATED COLUMNS
        if calculated_efficiencies:
            eff_df = pd.DataFrame(
                calculated_efficiencies,
                index=ts_df.index
            )
            country_loads_time_series[country][current_heat_load] = pd.concat(
                [
                    ts_df,
                    eff_df
                ],
                axis=1
            )
            print(
                f"  [{current_heat_load}] "
                f"Added {len(calculated_efficiencies)} "
                f"'_/ThermEfficiency' columns."
            )
print("\nThermal efficiency calculation completed successfully!")
# Out:
# --- Loading COP Time Series ---
# File: /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/Load_RealTime/COP_ts_Sufficiency_Scenario_2030.csv
# COP time series loaded: 8,760 snapshots | 70 COP series
# COP columns:
#   BE1 0 residential rural air heat pump-2030
#   BE1 0 residential rural ground heat pump-2030
#   BE1 0 residential urban decentral air heat pump-2030
#   BE1 0 services rural air heat pump-2030
#   BE1 0 services rural ground heat pump-2030
#   BE1 0 services urban decentral air heat pump-2030
#   BE1 0 urban central air heat pump-2030
#   DE1 0 residential rural air heat pump-2030
#   DE1 0 residential rural ground heat pump-2015
#   DE1 0 residential rural ground heat pump-2019
#   DE1 0 residential rural ground heat pump-2030
#   DE1 0 residential urban decentral air heat pump-2015
#   DE1 0 residential urban decentral air heat pump-2019
#   DE1 0 residential urban decentral air heat pump-2030
#   DE1 0 services rural air heat pump-2030
#   DE1 0 services rural ground heat pump-2015
#   DE1 0 services rural ground heat pump-2019
#   DE1 0 services rural ground heat pump-2030
#   DE1 0 services urban decentral air heat pump-2015
#   DE1 0 services urban decentral air heat pump-2019
#   DE1 0 services urban decentral air heat pump-2030
#   DE1 0 urban central air heat pump-2030
#   FR1 0 residential rural air heat pump-2030
#   FR1 0 residential rural ground heat pump-2015
#   FR1 0 residential rural ground heat pump-2019
#   FR1 0 residential rural ground heat pump-2030
#   FR1 0 residential urban decentral air heat pump-2015
#   FR1 0 residential urban decentral air heat pump-2019
#   FR1 0 residential urban decentral air heat pump-2030
#   FR1 0 services rural air heat pump-2030
#   FR1 0 services rural ground heat pump-2015
#   FR1 0 services rural ground heat pump-2019
#   FR1 0 services rural ground heat pump-2030
#   FR1 0 services urban decentral air heat pump-2015
#   FR1 0 services urban decentral air heat pump-2019
#   FR1 0 services urban decentral air heat pump-2030
#   FR1 0 urban central air heat pump-2030
#   GB0 0 residential rural air heat pump-2030
#   GB0 0 residential rural ground heat pump-2015
#   GB0 0 residential rural ground heat pump-2030
#   GB0 0 residential urban decentral air heat pump-2015
#   GB0 0 residential urban decentral air heat pump-2019
#   GB0 0 residential urban decentral air heat pump-2030
#   GB0 0 services rural air heat pump-2030
#   GB0 0 services rural ground heat pump-2030
#   GB0 0 services urban decentral air heat pump-2015
#   GB0 0 services urban decentral air heat pump-2030
#   GB0 0 urban central air heat pump-2030
#   GB2 0 residential rural air heat pump-2030
#   GB2 0 residential rural ground heat pump-2030
#   GB2 0 residential urban decentral air heat pump-2030
#   GB2 0 services rural air heat pump-2030
#   GB2 0 services rural ground heat pump-2030
#   GB2 0 services urban decentral air heat pump-2030
#   GB2 0 urban central air heat pump-2030
#   NL1 0 residential rural air heat pump-2030
#   NL1 0 residential rural ground heat pump-2015
#   NL1 0 residential rural ground heat pump-2019
#   NL1 0 residential rural ground heat pump-2030
#   NL1 0 residential urban decentral air heat pump-2015
#   NL1 0 residential urban decentral air heat pump-2019
#   NL1 0 residential urban decentral air heat pump-2030
#   NL1 0 services rural air heat pump-2030
#   NL1 0 services rural ground heat pump-2015
#   NL1 0 services rural ground heat pump-2019
#   NL1 0 services rural ground heat pump-2030
#   NL1 0 services urban decentral air heat pump-2015
#   NL1 0 services urban decentral air heat pump-2019
#   NL1 0 services urban decentral air heat pump-2030
#   NL1 0 urban central air heat pump-2030
#
# --- Calculating Thermal Efficiencies for Country: BE ---
#   Loading metadata from:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/BE/pypsa_power_plants_BE_2030.csv
#   [urban central heat] Using COP time series for 'BE1 0 urban central air heat pump-2030'.
#   [urban central heat] Added 5 '_/ThermEfficiency' columns.
#   [services urban decentral heat] Using COP time series for 'BE1 0 services urban decentral air heat pump-2030'.
#   [services urban decentral heat] Added 4 '_/ThermEfficiency' columns.
#   [services rural heat] Using COP time series for 'BE1 0 services rural ground heat pump-2030'.
#   [services rural heat] Using COP time series for 'BE1 0 services rural air heat pump-2030'.
#   [services rural heat] Added 3 '_/ThermEfficiency' columns.
#   [residential rural heat] Using COP time series for 'BE1 0 residential rural ground heat pump-2030'.
#   [residential rural heat] Using COP time series for 'BE1 0 residential rural air heat pump-2030'.
#   [residential rural heat] Added 5 '_/ThermEfficiency' columns.
#   [residential urban decentral heat] Using COP time series for 'BE1 0 residential urban decentral air heat pump-2030'.
#   [residential urban decentral heat] Added 4 '_/ThermEfficiency' columns.
#
# --- Calculating Thermal Efficiencies for Country: FR ---
#   Loading metadata from:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/FR/pypsa_power_plants_FR_2030.csv
#   [urban central heat] Using COP time series for 'FR1 0 urban central air heat pump-2030'.
#   [urban central heat] Added 5 '_/ThermEfficiency' columns.
#   [services urban decentral heat] Using COP time series for 'FR1 0 services urban decentral air heat pump-2030'.
#   [services urban decentral heat] Using COP time series for 'FR1 0 services urban decentral air heat pump-2015'.
#   [services urban decentral heat] Using COP time series for 'FR1 0 services urban decentral air heat pump-2019'.
#   [services urban decentral heat] Added 6 '_/ThermEfficiency' columns.
#   [services rural heat] Using COP time series for 'FR1 0 services rural ground heat pump-2030'.
#   [services rural heat] Using COP time series for 'FR1 0 services rural air heat pump-2030'.
#   [services rural heat] Using COP time series for 'FR1 0 services rural ground heat pump-2015'.
#   [services rural heat] Using COP time series for 'FR1 0 services rural ground heat pump-2019'.
#   [services rural heat] Added 7 '_/ThermEfficiency' columns.
#   [residential rural heat] Using COP time series for 'FR1 0 residential rural ground heat pump-2030'.
#   [residential rural heat] Using COP time series for 'FR1 0 residential rural air heat pump-2030'.
#   [residential rural heat] Using COP time series for 'FR1 0 residential rural ground heat pump-2015'.
#   [residential rural heat] Using COP time series for 'FR1 0 residential rural ground heat pump-2019'.
#   [residential rural heat] Added 7 '_/ThermEfficiency' columns.
#   [residential urban decentral heat] Using COP time series for 'FR1 0 residential urban decentral air heat pump-2030'.
#   [residential urban decentral heat] Using COP time series for 'FR1 0 residential urban decentral air heat pump-2015'.
#   [residential urban decentral heat] Using COP time series for 'FR1 0 residential urban decentral air heat pump-2019'.
#   [residential urban decentral heat] Added 6 '_/ThermEfficiency' columns.
#
# --- Calculating Thermal Efficiencies for Country: DE ---
#   Loading metadata from:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/DE/pypsa_power_plants_DE_2030.csv
#   [urban central heat] Using COP time series for 'DE1 0 urban central air heat pump-2030'.
#   [urban central heat] Added 5 '_/ThermEfficiency' columns.
#   [services urban decentral heat] Using COP time series for 'DE1 0 services urban decentral air heat pump-2030'.
#   [services urban decentral heat] Using COP time series for 'DE1 0 services urban decentral air heat pump-2015'.
#   [services urban decentral heat] Using COP time series for 'DE1 0 services urban decentral air heat pump-2019'.
#   [services urban decentral heat] Added 4 '_/ThermEfficiency' columns.
#   [services rural heat] Using COP time series for 'DE1 0 services rural ground heat pump-2030'.
#   [services rural heat] Using COP time series for 'DE1 0 services rural air heat pump-2030'.
#   [services rural heat] Using COP time series for 'DE1 0 services rural ground heat pump-2015'.
#   [services rural heat] Using COP time series for 'DE1 0 services rural ground heat pump-2019'.
#   [services rural heat] Added 5 '_/ThermEfficiency' columns.
#   [residential rural heat] Using COP time series for 'DE1 0 residential rural ground heat pump-2030'.
#   [residential rural heat] Using COP time series for 'DE1 0 residential rural air heat pump-2030'.
#   [residential rural heat] Using COP time series for 'DE1 0 residential rural ground heat pump-2015'.
#   [residential rural heat] Using COP time series for 'DE1 0 residential rural ground heat pump-2019'.
#   [residential rural heat] Added 5 '_/ThermEfficiency' columns.
#   [residential urban decentral heat] Using COP time series for 'DE1 0 residential urban decentral air heat pump-2030'.
#   [residential urban decentral heat] Using COP time series for 'DE1 0 residential urban decentral air heat pump-2015'.
#   [residential urban decentral heat] Using COP time series for 'DE1 0 residential urban decentral air heat pump-2019'.
#   [residential urban decentral heat] Added 4 '_/ThermEfficiency' columns.
#
# --- Calculating Thermal Efficiencies for Country: NL ---
#   Loading metadata from:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/NL/pypsa_power_plants_NL_2030.csv
#   [urban central heat] Using COP time series for 'NL1 0 urban central air heat pump-2030'.
#   [urban central heat] Added 5 '_/ThermEfficiency' columns.
#   [services urban decentral heat] Using COP time series for 'NL1 0 services urban decentral air heat pump-2030'.
#   [services urban decentral heat] Using COP time series for 'NL1 0 services urban decentral air heat pump-2015'.
#   [services urban decentral heat] Using COP time series for 'NL1 0 services urban decentral air heat pump-2019'.
#   [services urban decentral heat] Added 4 '_/ThermEfficiency' columns.
#   [services rural heat] Using COP time series for 'NL1 0 services rural ground heat pump-2030'.
#   [services rural heat] Using COP time series for 'NL1 0 services rural air heat pump-2030'.
#   [services rural heat] Using COP time series for 'NL1 0 services rural ground heat pump-2015'.
#   [services rural heat] Using COP time series for 'NL1 0 services rural ground heat pump-2019'.
#   [services rural heat] Added 5 '_/ThermEfficiency' columns.
#   [residential rural heat] Using COP time series for 'NL1 0 residential rural ground heat pump-2030'.
#   [residential rural heat] Using COP time series for 'NL1 0 residential rural air heat pump-2030'.
#   [residential rural heat] Using COP time series for 'NL1 0 residential rural ground heat pump-2015'.
#   [residential rural heat] Using COP time series for 'NL1 0 residential rural ground heat pump-2019'.
#   [residential rural heat] Added 5 '_/ThermEfficiency' columns.
#   [residential urban decentral heat] Using COP time series for 'NL1 0 residential urban decentral air heat pump-2030'.
#   [residential urban decentral heat] Using COP time series for 'NL1 0 residential urban decentral air heat pump-2015'.
#   [residential urban decentral heat] Using COP time series for 'NL1 0 residential urban decentral air heat pump-2019'.
#   [residential urban decentral heat] Added 6 '_/ThermEfficiency' columns.
#
# --- Calculating Thermal Efficiencies for Country: UK ---
#   Loading metadata from:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/UK/pypsa_power_plants_UK_2030.csv
#   [urban central heat] Using COP time series for 'GB0 0 urban central air heat pump-2030'.
#   [urban central heat] Using COP time series for 'GB2 0 urban central air heat pump-2030'.
#   [urban central heat] Added 10 '_/ThermEfficiency' columns.
#   [services urban decentral heat] Using COP time series for 'GB0 0 services urban decentral air heat pump-2030'.
#   [services urban decentral heat] Using COP time series for 'GB2 0 services urban decentral air heat pump-2030'.
#   [services urban decentral heat] Using COP time series for 'GB0 0 services urban decentral air heat pump-2015'.
#   [services urban decentral heat] Added 7 '_/ThermEfficiency' columns.
#   [services rural heat] Using COP time series for 'GB0 0 services rural ground heat pump-2030'.
#   [services rural heat] Using COP time series for 'GB2 0 services rural ground heat pump-2030'.
#   [services rural heat] Using COP time series for 'GB0 0 services rural air heat pump-2030'.
#   [services rural heat] Using COP time series for 'GB2 0 services rural air heat pump-2030'.
#   [services rural heat] Added 10 '_/ThermEfficiency' columns.
#   [residential rural heat] Using COP time series for 'GB0 0 residential rural ground heat pump-2030'.
#   [residential rural heat] Using COP time series for 'GB2 0 residential rural ground heat pump-2030'.
#   [residential rural heat] Using COP time series for 'GB0 0 residential rural air heat pump-2030'.
#   [residential rural heat] Using COP time series for 'GB2 0 residential rural air heat pump-2030'.
#   [residential rural heat] Using COP time series for 'GB0 0 residential rural ground heat pump-2015'.
#   [residential rural heat] Added 11 '_/ThermEfficiency' columns.
#   [residential urban decentral heat] Using COP time series for 'GB0 0 residential urban decentral air heat pump-2030'.
#   [residential urban decentral heat] Using COP time series for 'GB2 0 residential urban decentral air heat pump-2030'.
#   [residential urban decentral heat] Using COP time series for 'GB0 0 residential urban decentral air heat pump-2015'.
#   [residential urban decentral heat] Using COP time series for 'GB0 0 residential urban decentral air heat pump-2019'.
#   [residential urban decentral heat] Added 10 '_/ThermEfficiency' columns.
#
# Thermal efficiency calculation completed successfully!

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         D-10. Extracting Heater Consumption Electric Equivalency (with VPP-Based Filtering)
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process extracts all <b>_/ThermEfficiency</b> columns from the <b>country_loads_time_series</b> dictionary and consolidates them into a new dictionary (<b>heaters_consumption_elect_equivalency</b>).<br> These columns represent the <b>electric equivalency of heater consumption</b> (fuel input demand) for various technologies.<br> The extraction is <b>conditionally filtered based on VPP mode</b> to exclude resistive heaters when VPP is enabled.<br>
#     <b>Extraction Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each country, the script iterates through all heat load categories and identifies columns containing <b>_/ThermEfficiency</b> in their names. The selection is filtered based on <b>VPP</b> mode:
#                 <div style="margin-left: 2em;">
#         <b>When VPP = True</b> → Excludes columns containing <b>"resistive"</b> (resistive heaters are handled separately by VPP logic)<br>
#         <b>When VPP = False</b> → Includes all <b>_/ThermEfficiency</b> columns
#                 </div>
#         The selected columns are concatenated <b>horizontally</b> (along the column axis) into a single DataFrame per country.
#         </div>
#     </div>
# </div>

# %%
heaters_consumption_elect_equivalency = {}
for country, heat_loads_dict in country_loads_time_series.items():
    country_efficiency_dfs = []
    for heat_category, df in heat_loads_dict.items():
        # SELECT /ThermEfficiency COLUMNS ACCORDING TO VPP FLAG
        if VPP:
            # VPP activated:
            # Exclude all resistive heater columns
            efficiency_cols = [
                col
                for col in df.columns
                if (
                    "_/ThermEfficiency" in str(col)
                    and "resistive" not in str(col).lower()
                )
            ]
        else:
            # VPP deactivated:
            # Include all /ThermEfficiency columns
            efficiency_cols = [
                col
                for col in df.columns
                if "_/ThermEfficiency" in str(col)
            ]
        # STORE SELECTED COLUMNS
        if efficiency_cols:
            country_efficiency_dfs.append(
                df[efficiency_cols]
            )
    # COMBINE ALL HEAT CATEGORIES FOR THE COUNTRY
    if country_efficiency_dfs:
        heaters_consumption_elect_equivalency[country] = pd.concat(
            country_efficiency_dfs,
            axis=1
        )
    else:
        heaters_consumption_elect_equivalency[country] = pd.DataFrame(
            index=next(iter(heat_loads_dict.values())).index
        )
# FINAL INFORMATION
print("\nProcess completed.")
for country, df in heaters_consumption_elect_equivalency.items():
    print(
        f" {country}: "
        f"{df.shape[1]} efficiency columns extracted"
    )
# Out:
# Process completed.
#  BE: 10 efficiency columns extracted
#  FR: 18 efficiency columns extracted
#  DE: 18 efficiency columns extracted
#  NL: 18 efficiency columns extracted
#  UK: 24 efficiency columns extracted

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         D-11. Summing All Heater Consumption Electric Equivalency Columns
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process aggregates all heater consumption electric equivalency columns for each country into a <b>single total time series</b>.<br> The resulting DataFrame contains one column per country (<b>total_heaters_consumption_elect_equivalency</b>) representing the <b>total electric equivalency of all heater consumption</b> at each snapshot.<br>
#     <b>Aggregation Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each country, the script sums all columns of the DataFrame <b>horizontally</b> (along the column axis) using <b>df.sum(axis=1)</b>. This produces a single Series where each value is the sum of all heater electric equivalency components at that snapshot.
#         <br>The Series is then converted to a DataFrame with a single column named <b>"total_heaters_consumption_elect_equivalency"</b>, preserving the snapshot as the index.
#         </div>
#         The resulting dictionary, <b>total_heaters_consumption_elect_equivalency</b>, contains one DataFrame per country with a single column representing the total electric equivalency of all heater consumption. This aggregated profile is ready for Dispa-SET load formatting.
#     </div>
# </div>

# %%
total_heaters_consumption_elect_equivalency = {}
for country, df in heaters_consumption_elect_equivalency.items():
    total_consumption = df.sum(axis=1)
    total_heaters_consumption_elect_equivalency[country] = (
        total_consumption.to_frame(
            name="total_heaters_consumption_elect_equivalency"
        )
    )
    total_heaters_consumption_elect_equivalency[country].index.name = "snapshot"
print("\nProcess completed.")
for country, df in total_heaters_consumption_elect_equivalency.items():
    print(
        f"{country}: {len(df)} snapshots processed, "
        f"column = '{df.columns[0]}'"
    )
# Out:
# Process completed.
# BE: 8760 snapshots processed, column = 'total_heaters_consumption_elect_equivalency'
# FR: 8760 snapshots processed, column = 'total_heaters_consumption_elect_equivalency'
# DE: 8760 snapshots processed, column = 'total_heaters_consumption_elect_equivalency'
# NL: 8760 snapshots processed, column = 'total_heaters_consumption_elect_equivalency'
# UK: 8760 snapshots processed, column = 'total_heaters_consumption_elect_equivalency'

# %% [markdown]
# <div style= "background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099; " >
#  <span style= "font-weight: bold; font-size: 16px; " >
# Section E Overview: Sector Power Load Calculation
#  </span >
#  <div style= "border-top: 1px solid #000099; padding: 10px; " >
# This section calculates the baseline Sector Power Load for each country.<br> It combines three core components: the total baseline electric load, the total electric consumption from sector-coupled links, and the total electric equivalency of heater consumptions, resulting in a unified power sector demand profile.
#  </div >
#  </div >
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         E-1. Calculating Sector Power Load
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process calculates the <b>Sector Power Load</b> for each country by combining three components: <b>total electric load</b>, <b>total electric consumption</b>, and <b>total heaters consumption electric equivalency</b>. <br>The result is a single time series representing the total sector power load for each country.<br>
#     <b>Calculation Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each country, the script retrieves three DataFrames:
#             <div style="margin-left: 2em;">
#         <b>1.</b> <b>total_electric_load</b> from <code>total_electric_loads</code><br>
#         <b>2.</b> <b>Total_Electric_Consumption</b> from <code>total_electric_consumption</code><br>
#         <b>3.</b> <b>total_heaters_consumption_elect_equivalency</b> from <code>total_heaters_consumption_elect_equivalency</code>
#             </div>
#         All indices are converted to DatetimeIndex and the three columns are combined using <b>pd.concat(axis=1, join="inner")</b>. The Sector Power Load is then calculated as:
#             <div style="text-align: center; font-size: 14px;">
#         <b>Sector_Power_Load = total_electric_load + Total_Electric_Consumption + total_heaters_consumption_elect_equivalency</b>
#             </div>
#         The resulting DataFrame is stored in the <b>Sector_Power_Load</b> dictionary with a single column named "Sector_Power_Load" and a snapshot index.
#         <br>A summary report displays the shape and first values per country.
#         </div>
#     </div>
# </div>

# %%
### CALCULATE SECTOR POWER LOAD
Sector_Power_Load = {}
### PROCESS EACH COUNTRY
for country in total_electric_loads.keys():
    print(f"\n--- Processing {country} ---")
    # Get the three source DataFrames
    electric_loads_df = total_electric_loads[country].copy()
    electric_consumption_df = (
        total_electric_consumption[country].copy()
    )
    heaters_consumption_df = (
        total_heaters_consumption_elect_equivalency[country].copy()
    )
    # Make sure all indexes are DatetimeIndex
    electric_loads_df.index = pd.to_datetime(
        electric_loads_df.index
    )
    electric_consumption_df.index = pd.to_datetime(
        electric_consumption_df.index
    )
    heaters_consumption_df.index = pd.to_datetime(
        heaters_consumption_df.index
    )
    # Select the relevant columns
    electric_load = electric_loads_df[
        "total_electric_load"
    ]
    electric_consumption = electric_consumption_df[
        "Total_Electric_Consumption"
    ]
    heaters_consumption = (
        heaters_consumption_df[
            "total_heaters_consumption_elect_equivalency"
        ]
    )
    # Combine using the common snapshot index
    combined_df = pd.concat(
        [
            electric_load.rename("total_electric_load"),
            electric_consumption.rename(
                "Total_Electric_Consumption"
            ),
            heaters_consumption.rename(
                "total_heaters_consumption_elect_equivalency"
            ),
        ],
        axis=1,
        join="inner"
    )
    # Calculate Sector Power Load
    combined_df["Sector_Power_Load"] = (
        combined_df["total_electric_load"]
        + combined_df["Total_Electric_Consumption"]
        + combined_df[
            "total_heaters_consumption_elect_equivalency"
        ]
    )
    # Keep only the final result
    Sector_Power_Load[country] = combined_df[
        ["Sector_Power_Load"]
    ].copy()
    Sector_Power_Load[country].index.name = "snapshot"
    # Inspection
    print(
        f"  Created: Sector_Power_Load"
    )
    print(
        f"  Shape: "
        f"{Sector_Power_Load[country].shape}"
    )
    print(
        "  First values:"
    )
    print(
        Sector_Power_Load[country].head(2)
    )
### FINAL MESSAGE
print("\n" + "=" * 70)
print(
    "Successfully calculated "
    "'Sector_Power_Load' "
    "for all countries."
)
print("=" * 70)
# Out:
# --- Processing BE ---
#   Created: Sector_Power_Load
#   Shape: (8760, 1)
#   First values:
#                      Sector_Power_Load
# snapshot
# 2013-01-01 00:00:00       17107.668351
# 2013-01-01 01:00:00       16595.645796
#
# --- Processing FR ---
#   Created: Sector_Power_Load
#   Shape: (8760, 1)
#   First values:
#                      Sector_Power_Load
# snapshot
# 2013-01-01 00:00:00       54534.395010
# 2013-01-01 01:00:00       52766.633691
#
# --- Processing DE ---
#   Created: Sector_Power_Load
#   Shape: (8760, 1)
#   First values:
#                      Sector_Power_Load
# snapshot
# 2013-01-01 00:00:00       84664.755481
# 2013-01-01 01:00:00       83490.386883
#
# --- Processing NL ---
#   Created: Sector_Power_Load
#   Shape: (8760, 1)
#   First values:
#                      Sector_Power_Load
# snapshot
# 2013-01-01 00:00:00       27156.725263
# 2013-01-01 01:00:00       25471.200134
#
# --- Processing UK ---
#   Created: Sector_Power_Load
#   Shape: (8760, 1)
#   First values:
#                      Sector_Power_Load
# snapshot
# 2013-01-01 00:00:00       47973.970771
# 2013-01-01 01:00:00       47367.436169
#
# ======================================================================
# Successfully calculated 'Sector_Power_Load' for all countries.
# ======================================================================

# %% [markdown]
# <div style= "background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099; " >
#  <span style= "font-weight: bold; font-size: 16px; " >
# Section F Overview: DHW & Space Heating Split, Reshaping & Conversion
#  </span >
#  <div style= "border-top: 1px solid #000099; padding: 10px; " >
# This section isolates the resistive heater demands for VPP modeling.<br> It splits the total resistive load into Domestic Hot Water (DHW) and Space Heating using a seasonal-baseload approach, reshapes the DHW profile using historical 2023 reference profiles to ensure realistic diurnal patterns, and converts both thermal demands back into electrical demands using the average efficiency of the resistive heaters.
#  </div >
#  </div >
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#       F-1. Seasonal Split of Resistive Heating into DHW and Space Heating
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process splits resistive heater load profiles into <b>Domestic Hot Water (DHW)</b> and <b>Space Heating</b> components using a <b>seasonal-baseload approach</b>.<br> The split is based on the average resistive load during summer months, which is used to estimate the DHW baseline, while space heating is calculated as the residual after applying a representative diurnal profile.<br>
#     <b>Splitting Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each node, the script aggregates all resistive heater proportion columns and performs the following steps:
#             <div style="margin-left: 2em;">
#         <b>1.</b> <b>DHW Baseline:</b> Calculates the average resistive load during summer months (June, July, August) as the initial DHW baseline.<br>
#         <b>2.</b> <b>Diurnal Profile:</b> Estimates a representative 24-hour diurnal profile from the hourly means of the load data.<br>
#         <b>3.</b> <b>DHW Profile:</b> Applies the diurnal profile to the DHW baseline and smooths it over 24 hours.<br>
#         <b>4.</b> <b>Energy Preservation:</b> Scales the DHW profile to preserve the annual DHW energy.<br>
#         <b>5.</b> <b>Space Heating:</b> Calculates space heating as the residual: <b>Space Heating = Total Resistive - DHW</b>.
#             </div>
#         The resulting DHW and space heating demand profiles are added as new columns (<b>{node} DHW_demand</b> and <b>{node} SpaceHeating_demand</b>) for each processed node, enabling detailed thermal load modeling in Dispa-SET.
#         </div>
#     </div>
# </div>

# %%
### HELPER FUNCTION: SEASONAL SPLIT OF RESISTIVE HEATING
def split_heat_demand_seasonal(
    heat_series,
    summer_months=[6, 7, 8],
    smoothing_window_hours=24,
    time_step=data_target_time_step
):
    """
    Split a resistive-heater load profile into:
        1. DHW demand
        2. Space-heating demand
    The split is based on a seasonal-baseload approach:
    - The average resistive load during summer is used as the initial DHW
      baseline.
    - A representative diurnal profile is applied.
    - The DHW profile is smoothed over 24 hours.
    - Space heating is obtained as the residual.
    Parameters
    ----------
    heat_series : pandas.Series
        Total resistive-heater load for one node.
    summer_months : list
        Months considered representative of the summer DHW baseline.
    smoothing_window_hours : int
        Smoothing window expressed in hours, independent of the model
        temporal resolution.
    time_step : str
        Model temporal resolution. Expected values:
        '1h', '30min', '15min'.
    Returns
    -------
    dhw : pandas.Series
        Estimated domestic hot-water demand.
    sh : pandas.Series
        Estimated space-heating demand.
    """
    heat = heat_series.copy()
    ### 1. Ensure numeric values
    heat = pd.to_numeric(heat, errors="coerce").fillna(0.0)
    ### 2. Ensure datetime index
    if not isinstance(heat.index, pd.DatetimeIndex):
        heat.index = pd.to_datetime(heat.index)
    ### 3. Determine number of observations corresponding to 24 hours
    time_step_to_minutes = {
        "1h": 60,
        "60min": 60,
        "30min": 30,
        "15min": 15
    }
    if time_step not in time_step_to_minutes:
        raise ValueError(
            f"Unsupported time step '{time_step}'. "
            f"Expected one of: {list(time_step_to_minutes.keys())}"
        )
    observations_per_hour = 60 / time_step_to_minutes[time_step]
    smoothing_window = max(
        1,
        int(round(smoothing_window_hours * observations_per_hour))
    )
    ### 4. Estimate DHW baseline from summer months
    summer_mask = heat.index.month.isin(summer_months)
    if summer_mask.any():
        dhw_baseline = heat.loc[summer_mask].mean()
    else:
        dhw_baseline = heat.mean()
    ### If there is no resistive load, return zeros
    if dhw_baseline <= 0:
        dhw = pd.Series(0.0, index=heat.index)
        sh = pd.Series(0.0, index=heat.index)
        return dhw, sh
    ### 5. Estimate representative diurnal profile
    hourly_mean = heat.groupby(heat.index.hour).mean()
    mean_of_hourly = hourly_mean.mean()
    if mean_of_hourly > 0:
        hourly_profile = hourly_mean / mean_of_hourly
        ### Map each timestamp to its corresponding hour-of-day profile
        diurnal_factor = pd.Series(
            heat.index.hour.map(hourly_profile),
            index=heat.index
        )
        dhw = dhw_baseline * diurnal_factor
    else:
        dhw = pd.Series(
            dhw_baseline,
            index=heat.index
        )
    ### 6. Smooth DHW profile
    dhw = (
        dhw
        .rolling(
            window=smoothing_window,
            center=True,
            min_periods=1
        )
        .mean()
    )
    ### 7. Preserve the intended annual DHW energy
    target_energy = dhw_baseline * len(dhw)
    current_dhw_energy = dhw.sum()
    if current_dhw_energy > 0:
        dhw *= target_energy / current_dhw_energy
    ### 8. Space heating = residual
    sh = heat - dhw
    ### Numerical / physical correction
    sh = sh.clip(lower=0.0)
    ### 9. Ensure exact decomposition of the original resistive load
    dhw = heat - sh
    return dhw, sh
# =============================================================================
### IN-PLACE SEASONAL SPLIT OF INDIVIDUAL RESISTIVE-HEATER UNITS
# =============================================================================

for country_code, heat_dict in country_loads_time_series.items():

    for heat_category in all_heat_loads:

        ### Check that the heat category exists
        if heat_category not in heat_dict:
            continue

        df = heat_dict[heat_category]

        if df.empty:
            continue

        # ---------------------------------------------------------------------
        ### 1. Identify all resistive-heater proportion columns
        ###
        ### All year-specific units are retained:
        ###
        ### ...resistive heater-2015_proportion
        ### ...resistive heater-2019_proportion
        ### ...resistive heater-2030_proportion
        # ---------------------------------------------------------------------

        matching_cols = [
            col
            for col in df.columns
            if (
                "resistive heater" in str(col).lower()
                and "_proportion" in str(col).lower()
            )
        ]

        if not matching_cols:
            continue

        # ---------------------------------------------------------------------
        ### 2. Process each resistive-heater unit independently
        # ---------------------------------------------------------------------

        processed_units = []

        for proportion_col in matching_cols:

            ### Remove "_proportion"
            asset_name = str(proportion_col)[:-11]

            ### Remove only the final year suffix for the SOURCE SECTOR name
            ###
            ### Example:
            ### BE1 0 services urban decentral resistive heater-2019
            ###
            ### becomes:
            ###
            ### BE1 0 services urban decentral resistive heater

            source_sector = re.sub(
                r"-\d{4}$",
                "",
                asset_name
            )

            # -----------------------------------------------------------------
            ### 3. Extract the node prefix
            # -----------------------------------------------------------------

            node_match = re.match(
                r"^([A-Z]{2}\d+\s+\d+)",
                asset_name
            )

            if node_match:
                node = node_match.group(1).strip()
            else:
                node = country_code

            # -----------------------------------------------------------------
            ### 4. Get the individual resistive-heater thermal profile
            # -----------------------------------------------------------------

            heat_series = (
                pd.to_numeric(
                    df[proportion_col],
                    errors="coerce"
                )
                .fillna(0.0)
            )

            # -----------------------------------------------------------------
            ### 5. Perform seasonal DHW / space-heating split
            # -----------------------------------------------------------------

            if heat_series.sum() > 0:

                dhw, space_heating = (
                    split_heat_demand_seasonal(
                        heat_series,
                        time_step=data_target_time_step
                    )
                )

            else:

                dhw = pd.Series(
                    0.0,
                    index=df.index
                )

                space_heating = pd.Series(
                    0.0,
                    index=df.index
                )

            # -----------------------------------------------------------------
            ### 6. Store individual-unit results
            # -----------------------------------------------------------------

            df[
                f"{asset_name} DHW_demand"
            ] = dhw

            df[
                f"{asset_name} SpaceHeating_demand"
            ] = space_heating

            processed_units.append(asset_name)

        # ---------------------------------------------------------------------
        ### 7. Report
        # ---------------------------------------------------------------------

        if processed_units:

            print(
                f"✅ [{country_code}] [{heat_category}] "
                f"Seasonal split applied to "
                f"{len(processed_units)} resistive-heater units."
            )

        else:

            print(
                f"⚠️ [{country_code}] [{heat_category}] "
                f"No resistive-heater units processed."
            )


print(
    "\n============================================================"
)
print(
    "DONE: Individual resistive-heater units have been split "
    "into DHW and Space Heating."
)
print(
    "All year-specific units (e.g. 2015, 2019, 2030) are retained."
)
print(
    "============================================================"
)
# Out:
# ✅ [BE] [urban central heat] Seasonal split applied to 1 resistive-heater units.
# ✅ [BE] [services urban decentral heat] Seasonal split applied to 3 resistive-heater units.
# ✅ [BE] [services rural heat] Seasonal split applied to 1 resistive-heater units.
# ✅ [BE] [residential rural heat] Seasonal split applied to 3 resistive-heater units.
# ✅ [BE] [residential urban decentral heat] Seasonal split applied to 3 resistive-heater units.
# ✅ [FR] [urban central heat] Seasonal split applied to 1 resistive-heater units.
# ✅ [FR] [services urban decentral heat] Seasonal split applied to 3 resistive-heater units.
# ✅ [FR] [services rural heat] Seasonal split applied to 3 resistive-heater units.
# ✅ [FR] [residential rural heat] Seasonal split applied to 3 resistive-heater units.
# ✅ [FR] [residential urban decentral heat] Seasonal split applied to 3 resistive-heater units.
# ✅ [DE] [urban central heat] Seasonal split applied to 1 resistive-heater units.
# ✅ [DE] [services urban decentral heat] Seasonal split applied to 1 resistive-heater units.
# ✅ [DE] [services rural heat] Seasonal split applied to 1 resistive-heater units.
# ✅ [DE] [residential rural heat] Seasonal split applied to 1 resistive-heater units.
# ✅ [DE] [residential urban decentral heat] Seasonal split applied to 1 resistive-heater units.
# ✅ [NL] [urban central heat] Seasonal split applied to 1 resistive-heater units.
# ✅ [NL] [services urban decentral heat] Seasonal split applied to 1 resistive-heater units.
# ✅ [NL] [services rural heat] Seasonal split applied to 1 resistive-heater units.
# ✅ [NL] [residential rural heat] Seasonal split applied to 1 resistive-heater units.
# ✅ [NL] [residential urban decentral heat] Seasonal split applied to 3 resistive-heater units.
# ✅ [UK] [urban central heat] Seasonal split applied to 2 resistive-heater units.
# ✅ [UK] [services urban decentral heat] Seasonal split applied to 4 resistive-heater units.
# ✅ [UK] [services rural heat] Seasonal split applied to 6 resistive-heater units.
# ✅ [UK] [residential rural heat] Seasonal split applied to 6 resistive-heater units.
# ✅ [UK] [residential urban decentral heat] Seasonal split applied to 6 resistive-heater units.
#
# ============================================================
# DONE: Individual resistive-heater units have been split into DHW and Space Heating.
# All year-specific units (e.g. 2015, 2019, 2030) are retained.
# ============================================================

# %%
country_loads_time_series["BE"]['services urban decentral heat'].to_csv('/home/ray/Documents/Unleash/Julios_Data/Auxiliar_Documents/testing_file14.csv', index=True)

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         F-2. Reshaping DHW Profiles Using a Reference Profile
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process reshapes the <b>Domestic Hot Water (DHW) demand profiles</b> for each node using a <b>country-specific reference profile</b> (typically a 2023 historical profile). <br>The reshaping preserves the <b>total annual DHW energy</b> while imposing the <b>temporal shape</b> of the reference profile, ensuring that the resulting DHW demand follows realistic diurnal and seasonal patterns.<br>
#     <b>Reshaping Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each country and node, the script loads the country-specific reference DHW profile (e.g., <b>Database/Boundary_Sector/BoundarySectorDemand/BE/2023.csv</b>).
#         <br>
#         It then applies the <b>reshape_dhw_series</b> function, which:
#             <div style="margin-left: 2em;">
#         <b>1.</b> Extracts the total annual DHW energy from the original profile<br>
#         <b>2.</b> Maps the reference profile onto the target timestamps using <b>month + day + hour + minute</b> keys<br>
#         <b>3.</b> Normalizes the mapped reference profile to sum to 1<br>
#         <b>4.</b> Rescales the normalized shape to match the original total DHW energy<br>
#         <b>5.</b> Handles missing timestamps (e.g., February 29 in leap years) by filling with the mean reference value
#             </div>
#         The resulting reshaped DHW profiles are added as new columns (<b>{node} DHW_demand_reshaped</b>), while the original DHW columns are preserved. An energy balance check confirms that the total annual DHW energy is maintained.
#         </div>
#     </div>
# </div>

# %%
### USER SETTINGS & PATH CONFIGURATION
root_dir = dispaSET_unleash_folder_path.joinpath("Database")
### HELPER FUNCTION: RESHAPE DHW PROFILE USING A REFERENCE PROFILE
### ENERGY-PRESERVING AND TIME-STEP AWARE
def reshape_dhw_series(dhw_series, reference_series):
    """
    Reshape a DHW demand series using the temporal shape of a reference
    profile while preserving the total DHW energy of the original series.
    Parameters
    ----------
    dhw_series : pandas.Series
        Target DHW demand series to be reshaped.
    reference_series : pandas.Series
        Reference DHW profile, normally the country 2023 profile.
    Returns
    -------
    pandas.Series
        Reshaped DHW profile with the same index as dhw_series and exactly
        the same total energy as the original DHW series.
    """
    ### 1. Copy and clean target DHW series
    dhw = pd.to_numeric(
        dhw_series,
        errors="coerce"
    ).fillna(0.0)
    ### Make sure the index is datetime
    if not isinstance(dhw.index, pd.DatetimeIndex):
        dhw.index = pd.to_datetime(dhw.index)
    ### Remove timezone if present
    if dhw.index.tz is not None:
        dhw.index = dhw.index.tz_localize(None)
    ### Total DHW energy to preserve
    target_energy = dhw.sum()
    ### If there is no DHW energy, return zeros
    if target_energy <= 0:
        return pd.Series(
            0.0,
            index=dhw.index
        )
    ### 2. Clean reference profile
    reference = pd.to_numeric(
        reference_series,
        errors="coerce"
    ).fillna(0.0)
    ### Make sure reference index is datetime
    if not isinstance(reference.index, pd.DatetimeIndex):
        reference.index = pd.to_datetime(reference.index)
    ### Remove timezone if present
    if reference.index.tz is not None:
        reference.index = reference.index.tz_localize(None)
    ### Remove negative values
    reference = reference.clip(lower=0.0)
    if reference.sum() <= 0:
        print(
            "   ⚠️ Reference profile has zero energy. "
            "Original DHW profile will be retained."
        )
        return dhw.copy()
    ### 3. Convert reference profile to the same temporal resolution
    ### Determine target temporal resolution from the target index.
    ### This assumes a regular time series, which is the case for the
    ### PyPSA / Dispa-SET profiles being processed here.
    if len(dhw.index) > 1:
        target_delta = (
            dhw.index[1:] - dhw.index[:-1]
        ).median()
        target_minutes = target_delta.total_seconds() / 60
    else:
        target_minutes = None
    ### If the reference and target have different numbers of observations,
    ### interpolate the reference profile to the target temporal resolution.
    if target_minutes is not None and len(reference.index) > 1:
        reference_delta = (
            reference.index[1:] - reference.index[:-1]
        ).median()
        reference_minutes = (
            reference_delta.total_seconds() / 60
        )
        if reference_minutes != target_minutes:
            reference = (
                reference
                .resample(
                    f"{int(target_minutes)}min"
                )
                .mean()
                .interpolate(method="time")
            )
    ### 4. Build an annual temporal shape
    ### Instead of simply truncating/repeating the reference profile based
    ### on length, match the reference according to:
    ###       month + day + hour + minute
    ### This allows a 2023 reference profile to be applied to another year.
    reference_shape = reference.copy()
    reference_shape.index = pd.MultiIndex.from_arrays(
        [
            reference_shape.index.month,
            reference_shape.index.day,
            reference_shape.index.hour,
            reference_shape.index.minute
        ],
        names=[
            "month",
            "day",
            "hour",
            "minute"
        ]
    )
    ### Remove duplicated timestamps/components if necessary
    reference_shape = reference_shape[
        ~reference_shape.index.duplicated(
            keep="first"
        )
    ]
    ### 5. Map reference profile onto target timestamps
    target_keys = pd.MultiIndex.from_arrays(
        [
            dhw.index.month,
            dhw.index.day,
            dhw.index.hour,
            dhw.index.minute
        ],
        names=[
            "month",
            "day",
            "hour",
            "minute"
        ]
    )
    reshaped_shape = reference_shape.reindex(
        target_keys
    )
    ### 6. Handle missing timestamps
    ### The main case is a leap-year target containing February 29,
    ### while the 2023 reference does not contain February 29.
    ### Missing values are filled using interpolation over the sequence
    ### of the reference profile.
    if reshaped_shape.isna().any():
        reference_values = reference_shape.to_numpy(
            dtype=float
        )
        valid_reference_values = reference_values[
            ~np.isnan(reference_values)
        ]
        if len(valid_reference_values) > 0:
            missing_positions = np.isnan(
                reshaped_shape.to_numpy(
                    dtype=float
                )
            )
            filled_values = reshaped_shape.to_numpy(
                dtype=float
            )
            filled_values[missing_positions] = np.mean(
                valid_reference_values
            )
            reshaped_shape = pd.Series(
                filled_values,
                index=target_keys
            )
    ### Restore target datetime index
    reshaped_shape.index = dhw.index
    ### Remove negative values
    reshaped_shape = reshaped_shape.clip(
        lower=0.0
    )
    ### 7. Normalize the reference shape
    reference_sum = reshaped_shape.sum()
    if reference_sum <= 0:
        print(
            "   ⚠️ Mapped reference profile has zero energy. "
            "Original DHW profile will be retained."
        )
        return dhw.copy()
    normalized_shape = (
        reshaped_shape / reference_sum
    )
    ### 8. Rescale reference shape to original DHW energy
    reshaped_dhw = (
        normalized_shape * target_energy
    )
    ### 9. Final energy correction
    reshaped_energy = reshaped_dhw.sum()
    if reshaped_energy > 0:
        reshaped_dhw *= (
            target_energy / reshaped_energy
        )
    ### Make sure index is exactly the original target index
    reshaped_dhw.index = dhw.index
    return reshaped_dhw
# =============================================================================
### MAIN PROCESSING:
### RESHAPE INDIVIDUAL RESISTIVE-HEATER DHW DEMAND
# =============================================================================

for country_code, heat_dict in country_loads_time_series.items():

    # -------------------------------------------------------------------------
    ### 1. Load country-specific 2023 reference profile
    # -------------------------------------------------------------------------

    reference_profile_path = (
        f"{root_dir}/Boundary_Sector/"
        f"BoundarySectorDemand/{country_code}/2023.csv"
    )

    if not os.path.exists(reference_profile_path):
        print(
            f"⚠️ [{country_code}] Reference file not found:"
            f"\n   {reference_profile_path}"
        )
        continue

    # -------------------------------------------------------------------------
    ### Read reference profile
    # -------------------------------------------------------------------------

    ref_df = pd.read_csv(
        reference_profile_path,
        index_col=0,
        parse_dates=True
    )

    # -------------------------------------------------------------------------
    ### Use first data column as reference DHW profile
    # -------------------------------------------------------------------------

    ref_series = ref_df.iloc[:, 0].copy()

    # -------------------------------------------------------------------------
    ### Ensure datetime index
    # -------------------------------------------------------------------------

    if not isinstance(
        ref_series.index,
        pd.DatetimeIndex
    ):
        ref_series.index = pd.to_datetime(
            ref_series.index
        )

    # -------------------------------------------------------------------------
    ### Remove timezone if present
    # -------------------------------------------------------------------------

    if ref_series.index.tz is not None:
        ref_series.index = (
            ref_series.index.tz_localize(None)
        )

    print(
        f"\n📌 [{country_code}] "
        f"Reference DHW profile loaded:"
        f" {len(ref_series)} observations"
    )

    # -------------------------------------------------------------------------
    ### 2. Process every heat category
    # -------------------------------------------------------------------------

    for heat_category in all_heat_loads:

        if heat_category not in heat_dict:
            continue

        df = heat_dict[heat_category]

        if df.empty:
            continue

        # ---------------------------------------------------------------------
        ### 3. Find individual resistive-heater DHW columns
        ###
        ### Examples:
        ###
        ### BE1 0 services urban decentral resistive heater-2015 DHW_demand
        ### BE1 0 services urban decentral resistive heater-2019 DHW_demand
        ### BE1 0 services urban decentral resistive heater-2030 DHW_demand
        ###
        ### Every unit is processed independently.
        # ---------------------------------------------------------------------

        dhw_cols = [
            col
            for col in df.columns
            if (
                "resistive heater" in str(col).lower()
                and str(col).endswith("DHW_demand")
            )
        ]

        if not dhw_cols:
            continue

        # ---------------------------------------------------------------------
        ### 4. Process every individual resistive-heater unit
        # ---------------------------------------------------------------------

        processed_units = []

        for dhw_col in dhw_cols:

            # -----------------------------------------------------------------
            ### Extract the original asset name
            ###
            ### Example:
            ### BE1 0 services urban decentral resistive heater-2019 DHW_demand
            ###
            ### becomes:
            ### BE1 0 services urban decentral resistive heater-2019
            # -----------------------------------------------------------------

            asset_name = str(dhw_col).replace(
                " DHW_demand",
                ""
            )

            # -----------------------------------------------------------------
            ### Extract the source-sector name
            ###
            ### This removes ONLY the final year suffix.
            ###
            ### -2015 -> source sector
            ### -2019 -> source sector
            ### -2030 -> source sector
            ###
            ### This is only for identification/matching later.
            # -----------------------------------------------------------------

            source_sector = re.sub(
                r"-\d{4}$",
                "",
                asset_name
            )

            # -----------------------------------------------------------------
            ### 5. Extract node prefix
            # -----------------------------------------------------------------

            node_match = re.match(
                r"^([A-Z]{2}\d+\s+\d+)",
                asset_name
            )

            if node_match:
                node = node_match.group(1).strip()
            else:
                node = country_code

            # -----------------------------------------------------------------
            ### 6. Get individual DHW profile
            # -----------------------------------------------------------------

            dhw_series = (
                pd.to_numeric(
                    df[dhw_col],
                    errors="coerce"
                )
                .fillna(0.0)
            )

            # -----------------------------------------------------------------
            ### 7. Reshape individual DHW profile
            # -----------------------------------------------------------------

            if dhw_series.sum() > 0:

                reshaped_dhw = reshape_dhw_series(
                    dhw_series,
                    ref_series
                )

            else:

                reshaped_dhw = pd.Series(
                    0.0,
                    index=df.index
                )

            # -----------------------------------------------------------------
            ### 8. Create individual reshaped DHW column
            # -----------------------------------------------------------------

            reshaped_column_name = (
                f"{asset_name} DHW_demand_reshaped"
            )

            df[
                reshaped_column_name
            ] = reshaped_dhw

            # -----------------------------------------------------------------
            ### 9. Energy balance check
            # -----------------------------------------------------------------

            original_energy = dhw_series.sum()
            reshaped_energy = reshaped_dhw.sum()

            balanced = np.isclose(
                original_energy,
                reshaped_energy,
                rtol=1e-9,
                atol=1e-9
            )

            print(
                f"   ✅ [{country_code}] "
                f"[{heat_category}] "
                f"[{node}] "
                f"[{asset_name}] "
                f"DHW reshaped | "
                f"Source sector: {source_sector} | "
                f"Original: {original_energy:.6f} | "
                f"Reshaped: {reshaped_energy:.6f} | "
                f"Balanced: {balanced}"
            )

            processed_units.append(
                asset_name
            )

        # ---------------------------------------------------------------------
        ### 10. Report processed units
        # ---------------------------------------------------------------------

        if processed_units:

            print(
                f"✅ [{country_code}] "
                f"[{heat_category}] "
                f"Reshaped DHW for "
                f"{len(processed_units)} individual "
                f"resistive-heater units."
            )

        else:

            print(
                f"⚠️ [{country_code}] "
                f"[{heat_category}] "
                f"No individual DHW units could be processed."
            )


# =============================================================================
### FINAL REPORT
# =============================================================================

print(
    "\n============================================================"
)

print(
    "DONE: Individual resistive-heater DHW demand profiles "
    "have been reshaped."
)

print(
    "Each year-specific unit (2015, 2019, 2030, etc.) "
    "was processed independently."
)

print(
    "The original DHW_demand columns have been preserved."
)

print(
    "New individual columns ending in "
    "'DHW_demand_reshaped' have been added."
)

print(
    "Node-level DHW_demand_reshaped columns are no longer "
    "used for the VPP calculation."
)

print(
    "============================================================"
)
# Out:
# 📌 [BE] Reference DHW profile loaded: 8760 observations
#    ✅ [BE] [urban central heat] [BE1 0] [BE1 0 urban central resistive heater-2030] DHW reshaped | Source sector: BE1 0 urban central resistive heater | Original: 933778.252973 | Reshaped: 933778.252973 | Balanced: True
# ✅ [BE] [urban central heat] Reshaped DHW for 1 individual resistive-heater units.
#    ✅ [BE] [services urban decentral heat] [BE1 0] [BE1 0 services urban decentral resistive heater-2030] DHW reshaped | Source sector: BE1 0 services urban decentral resistive heater | Original: 66.932110 | Reshaped: 66.932110 | Balanced: True
#    ✅ [BE] [services urban decentral heat] [BE1 0] [BE1 0 services urban decentral resistive heater-2015] DHW reshaped | Source sector: BE1 0 services urban decentral resistive heater | Original: 143668.726422 | Reshaped: 143668.726422 | Balanced: True
#    ✅ [BE] [services urban decentral heat] [BE1 0] [BE1 0 services urban decentral resistive heater-2019] DHW reshaped | Source sector: BE1 0 services urban decentral resistive heater | Original: 114934.981138 | Reshaped: 114934.981138 | Balanced: True
# ✅ [BE] [services urban decentral heat] Reshaped DHW for 3 individual resistive-heater units.
#    ✅ [BE] [services rural heat] [BE1 0] [BE1 0 services rural resistive heater-2030] DHW reshaped | Source sector: BE1 0 services rural resistive heater | Original: 4516.667550 | Reshaped: 4516.667550 | Balanced: True
# ✅ [BE] [services rural heat] Reshaped DHW for 1 individual resistive-heater units.
#    ✅ [BE] [residential rural heat] [BE1 0] [BE1 0 residential rural resistive heater-2030] DHW reshaped | Source sector: BE1 0 residential rural resistive heater | Original: 122.677164 | Reshaped: 122.677164 | Balanced: True
#    ✅ [BE] [residential rural heat] [BE1 0] [BE1 0 residential rural resistive heater-2015] DHW reshaped | Source sector: BE1 0 residential rural resistive heater | Original: 90602.172532 | Reshaped: 90602.172532 | Balanced: True
#    ✅ [BE] [residential rural heat] [BE1 0] [BE1 0 residential rural resistive heater-2019] DHW reshaped | Source sector: BE1 0 residential rural resistive heater | Original: 72481.738026 | Reshaped: 72481.738026 | Balanced: True
# ✅ [BE] [residential rural heat] Reshaped DHW for 3 individual resistive-heater units.
#    ✅ [BE] [residential urban decentral heat] [BE1 0] [BE1 0 residential urban decentral resistive heater-2030] DHW reshaped | Source sector: BE1 0 residential urban decentral resistive heater | Original: 144.498504 | Reshaped: 144.498504 | Balanced: True
#    ✅ [BE] [residential urban decentral heat] [BE1 0] [BE1 0 residential urban decentral resistive heater-2015] DHW reshaped | Source sector: BE1 0 residential urban decentral resistive heater | Original: 1869706.872115 | Reshaped: 1869706.872115 | Balanced: True
#    ✅ [BE] [residential urban decentral heat] [BE1 0] [BE1 0 residential urban decentral resistive heater-2019] DHW reshaped | Source sector: BE1 0 residential urban decentral resistive heater | Original: 1495765.497692 | Reshaped: 1495765.497692 | Balanced: True
# ✅ [BE] [residential urban decentral heat] Reshaped DHW for 3 individual resistive-heater units.
#
# 📌 [FR] Reference DHW profile loaded: 8760 observations
#    ✅ [FR] [urban central heat] [FR1 0] [FR1 0 urban central resistive heater-2030] DHW reshaped | Source sector: FR1 0 urban central resistive heater | Original: 1974492.008481 | Reshaped: 1974492.008481 | Balanced: True
# ✅ [FR] [urban central heat] Reshaped DHW for 1 individual resistive-heater units.
#    ✅ [FR] [services urban decentral heat] [FR1 0] [FR1 0 services urban decentral resistive heater-2030] DHW reshaped | Source sector: FR1 0 services urban decentral resistive heater | Original: 36.510798 | Reshaped: 36.510798 | Balanced: True
#    ✅ [FR] [services urban decentral heat] [FR1 0] [FR1 0 services urban decentral resistive heater-2015] DHW reshaped | Source sector: FR1 0 services urban decentral resistive heater | Original: 6383163.981759 | Reshaped: 6383163.981759 | Balanced: True
#    ✅ [FR] [services urban decentral heat] [FR1 0] [FR1 0 services urban decentral resistive heater-2019] DHW reshaped | Source sector: FR1 0 services urban decentral resistive heater | Original: 5106531.185407 | Reshaped: 5106531.185407 | Balanced: True
# ✅ [FR] [services urban decentral heat] Reshaped DHW for 3 individual resistive-heater units.
#    ✅ [FR] [services rural heat] [FR1 0] [FR1 0 services rural resistive heater-2030] DHW reshaped | Source sector: FR1 0 services rural resistive heater | Original: 133.591848 | Reshaped: 133.591848 | Balanced: True
#    ✅ [FR] [services rural heat] [FR1 0] [FR1 0 services rural resistive heater-2015] DHW reshaped | Source sector: FR1 0 services rural resistive heater | Original: 5298190.444598 | Reshaped: 5298190.444598 | Balanced: True
#    ✅ [FR] [services rural heat] [FR1 0] [FR1 0 services rural resistive heater-2019] DHW reshaped | Source sector: FR1 0 services rural resistive heater | Original: 4238552.355679 | Reshaped: 4238552.355679 | Balanced: True
# ✅ [FR] [services rural heat] Reshaped DHW for 3 individual resistive-heater units.
#    ✅ [FR] [residential rural heat] [FR1 0] [FR1 0 residential rural resistive heater-2030] DHW reshaped | Source sector: FR1 0 residential rural resistive heater | Original: 32.755011 | Reshaped: 32.755011 | Balanced: True
#    ✅ [FR] [residential rural heat] [FR1 0] [FR1 0 residential rural resistive heater-2015] DHW reshaped | Source sector: FR1 0 residential rural resistive heater | Original: 3686945.357581 | Reshaped: 3686945.357581 | Balanced: True
#    ✅ [FR] [residential rural heat] [FR1 0] [FR1 0 residential rural resistive heater-2019] DHW reshaped | Source sector: FR1 0 residential rural resistive heater | Original: 2949556.286065 | Reshaped: 2949556.286065 | Balanced: True
# ✅ [FR] [residential rural heat] Reshaped DHW for 3 individual resistive-heater units.
#    ✅ [FR] [residential urban decentral heat] [FR1 0] [FR1 0 residential urban decentral resistive heater-2030] DHW reshaped | Source sector: FR1 0 residential urban decentral resistive heater | Original: 28.720555 | Reshaped: 28.720555 | Balanced: True
#    ✅ [FR] [residential urban decentral heat] [FR1 0] [FR1 0 residential urban decentral resistive heater-2015] DHW reshaped | Source sector: FR1 0 residential urban decentral resistive heater | Original: 13447128.146544 | Reshaped: 13447128.146544 | Balanced: True
#    ✅ [FR] [residential urban decentral heat] [FR1 0] [FR1 0 residential urban decentral resistive heater-2019] DHW reshaped | Source sector: FR1 0 residential urban decentral resistive heater | Original: 10757702.517235 | Reshaped: 10757702.517235 | Balanced: True
# ✅ [FR] [residential urban decentral heat] Reshaped DHW for 3 individual resistive-heater units.
#
# 📌 [DE] Reference DHW profile loaded: 8760 observations
#    ✅ [DE] [urban central heat] [DE1 0] [DE1 0 urban central resistive heater-2030] DHW reshaped | Source sector: DE1 0 urban central resistive heater | Original: 9392850.812406 | Reshaped: 9392850.812406 | Balanced: True
# ✅ [DE] [urban central heat] Reshaped DHW for 1 individual resistive-heater units.
#    ✅ [DE] [services urban decentral heat] [DE1 0] [DE1 0 services urban decentral resistive heater-2030] DHW reshaped | Source sector: DE1 0 services urban decentral resistive heater | Original: 1836131.411603 | Reshaped: 1836131.411603 | Balanced: True
# ✅ [DE] [services urban decentral heat] Reshaped DHW for 1 individual resistive-heater units.
#    ✅ [DE] [services rural heat] [DE1 0] [DE1 0 services rural resistive heater-2030] DHW reshaped | Source sector: DE1 0 services rural resistive heater | Original: 7776814.216522 | Reshaped: 7776814.216522 | Balanced: True
# ✅ [DE] [services rural heat] Reshaped DHW for 1 individual resistive-heater units.
#    ✅ [DE] [residential rural heat] [DE1 0] [DE1 0 residential rural resistive heater-2030] DHW reshaped | Source sector: DE1 0 residential rural resistive heater | Original: 4372779.632739 | Reshaped: 4372779.632739 | Balanced: True
# ✅ [DE] [residential rural heat] Reshaped DHW for 1 individual resistive-heater units.
#    ✅ [DE] [residential urban decentral heat] [DE1 0] [DE1 0 residential urban decentral resistive heater-2030] DHW reshaped | Source sector: DE1 0 residential urban decentral resistive heater | Original: 5194457.454499 | Reshaped: 5194457.454499 | Balanced: True
# ✅ [DE] [residential urban decentral heat] Reshaped DHW for 1 individual resistive-heater units.
#
# 📌 [NL] Reference DHW profile loaded: 8760 observations
#    ✅ [NL] [urban central heat] [NL1 0] [NL1 0 urban central resistive heater-2030] DHW reshaped | Source sector: NL1 0 urban central resistive heater | Original: 7991663.584097 | Reshaped: 7991663.584097 | Balanced: True
# ✅ [NL] [urban central heat] Reshaped DHW for 1 individual resistive-heater units.
#    ✅ [NL] [services urban decentral heat] [NL1 0] [NL1 0 services urban decentral resistive heater-2030] DHW reshaped | Source sector: NL1 0 services urban decentral resistive heater | Original: 852741.589544 | Reshaped: 852741.589544 | Balanced: True
# ✅ [NL] [services urban decentral heat] Reshaped DHW for 1 individual resistive-heater units.
#    ✅ [NL] [services rural heat] [NL1 0] [NL1 0 services rural resistive heater-2030] DHW reshaped | Source sector: NL1 0 services rural resistive heater | Original: 29277.120911 | Reshaped: 29277.120911 | Balanced: True
# ✅ [NL] [services rural heat] Reshaped DHW for 1 individual resistive-heater units.
#    ✅ [NL] [residential rural heat] [NL1 0] [NL1 0 residential rural resistive heater-2030] DHW reshaped | Source sector: NL1 0 residential rural resistive heater | Original: 1938.835565 | Reshaped: 1938.835565 | Balanced: True
# ✅ [NL] [residential rural heat] Reshaped DHW for 1 individual resistive-heater units.
#    ✅ [NL] [residential urban decentral heat] [NL1 0] [NL1 0 residential urban decentral resistive heater-2030] DHW reshaped | Source sector: NL1 0 residential urban decentral resistive heater | Original: 2614908.625073 | Reshaped: 2614908.625073 | Balanced: True
#    ✅ [NL] [residential urban decentral heat] [NL1 0] [NL1 0 residential urban decentral resistive heater-2015] DHW reshaped | Source sector: NL1 0 residential urban decentral resistive heater | Original: 34571.147608 | Reshaped: 34571.147608 | Balanced: True
#    ✅ [NL] [residential urban decentral heat] [NL1 0] [NL1 0 residential urban decentral resistive heater-2019] DHW reshaped | Source sector: NL1 0 residential urban decentral resistive heater | Original: 27656.918086 | Reshaped: 27656.918086 | Balanced: True
# ✅ [NL] [residential urban decentral heat] Reshaped DHW for 3 individual resistive-heater units.
#
# 📌 [UK] Reference DHW profile loaded: 8760 observations
#    ✅ [UK] [urban central heat] [GB0 0] [GB0 0 urban central resistive heater-2030] DHW reshaped | Source sector: GB0 0 urban central resistive heater | Original: 6001859.232387 | Reshaped: 6001859.232387 | Balanced: True
#    ✅ [UK] [urban central heat] [GB2 0] [GB2 0 urban central resistive heater-2030] DHW reshaped | Source sector: GB2 0 urban central resistive heater | Original: 232286.687141 | Reshaped: 232286.687141 | Balanced: True
# ✅ [UK] [urban central heat] Reshaped DHW for 2 individual resistive-heater units.
#    ✅ [UK] [services urban decentral heat] [GB0 0] [GB0 0 services urban decentral resistive heater-2030] DHW reshaped | Source sector: GB0 0 services urban decentral resistive heater | Original: 4748460.112980 | Reshaped: 4748460.112980 | Balanced: True
#    ✅ [UK] [services urban decentral heat] [GB2 0] [GB2 0 services urban decentral resistive heater-2030] DHW reshaped | Source sector: GB2 0 services urban decentral resistive heater | Original: 183192.789932 | Reshaped: 183192.789932 | Balanced: True
#    ✅ [UK] [services urban decentral heat] [GB0 0] [GB0 0 services urban decentral resistive heater-2015] DHW reshaped | Source sector: GB0 0 services urban decentral resistive heater | Original: 1529816.939985 | Reshaped: 1529816.939985 | Balanced: True
#    ✅ [UK] [services urban decentral heat] [GB0 0] [GB0 0 services urban decentral resistive heater-2019] DHW reshaped | Source sector: GB0 0 services urban decentral resistive heater | Original: 1223853.551988 | Reshaped: 1223853.551988 | Balanced: True
# ✅ [UK] [services urban decentral heat] Reshaped DHW for 4 individual resistive-heater units.
#    ✅ [UK] [services rural heat] [GB0 0] [GB0 0 services rural resistive heater-2030] DHW reshaped | Source sector: GB0 0 services rural resistive heater | Original: 1021846.090852 | Reshaped: 1021846.090852 | Balanced: True
#    ✅ [UK] [services rural heat] [GB2 0] [GB2 0 services rural resistive heater-2030] DHW reshaped | Source sector: GB2 0 services rural resistive heater | Original: 658417.254186 | Reshaped: 658417.254186 | Balanced: True
#    ✅ [UK] [services rural heat] [GB0 0] [GB0 0 services rural resistive heater-2015] DHW reshaped | Source sector: GB0 0 services rural resistive heater | Original: 1053973.196298 | Reshaped: 1053973.196298 | Balanced: True
#    ✅ [UK] [services rural heat] [GB2 0] [GB2 0 services rural resistive heater-2015] DHW reshaped | Source sector: GB2 0 services rural resistive heater | Original: 117757.200004 | Reshaped: 117757.200004 | Balanced: True
#    ✅ [UK] [services rural heat] [GB0 0] [GB0 0 services rural resistive heater-2019] DHW reshaped | Source sector: GB0 0 services rural resistive heater | Original: 843178.557039 | Reshaped: 843178.557039 | Balanced: True
#    ✅ [UK] [services rural heat] [GB2 0] [GB2 0 services rural resistive heater-2019] DHW reshaped | Source sector: GB2 0 services rural resistive heater | Original: 94205.760003 | Reshaped: 94205.760003 | Balanced: True
# ✅ [UK] [services rural heat] Reshaped DHW for 6 individual resistive-heater units.
#    ✅ [UK] [residential rural heat] [GB0 0] [GB0 0 residential rural resistive heater-2030] DHW reshaped | Source sector: GB0 0 residential rural resistive heater | Original: 1700.387735 | Reshaped: 1700.387735 | Balanced: True
#    ✅ [UK] [residential rural heat] [GB2 0] [GB2 0 residential rural resistive heater-2030] DHW reshaped | Source sector: GB2 0 residential rural resistive heater | Original: 649414.004379 | Reshaped: 649414.004379 | Balanced: True
#    ✅ [UK] [residential rural heat] [GB0 0] [GB0 0 residential rural resistive heater-2015] DHW reshaped | Source sector: GB0 0 residential rural resistive heater | Original: 3406013.598464 | Reshaped: 3406013.598464 | Balanced: True
#    ✅ [UK] [residential rural heat] [GB2 0] [GB2 0 residential rural resistive heater-2015] DHW reshaped | Source sector: GB2 0 residential rural resistive heater | Original: 380543.476760 | Reshaped: 380543.476760 | Balanced: True
#    ✅ [UK] [residential rural heat] [GB0 0] [GB0 0 residential rural resistive heater-2019] DHW reshaped | Source sector: GB0 0 residential rural resistive heater | Original: 2724810.878771 | Reshaped: 2724810.878771 | Balanced: True
#    ✅ [UK] [residential rural heat] [GB2 0] [GB2 0 residential rural resistive heater-2019] DHW reshaped | Source sector: GB2 0 residential rural resistive heater | Original: 304434.781408 | Reshaped: 304434.781408 | Balanced: True
# ✅ [UK] [residential rural heat] Reshaped DHW for 6 individual resistive-heater units.
#    ✅ [UK] [residential urban decentral heat] [GB0 0] [GB0 0 residential urban decentral resistive heater-2030] DHW reshaped | Source sector: GB0 0 residential urban decentral resistive heater | Original: 2696.143040 | Reshaped: 2696.143040 | Balanced: True
#    ✅ [UK] [residential urban decentral heat] [GB2 0] [GB2 0 residential urban decentral resistive heater-2030] DHW reshaped | Source sector: GB2 0 residential urban decentral resistive heater | Original: 631228.372363 | Reshaped: 631228.372363 | Balanced: True
#    ✅ [UK] [residential urban decentral heat] [GB0 0] [GB0 0 residential urban decentral resistive heater-2015] DHW reshaped | Source sector: GB0 0 residential urban decentral resistive heater | Original: 15186467.762110 | Reshaped: 15186467.762110 | Balanced: True
#    ✅ [UK] [residential urban decentral heat] [GB2 0] [GB2 0 residential urban decentral resistive heater-2015] DHW reshaped | Source sector: GB2 0 residential urban decentral resistive heater | Original: 212225.229163 | Reshaped: 212225.229163 | Balanced: True
#    ✅ [UK] [residential urban decentral heat] [GB0 0] [GB0 0 residential urban decentral resistive heater-2019] DHW reshaped | Source sector: GB0 0 residential urban decentral resistive heater | Original: 12149174.209688 | Reshaped: 12149174.209688 | Balanced: True
#    ✅ [UK] [residential urban decentral heat] [GB2 0] [GB2 0 residential urban decentral resistive heater-2019] DHW reshaped | Source sector: GB2 0 residential urban decentral resistive heater | Original: 169780.183331 | Reshaped: 169780.183331 | Balanced: True
# ✅ [UK] [residential urban decentral heat] Reshaped DHW for 6 individual resistive-heater units.
#
# ============================================================
# DONE: Individual resistive-heater DHW demand profiles have been reshaped.
# Each year-specific unit (2015, 2019, 2030, etc.) was processed independently.
# The original DHW_demand columns have been preserved.
# New individual columns ending in 'DHW_demand_reshaped' have been added.
# Node-level DHW_demand_reshaped columns are no longer used for the VPP calculation.
# ============================================================

# %%
country_loads_time_series["BE"]['services urban decentral heat'].to_csv('/home/ray/Documents/Unleash/Julios_Data/Auxiliar_Documents/testing_file14.csv', index=True)

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         F-03. Converting Thermal Demand to Electrical Demand Using Resistive Heater Efficiencies
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process converts the <b>thermal demand</b> (Space Heating and DHW) into <b>electrical demand</b> by applying the <b>average efficiency</b> of resistive heaters for each node. <br>The conversion uses static efficiency values from the country-specific PyPSA CSV files to calculate the electrical input required to meet the thermal demand.<br>
#     <b>Conversion Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each country, heat load category, and demand type (SpaceHeating_demand, DHW_demand_reshaped), the script identifies all <b>resistive heater proportion columns</b> belonging to the same node.<br>
#             For each resistive heater asset, it finds the matching bus and retrieves the corresponding <b>static efficiency</b> from the metadata.
#         <br>The <b>average efficiency</b> of all resistive heaters in that node is calculated, and the thermal demand is divided by this average to obtain the <b>electrical demand</b>:
#             <div style=" text-align: center; font-size: 14px;">
#         <b>Electrical Demand = Thermal Demand / Average Efficiency</b><br>
#             </div>
#         The resulting electrical demand profiles are added as new columns (<b>{node} {demand_type}_/Efficiency</b>), ensuring that resistive heater loads are correctly represented as electrical consumption in Dispa-SET.
#         </div>
#     </div>
# </div>

# %%
# =============================================================================
### MAP PYPSA BUS COLUMNS TO THEIR CORRESPONDING EFFICIENCY PARAMETERS
# =============================================================================

bus_to_eff_map = {
    "bus":  "efficiency",
    "bus0": "efficiency",
    "bus1": "efficiency",
    "bus2": "efficiency2",
    "bus3": "efficiency3",
    "bus4": "efficiency4",
}


# =============================================================================
### DEMAND TYPES TO PROCESS
# =============================================================================

demand_types = [
    "SpaceHeating_demand",
    "DHW_demand_reshaped",
]


# =============================================================================
### IN-PLACE EFFICIENCY CONVERSION
### ONLY RESISTIVE HEATERS ARE CONSIDERED
###
### The required electrical/input power is calculated individually:
###
###     Electrical/Input demand = Thermal demand / efficiency
###
### Each resistive-heater unit keeps its own efficiency.
###
### Example:
###
###     Unit A: DHW / 0.90
###     Unit B: DHW / 0.99
###
### The profiles are NOT combined before applying efficiency.
# =============================================================================

for country, loads_dict in country_loads_time_series.items():

    print(
        f"\n--- Processing Country: {country} ---"
    )

    # -------------------------------------------------------------------------
    ### LOAD COUNTRY-SPECIFIC POWER-PLANT METADATA
    # -------------------------------------------------------------------------

    power_plants_file = os.path.join(
        pypsa_raw_data_folder_path,
        pypsa_scenario,
        "PowerPlants",
        data_target_year,
        country,
        f"pypsa_power_plants_{country}_{data_target_year}.csv"
    )

    print(
        f"  Loading metadata from:"
    )

    print(
        f"  {power_plants_file}"
    )

    master_df = pd.read_csv(
        power_plants_file
    )

    master_df = master_df.set_index(
        "name"
    )

    # -------------------------------------------------------------------------
    ### PROCESS EACH HEAT CATEGORY
    # -------------------------------------------------------------------------

    for current_heat_load, ts_df in loads_dict.items():

        if ts_df.empty:
            continue

        # ---------------------------------------------------------------------
        ### PROCESS SPACE HEATING AND DHW
        # ---------------------------------------------------------------------

        for demand_type in demand_types:

            # -----------------------------------------------------------------
            ### FIND INDIVIDUAL RESISTIVE-HEATER DEMAND COLUMNS
            ###
            ### For SpaceHeating_demand:
            ###
            ### BE1 0 services urban decentral resistive heater-2015
            ### SpaceHeating_demand
            ###
            ### For DHW:
            ###
            ### BE1 0 services urban decentral resistive heater-2015
            ### DHW_demand_reshaped
            # -----------------------------------------------------------------

            if demand_type == "SpaceHeating_demand":

                demand_cols = [
                    col
                    for col in ts_df.columns
                    if (
                        "resistive heater" in str(col).lower()
                        and str(col).endswith(
                            "SpaceHeating_demand"
                        )
                    )
                ]

            else:

                demand_cols = [
                    col
                    for col in ts_df.columns
                    if (
                        "resistive heater" in str(col).lower()
                        and str(col).endswith(
                            "DHW_demand_reshaped"
                        )
                    )
                ]

            if not demand_cols:
                continue

            # -----------------------------------------------------------------
            ### PROCESS EACH INDIVIDUAL RESISTIVE-HEATER UNIT
            # -----------------------------------------------------------------

            processed_units = []

            for demand_col in demand_cols:

                # -------------------------------------------------------------
                ### EXTRACT ORIGINAL ASSET NAME
                ###
                ### Example:
                ###
                ### BE1 0 services urban decentral resistive heater-2019
                ### DHW_demand_reshaped
                ###
                ### becomes:
                ###
                ### BE1 0 services urban decentral resistive heater-2019
                # -------------------------------------------------------------

                if demand_type == "SpaceHeating_demand":

                    asset_name = str(
                        demand_col
                    ).replace(
                        " SpaceHeating_demand",
                        ""
                    )

                else:

                    asset_name = str(
                        demand_col
                    ).replace(
                        " DHW_demand_reshaped",
                        ""
                    )

                # -------------------------------------------------------------
                ### NORMALIZED SOURCE-SECTOR NAME
                ###
                ### This removes only the final year suffix.
                ###
                ### Example:
                ###
                ### ...resistive heater-2015
                ### ...resistive heater-2019
                ### ...resistive heater-2030
                ###
                ### all become:
                ###
                ### ...resistive heater
                # -------------------------------------------------------------

                source_sector = re.sub(
                    r"-\d{4}$",
                    "",
                    asset_name
                )

                # -------------------------------------------------------------
                ### EXTRACT NODE PREFIX
                # -------------------------------------------------------------

                node_match = re.match(
                    r"^([A-Z]{2}\d+\s+\d+)",
                    asset_name
                )

                if node_match:

                    node_prefix = (
                        node_match.group(1).strip()
                    )

                else:

                    node_prefix = country

                # -------------------------------------------------------------
                ### FIND EXACT ASSET IN COUNTRY METADATA
                # -------------------------------------------------------------

                if asset_name not in master_df.index:

                    print(
                        f"  ⚠️ [{current_heat_load}] "
                        f"{demand_type} | "
                        f"Asset '{asset_name}' "
                        f"not found in metadata."
                    )

                    continue

                asset_row = master_df.loc[
                    asset_name
                ]

                # -------------------------------------------------------------
                ### FIND THE BUS ASSOCIATED WITH THE CURRENT HEAT LOAD
                ###
                ### This determines which efficiency column is required:
                ###
                ### bus  -> efficiency
                ### bus0 -> efficiency
                ### bus1 -> efficiency
                ### bus2 -> efficiency2
                ### bus3 -> efficiency3
                ### bus4 -> efficiency4
                # -------------------------------------------------------------

                matched_eff_col = None

                for bus_col, eff_col in bus_to_eff_map.items():

                    if bus_col not in asset_row:
                        continue

                    bus_value = asset_row[
                        bus_col
                    ]

                    if pd.isna(bus_value):
                        continue

                    if current_heat_load in str(
                        bus_value
                    ):

                        matched_eff_col = eff_col

                        break

                if matched_eff_col is None:

                    print(
                        f"  ⚠️ [{current_heat_load}] "
                        f"{demand_type} | "
                        f"Asset '{asset_name}' | "
                        f"No matching heat bus found."
                    )

                    continue

                # -------------------------------------------------------------
                ### GET INDIVIDUAL UNIT EFFICIENCY
                # -------------------------------------------------------------

                if matched_eff_col not in asset_row:

                    continue

                efficiency_value = asset_row[
                    matched_eff_col
                ]

                if pd.isna(
                    efficiency_value
                ):

                    continue

                efficiency_value = float(
                    efficiency_value
                )

                if efficiency_value <= 0:

                    print(
                        f"  ⚠️ [{current_heat_load}] "
                        f"{demand_type} | "
                        f"Asset '{asset_name}' | "
                        f"Invalid efficiency: "
                        f"{efficiency_value}"
                    )

                    continue

                # -------------------------------------------------------------
                ### GET INDIVIDUAL THERMAL DEMAND
                # -------------------------------------------------------------

                thermal_demand = (
                    pd.to_numeric(
                        ts_df[demand_col],
                        errors="coerce"
                    )
                    .fillna(0.0)
                )

                # -------------------------------------------------------------
                ### CONVERT INDIVIDUAL THERMAL DEMAND
                ### INTO INDIVIDUAL ELECTRICAL DEMAND
                # -------------------------------------------------------------

                electrical_demand = (
                    thermal_demand
                    / efficiency_value
                )

                # -------------------------------------------------------------
                ### CREATE INDIVIDUAL ELECTRICAL-EQUIVALENT COLUMN
                ###
                ### Example:
                ###
                ### BE1 0 services urban decentral resistive heater-2019
                ### DHW_demand_reshaped_/Efficiency
                # -------------------------------------------------------------

                out_col = (
                    f"{asset_name} "
                    f"{demand_type}_/Efficiency"
                )

                ts_df[
                    out_col
                ] = electrical_demand

                # -------------------------------------------------------------
                ### STORE METADATA FOR LATER VPP AGGREGATION
                # -------------------------------------------------------------

                processed_units.append(
                    {
                        "asset_name": asset_name,
                        "source_sector": source_sector,
                        "node": node_prefix,
                        "efficiency": efficiency_value,
                        "demand_column": demand_col,
                        "electrical_column": out_col,
                    }
                )

                # -------------------------------------------------------------
                ### REPORT
                # -------------------------------------------------------------

                print(
                    f"  ✅ [{current_heat_load}] "
                    f"{demand_type} | "
                    f"Asset: {asset_name} | "
                    f"Source sector: {source_sector} | "
                    f"Efficiency: "
                    f"{efficiency_value:.4f}"
                )

            # -----------------------------------------------------------------
            ### SUMMARY
            # -----------------------------------------------------------------

            if processed_units:

                print(
                    f"  ✅ [{current_heat_load}] "
                    f"{demand_type} | "
                    f"Processed "
                    f"{len(processed_units)} "
                    f"individual resistive-heater units."
                )

            else:

                print(
                    f"  ⚠️ [{current_heat_load}] "
                    f"{demand_type} | "
                    f"No valid resistive-heater units processed."
                )


# =============================================================================
### FINISHED
# =============================================================================

print(
    "\n============================================================"
)

print(
    "DONE: Individual resistive-heater thermal demands have "
    "been converted to electrical/input-equivalent demand."
)

print(
    "Each unit was converted using its own PyPSA efficiency."
)

print(
    "No arithmetic average efficiency was used."
)

print(
    "The individual year-specific units (2015, 2019, 2030, etc.) "
    "remain separate."
)

print(
    "These individual electrical profiles are now ready for "
    "VPP_SourceSectors-based aggregation."
)

print(
    "============================================================"
)
# Out:
# --- Processing Country: BE ---
#   Loading metadata from:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/BE/pypsa_power_plants_BE_2030.csv
#   ✅ [urban central heat] SpaceHeating_demand | Asset: BE1 0 urban central resistive heater-2030 | Source sector: BE1 0 urban central resistive heater | Efficiency: 0.9900
#   ✅ [urban central heat] SpaceHeating_demand | Processed 1 individual resistive-heater units.
#   ✅ [urban central heat] DHW_demand_reshaped | Asset: BE1 0 urban central resistive heater-2030 | Source sector: BE1 0 urban central resistive heater | Efficiency: 0.9900
#   ✅ [urban central heat] DHW_demand_reshaped | Processed 1 individual resistive-heater units.
#   ✅ [services urban decentral heat] SpaceHeating_demand | Asset: BE1 0 services urban decentral resistive heater-2030 | Source sector: BE1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] SpaceHeating_demand | Asset: BE1 0 services urban decentral resistive heater-2015 | Source sector: BE1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] SpaceHeating_demand | Asset: BE1 0 services urban decentral resistive heater-2019 | Source sector: BE1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] SpaceHeating_demand | Processed 3 individual resistive-heater units.
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Asset: BE1 0 services urban decentral resistive heater-2030 | Source sector: BE1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Asset: BE1 0 services urban decentral resistive heater-2015 | Source sector: BE1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Asset: BE1 0 services urban decentral resistive heater-2019 | Source sector: BE1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Processed 3 individual resistive-heater units.
#   ✅ [services rural heat] SpaceHeating_demand | Asset: BE1 0 services rural resistive heater-2030 | Source sector: BE1 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] SpaceHeating_demand | Processed 1 individual resistive-heater units.
#   ✅ [services rural heat] DHW_demand_reshaped | Asset: BE1 0 services rural resistive heater-2030 | Source sector: BE1 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] DHW_demand_reshaped | Processed 1 individual resistive-heater units.
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: BE1 0 residential rural resistive heater-2030 | Source sector: BE1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: BE1 0 residential rural resistive heater-2015 | Source sector: BE1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: BE1 0 residential rural resistive heater-2019 | Source sector: BE1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Processed 3 individual resistive-heater units.
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: BE1 0 residential rural resistive heater-2030 | Source sector: BE1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: BE1 0 residential rural resistive heater-2015 | Source sector: BE1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: BE1 0 residential rural resistive heater-2019 | Source sector: BE1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Processed 3 individual resistive-heater units.
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: BE1 0 residential urban decentral resistive heater-2030 | Source sector: BE1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: BE1 0 residential urban decentral resistive heater-2015 | Source sector: BE1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: BE1 0 residential urban decentral resistive heater-2019 | Source sector: BE1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Processed 3 individual resistive-heater units.
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: BE1 0 residential urban decentral resistive heater-2030 | Source sector: BE1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: BE1 0 residential urban decentral resistive heater-2015 | Source sector: BE1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: BE1 0 residential urban decentral resistive heater-2019 | Source sector: BE1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Processed 3 individual resistive-heater units.
#
# --- Processing Country: FR ---
#   Loading metadata from:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/FR/pypsa_power_plants_FR_2030.csv
#   ✅ [urban central heat] SpaceHeating_demand | Asset: FR1 0 urban central resistive heater-2030 | Source sector: FR1 0 urban central resistive heater | Efficiency: 0.9900
#   ✅ [urban central heat] SpaceHeating_demand | Processed 1 individual resistive-heater units.
#   ✅ [urban central heat] DHW_demand_reshaped | Asset: FR1 0 urban central resistive heater-2030 | Source sector: FR1 0 urban central resistive heater | Efficiency: 0.9900
#   ✅ [urban central heat] DHW_demand_reshaped | Processed 1 individual resistive-heater units.
#   ✅ [services urban decentral heat] SpaceHeating_demand | Asset: FR1 0 services urban decentral resistive heater-2030 | Source sector: FR1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] SpaceHeating_demand | Asset: FR1 0 services urban decentral resistive heater-2015 | Source sector: FR1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] SpaceHeating_demand | Asset: FR1 0 services urban decentral resistive heater-2019 | Source sector: FR1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] SpaceHeating_demand | Processed 3 individual resistive-heater units.
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Asset: FR1 0 services urban decentral resistive heater-2030 | Source sector: FR1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Asset: FR1 0 services urban decentral resistive heater-2015 | Source sector: FR1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Asset: FR1 0 services urban decentral resistive heater-2019 | Source sector: FR1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Processed 3 individual resistive-heater units.
#   ✅ [services rural heat] SpaceHeating_demand | Asset: FR1 0 services rural resistive heater-2030 | Source sector: FR1 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] SpaceHeating_demand | Asset: FR1 0 services rural resistive heater-2015 | Source sector: FR1 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] SpaceHeating_demand | Asset: FR1 0 services rural resistive heater-2019 | Source sector: FR1 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] SpaceHeating_demand | Processed 3 individual resistive-heater units.
#   ✅ [services rural heat] DHW_demand_reshaped | Asset: FR1 0 services rural resistive heater-2030 | Source sector: FR1 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] DHW_demand_reshaped | Asset: FR1 0 services rural resistive heater-2015 | Source sector: FR1 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] DHW_demand_reshaped | Asset: FR1 0 services rural resistive heater-2019 | Source sector: FR1 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] DHW_demand_reshaped | Processed 3 individual resistive-heater units.
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: FR1 0 residential rural resistive heater-2030 | Source sector: FR1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: FR1 0 residential rural resistive heater-2015 | Source sector: FR1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: FR1 0 residential rural resistive heater-2019 | Source sector: FR1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Processed 3 individual resistive-heater units.
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: FR1 0 residential rural resistive heater-2030 | Source sector: FR1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: FR1 0 residential rural resistive heater-2015 | Source sector: FR1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: FR1 0 residential rural resistive heater-2019 | Source sector: FR1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Processed 3 individual resistive-heater units.
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: FR1 0 residential urban decentral resistive heater-2030 | Source sector: FR1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: FR1 0 residential urban decentral resistive heater-2015 | Source sector: FR1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: FR1 0 residential urban decentral resistive heater-2019 | Source sector: FR1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Processed 3 individual resistive-heater units.
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: FR1 0 residential urban decentral resistive heater-2030 | Source sector: FR1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: FR1 0 residential urban decentral resistive heater-2015 | Source sector: FR1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: FR1 0 residential urban decentral resistive heater-2019 | Source sector: FR1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Processed 3 individual resistive-heater units.
#
# --- Processing Country: DE ---
#   Loading metadata from:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/DE/pypsa_power_plants_DE_2030.csv
#   ✅ [urban central heat] SpaceHeating_demand | Asset: DE1 0 urban central resistive heater-2030 | Source sector: DE1 0 urban central resistive heater | Efficiency: 0.9900
#   ✅ [urban central heat] SpaceHeating_demand | Processed 1 individual resistive-heater units.
#   ✅ [urban central heat] DHW_demand_reshaped | Asset: DE1 0 urban central resistive heater-2030 | Source sector: DE1 0 urban central resistive heater | Efficiency: 0.9900
#   ✅ [urban central heat] DHW_demand_reshaped | Processed 1 individual resistive-heater units.
#   ✅ [services urban decentral heat] SpaceHeating_demand | Asset: DE1 0 services urban decentral resistive heater-2030 | Source sector: DE1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] SpaceHeating_demand | Processed 1 individual resistive-heater units.
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Asset: DE1 0 services urban decentral resistive heater-2030 | Source sector: DE1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Processed 1 individual resistive-heater units.
#   ✅ [services rural heat] SpaceHeating_demand | Asset: DE1 0 services rural resistive heater-2030 | Source sector: DE1 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] SpaceHeating_demand | Processed 1 individual resistive-heater units.
#   ✅ [services rural heat] DHW_demand_reshaped | Asset: DE1 0 services rural resistive heater-2030 | Source sector: DE1 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] DHW_demand_reshaped | Processed 1 individual resistive-heater units.
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: DE1 0 residential rural resistive heater-2030 | Source sector: DE1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Processed 1 individual resistive-heater units.
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: DE1 0 residential rural resistive heater-2030 | Source sector: DE1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Processed 1 individual resistive-heater units.
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: DE1 0 residential urban decentral resistive heater-2030 | Source sector: DE1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Processed 1 individual resistive-heater units.
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: DE1 0 residential urban decentral resistive heater-2030 | Source sector: DE1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Processed 1 individual resistive-heater units.
#
# --- Processing Country: NL ---
#   Loading metadata from:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/NL/pypsa_power_plants_NL_2030.csv
#   ✅ [urban central heat] SpaceHeating_demand | Asset: NL1 0 urban central resistive heater-2030 | Source sector: NL1 0 urban central resistive heater | Efficiency: 0.9900
#   ✅ [urban central heat] SpaceHeating_demand | Processed 1 individual resistive-heater units.
#   ✅ [urban central heat] DHW_demand_reshaped | Asset: NL1 0 urban central resistive heater-2030 | Source sector: NL1 0 urban central resistive heater | Efficiency: 0.9900
#   ✅ [urban central heat] DHW_demand_reshaped | Processed 1 individual resistive-heater units.
#   ✅ [services urban decentral heat] SpaceHeating_demand | Asset: NL1 0 services urban decentral resistive heater-2030 | Source sector: NL1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] SpaceHeating_demand | Processed 1 individual resistive-heater units.
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Asset: NL1 0 services urban decentral resistive heater-2030 | Source sector: NL1 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Processed 1 individual resistive-heater units.
#   ✅ [services rural heat] SpaceHeating_demand | Asset: NL1 0 services rural resistive heater-2030 | Source sector: NL1 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] SpaceHeating_demand | Processed 1 individual resistive-heater units.
#   ✅ [services rural heat] DHW_demand_reshaped | Asset: NL1 0 services rural resistive heater-2030 | Source sector: NL1 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] DHW_demand_reshaped | Processed 1 individual resistive-heater units.
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: NL1 0 residential rural resistive heater-2030 | Source sector: NL1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Processed 1 individual resistive-heater units.
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: NL1 0 residential rural resistive heater-2030 | Source sector: NL1 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Processed 1 individual resistive-heater units.
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: NL1 0 residential urban decentral resistive heater-2030 | Source sector: NL1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: NL1 0 residential urban decentral resistive heater-2015 | Source sector: NL1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: NL1 0 residential urban decentral resistive heater-2019 | Source sector: NL1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Processed 3 individual resistive-heater units.
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: NL1 0 residential urban decentral resistive heater-2030 | Source sector: NL1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: NL1 0 residential urban decentral resistive heater-2015 | Source sector: NL1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: NL1 0 residential urban decentral resistive heater-2019 | Source sector: NL1 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Processed 3 individual resistive-heater units.
#
# --- Processing Country: UK ---
#   Loading metadata from:
#   /home/ray/Dispa-SET_Unleash/RawData_PyPSA/Sufficiency_Scenario/PowerPlants/2030/UK/pypsa_power_plants_UK_2030.csv
#   ✅ [urban central heat] SpaceHeating_demand | Asset: GB0 0 urban central resistive heater-2030 | Source sector: GB0 0 urban central resistive heater | Efficiency: 0.9900
#   ✅ [urban central heat] SpaceHeating_demand | Asset: GB2 0 urban central resistive heater-2030 | Source sector: GB2 0 urban central resistive heater | Efficiency: 0.9900
#   ✅ [urban central heat] SpaceHeating_demand | Processed 2 individual resistive-heater units.
#   ✅ [urban central heat] DHW_demand_reshaped | Asset: GB0 0 urban central resistive heater-2030 | Source sector: GB0 0 urban central resistive heater | Efficiency: 0.9900
#   ✅ [urban central heat] DHW_demand_reshaped | Asset: GB2 0 urban central resistive heater-2030 | Source sector: GB2 0 urban central resistive heater | Efficiency: 0.9900
#   ✅ [urban central heat] DHW_demand_reshaped | Processed 2 individual resistive-heater units.
#   ✅ [services urban decentral heat] SpaceHeating_demand | Asset: GB0 0 services urban decentral resistive heater-2030 | Source sector: GB0 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] SpaceHeating_demand | Asset: GB2 0 services urban decentral resistive heater-2030 | Source sector: GB2 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] SpaceHeating_demand | Asset: GB0 0 services urban decentral resistive heater-2015 | Source sector: GB0 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] SpaceHeating_demand | Asset: GB0 0 services urban decentral resistive heater-2019 | Source sector: GB0 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] SpaceHeating_demand | Processed 4 individual resistive-heater units.
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Asset: GB0 0 services urban decentral resistive heater-2030 | Source sector: GB0 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Asset: GB2 0 services urban decentral resistive heater-2030 | Source sector: GB2 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Asset: GB0 0 services urban decentral resistive heater-2015 | Source sector: GB0 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Asset: GB0 0 services urban decentral resistive heater-2019 | Source sector: GB0 0 services urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [services urban decentral heat] DHW_demand_reshaped | Processed 4 individual resistive-heater units.
#   ✅ [services rural heat] SpaceHeating_demand | Asset: GB0 0 services rural resistive heater-2030 | Source sector: GB0 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] SpaceHeating_demand | Asset: GB2 0 services rural resistive heater-2030 | Source sector: GB2 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] SpaceHeating_demand | Asset: GB0 0 services rural resistive heater-2015 | Source sector: GB0 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] SpaceHeating_demand | Asset: GB2 0 services rural resistive heater-2015 | Source sector: GB2 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] SpaceHeating_demand | Asset: GB0 0 services rural resistive heater-2019 | Source sector: GB0 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] SpaceHeating_demand | Asset: GB2 0 services rural resistive heater-2019 | Source sector: GB2 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] SpaceHeating_demand | Processed 6 individual resistive-heater units.
#   ✅ [services rural heat] DHW_demand_reshaped | Asset: GB0 0 services rural resistive heater-2030 | Source sector: GB0 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] DHW_demand_reshaped | Asset: GB2 0 services rural resistive heater-2030 | Source sector: GB2 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] DHW_demand_reshaped | Asset: GB0 0 services rural resistive heater-2015 | Source sector: GB0 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] DHW_demand_reshaped | Asset: GB2 0 services rural resistive heater-2015 | Source sector: GB2 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] DHW_demand_reshaped | Asset: GB0 0 services rural resistive heater-2019 | Source sector: GB0 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] DHW_demand_reshaped | Asset: GB2 0 services rural resistive heater-2019 | Source sector: GB2 0 services rural resistive heater | Efficiency: 0.9000
#   ✅ [services rural heat] DHW_demand_reshaped | Processed 6 individual resistive-heater units.
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: GB0 0 residential rural resistive heater-2030 | Source sector: GB0 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: GB2 0 residential rural resistive heater-2030 | Source sector: GB2 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: GB0 0 residential rural resistive heater-2015 | Source sector: GB0 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: GB2 0 residential rural resistive heater-2015 | Source sector: GB2 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: GB0 0 residential rural resistive heater-2019 | Source sector: GB0 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Asset: GB2 0 residential rural resistive heater-2019 | Source sector: GB2 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] SpaceHeating_demand | Processed 6 individual resistive-heater units.
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: GB0 0 residential rural resistive heater-2030 | Source sector: GB0 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: GB2 0 residential rural resistive heater-2030 | Source sector: GB2 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: GB0 0 residential rural resistive heater-2015 | Source sector: GB0 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: GB2 0 residential rural resistive heater-2015 | Source sector: GB2 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: GB0 0 residential rural resistive heater-2019 | Source sector: GB0 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Asset: GB2 0 residential rural resistive heater-2019 | Source sector: GB2 0 residential rural resistive heater | Efficiency: 0.9000
#   ✅ [residential rural heat] DHW_demand_reshaped | Processed 6 individual resistive-heater units.
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: GB0 0 residential urban decentral resistive heater-2030 | Source sector: GB0 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: GB2 0 residential urban decentral resistive heater-2030 | Source sector: GB2 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: GB0 0 residential urban decentral resistive heater-2015 | Source sector: GB0 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: GB2 0 residential urban decentral resistive heater-2015 | Source sector: GB2 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: GB0 0 residential urban decentral resistive heater-2019 | Source sector: GB0 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Asset: GB2 0 residential urban decentral resistive heater-2019 | Source sector: GB2 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] SpaceHeating_demand | Processed 6 individual resistive-heater units.
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: GB0 0 residential urban decentral resistive heater-2030 | Source sector: GB0 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: GB2 0 residential urban decentral resistive heater-2030 | Source sector: GB2 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: GB0 0 residential urban decentral resistive heater-2015 | Source sector: GB0 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: GB2 0 residential urban decentral resistive heater-2015 | Source sector: GB2 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: GB0 0 residential urban decentral resistive heater-2019 | Source sector: GB0 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Asset: GB2 0 residential urban decentral resistive heater-2019 | Source sector: GB2 0 residential urban decentral resistive heater | Efficiency: 0.9000
#   ✅ [residential urban decentral heat] DHW_demand_reshaped | Processed 6 individual resistive-heater units.
#
# ============================================================
# DONE: Individual resistive-heater thermal demands have been converted to electrical/input-equivalent demand.
# Each unit was converted using its own PyPSA efficiency.
# No arithmetic average efficiency was used.
# The individual year-specific units (2015, 2019, 2030, etc.) remain separate.
# These individual electrical profiles are now ready for VPP_SourceSectors-based aggregation.
# ============================================================

# %%
country_loads_time_series["UK"]['services urban decentral heat'].to_csv('/home/ray/Documents/Unleash/Julios_Data/Auxiliar_Documents/testing_file14.csv', index=True)

# %% [markdown]
# <div style= "background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099; " >
#  <span style= "font-weight: bold; font-size: 16px; " >
# Section G Overview: Space Heating Aggregation & VPP Sector Load
#  </span >
#  <div style= "border-top: 1px solid #000099; padding: 10px; " >
# This section finalizes the VPP power load calculations.<br> It extracts and sums the electrical equivalency of space heating across all nodes. <br>If VPP mode is enabled, it adds this space heating equivalency to the baseline Sector Power Load to create the comprehensive VPP Sector Power Load dictionary.
#  </div >
#  </div >
#  <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         G-1. Extracting and Summing Space Heating Consumption Electric Equivalency
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process extracts all <b>SpaceHeating_demand_/Efficiency</b> columns from the <b>country_loads_time_series</b> dictionary, sums them horizontally for each country, and stores the result in a new dictionary (<b>space_heating_consumption_elect_equivalency</b>).<br> These columns represent the <b>electric equivalency of space heating consumption</b> for each node.<br>
#     <b>Extraction and Aggregation Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each country, the script iterates through all heat load categories and identifies columns containing <b>"SpaceHeating_demand_/Efficiency"</b>.<br> These columns represent the electrical input required for space heating (accounting for efficiency).<br> The found columns are collected from all heat categories and then <b>concatenated horizontally</b>.<br> The total space heating consumption is calculated by <b>summing all columns along the row axis</b> (<b>df.sum(axis=1)</b>).<br>
#         The resulting dictionary contains one DataFrame per country with a single column named <b>"space_heating_consumption_elect_equivalency"</b>.
#         </div>
#     </div>
# </div>

# %%
space_heating_consumption_elect_equivalency = {}
for country, heat_loads_dict in country_loads_time_series.items():
    country_space_heating_dfs = []
    for heat_category, df in heat_loads_dict.items():
        # FIND SpaceHeating_demand_/Efficiency COLUMNS
        efficiency_cols = [
            col
            for col in df.columns
            if "SpaceHeating_demand_/Efficiency" in str(col)
        ]
        # EXTRACT FOUND COLUMNS
        if efficiency_cols:
            country_space_heating_dfs.append(
                df[efficiency_cols]
            )
    # AGGREGATE ALL FOUND COLUMNS
    if country_space_heating_dfs:
        combined_space_heating = pd.concat(
            country_space_heating_dfs,
            axis=1
        )
        total_space_heating = combined_space_heating.sum(axis=1)
        space_heating_consumption_elect_equivalency[country] = (
            total_space_heating.to_frame(
                name="space_heating_consumption_elect_equivalency"
            )
        )
    else:
        # Keep the country's time index even if no columns were found
        first_df = next(iter(heat_loads_dict.values()))
        space_heating_consumption_elect_equivalency[country] = (
            pd.DataFrame(
                index=first_df.index,
                columns=[
                    "space_heating_consumption_elect_equivalency"
                ]
            )
        )
        space_heating_consumption_elect_equivalency[country] = (
            space_heating_consumption_elect_equivalency[country].fillna(0.0)
        )
    # Make sure the index is called snapshot
    space_heating_consumption_elect_equivalency[country].index.name = (
        "snapshot"
    )
# INSPECTION
print("\nProcess completed.")
for country, df in space_heating_consumption_elect_equivalency.items():
    print(
        f" {country}: "
        f"{df.shape[0]} snapshots, "
        f"{df.shape[1]} column"
    )
    print(
        df.head(2)
    )
# Out:
# Process completed.
#  BE: 8760 snapshots, 1 column
#                      space_heating_consumption_elect_equivalency
# snapshot
# 2013-01-01 00:00:00                                  2979.667563
# 2013-01-01 01:00:00                                  3050.590933
#  FR: 8760 snapshots, 1 column
#                      space_heating_consumption_elect_equivalency
# snapshot
# 2013-01-01 00:00:00                                 16882.206600
# 2013-01-01 01:00:00                                 17372.735043
#  DE: 8760 snapshots, 1 column
#                      space_heating_consumption_elect_equivalency
# snapshot
# 2013-01-01 00:00:00                                  6206.681962
# 2013-01-01 01:00:00                                  6157.357156
#  NL: 8760 snapshots, 1 column
#                      space_heating_consumption_elect_equivalency
# snapshot
# 2013-01-01 00:00:00                                  9279.171172
# 2013-01-01 01:00:00                                  9290.810420
#  UK: 8760 snapshots, 1 column
#                      space_heating_consumption_elect_equivalency
# snapshot
# 2013-01-01 00:00:00                                  6845.655661
# 2013-01-01 01:00:00                                  6839.643780

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         G-2. Creating VPP Sector Power Load
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process creates the <b>VPP Sector Power Load</b> dictionary by starting with the original <b>Sector_Power_Load</b> and <b>conditionally adding space heating consumption</b> when VPP mode is enabled. The result is stored in a new dictionary (<b>vpp_Sector_Power_Load</b>).<br>
#     <b>Creation Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each country, the script copies the original <b>Sector_Power_Load</b> DataFrame. <br>
#         If <b>VPP = True</b>, it retrieves the space heating consumption DataFrame and validates that both DataFrames have the <b>same number of snapshots</b> and <b>identical snapshot indexes</b>.<br>
#         The space heating column is then added to the Sector_Power_Load column. <br>
#             If <b>VPP = False</b>, no addition is performed.<br>
#         The resulting dictionary contains one DataFrame per country with the updated <b>Sector_Power_Load</b> column.
#         </div>
#     </div>
# </div>

# %%
# CREATE VPP SECTOR POWER LOAD
vpp_Sector_Power_Load = {}
for country in Sector_Power_Load:
    # COPY ORIGINAL SECTOR POWER LOAD
    sector_df = Sector_Power_Load[country].copy()
    # IF VPP IS ACTIVE, ADD SPACE HEATING
    if VPP:
        space_heating_df = (
            space_heating_consumption_elect_equivalency[country]
            .copy()
        )
        # NORMALIZE SNAPSHOT INDEXES
        sector_index = pd.to_datetime(sector_df.index)
        space_heating_index = pd.to_datetime(
            space_heating_df.index
        )
        # Remove timezone if present
        if sector_index.tz is not None:
            sector_index = sector_index.tz_localize(None)
        if space_heating_index.tz is not None:
            space_heating_index = space_heating_index.tz_localize(None)
        sector_df.index = sector_index
        space_heating_df.index = space_heating_index
        sector_df.index.name = "snapshot"
        space_heating_df.index.name = "snapshot"
        # CHECK SAME NUMBER OF SNAPSHOTS
        if len(sector_df) != len(space_heating_df):
            raise ValueError(
                f"{country}: different number of snapshots. "
                f"Sector_Power_Load = {len(sector_df)}, "
                f"Space Heating = {len(space_heating_df)}"
            )
        # CHECK SAME SNAPSHOT INDEX
        if not sector_df.index.equals(space_heating_df.index):
            raise ValueError(
                f"{country}: snapshot indexes are not identical."
            )
        # SUM INTO THE SAME COLUMN
        sector_df["Sector_Power_Load"] = (
            sector_df["Sector_Power_Load"]
            + space_heating_df[
                "space_heating_consumption_elect_equivalency"
            ]
        )
    # SAVE RESULT INTO NEW DICTIONARY
    vpp_Sector_Power_Load[country] = sector_df
    # INSPECTION
    print(
        f"\n{country}: "
        f"{len(vpp_Sector_Power_Load[country])} snapshots"
    )
    print(
        vpp_Sector_Power_Load[country].head(2)
    )
# FINAL MESSAGE
if VPP:
    print(
        "\nVPP activated: "
        "space heating was added to vpp_Sector_Power_Load."
    )
else:
    print(
        "\nVPP deactivated: "
        "vpp_Sector_Power_Load is equal to Sector_Power_Load."
    )
# Out:
# BE: 8760 snapshots
#                      Sector_Power_Load
# snapshot
# 2013-01-01 00:00:00       20087.335915
# 2013-01-01 01:00:00       19646.236728
#
# FR: 8760 snapshots
#                      Sector_Power_Load
# snapshot
# 2013-01-01 00:00:00       71416.601610
# 2013-01-01 01:00:00       70139.368734
#
# DE: 8760 snapshots
#                      Sector_Power_Load
# snapshot
# 2013-01-01 00:00:00       90871.437443
# 2013-01-01 01:00:00       89647.744039
#
# NL: 8760 snapshots
#                      Sector_Power_Load
# snapshot
# 2013-01-01 00:00:00       36435.896435
# 2013-01-01 01:00:00       34762.010554
#
# UK: 8760 snapshots
#                      Sector_Power_Load
# snapshot
# 2013-01-01 00:00:00       54819.626432
# 2013-01-01 01:00:00       54207.079949
#
# VPP activated: space heating was added to vpp_Sector_Power_Load.

# %% [markdown]
# <div style= "background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099; " >
#  <span style= "font-weight: bold; font-size: 16px; " >
# Section H Overview: Target Year Adjustment & Power Load Export
#  </span >
#  <div style= "border-top: 1px solid #000099; padding: 10px; " >
# This section prepares the power load time series for export.<br> It adjusts the DataFrames to match the exact number of rows required for the target year, intelligently handling leap year differences (February 29). <br>It then saves the files with dynamic VPP suffixes and copies them to the appropriate standard or VPP directories based on the zone configuration.
#  </div >
#  </div >
#  <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         H-1. Adjusting Selected Load Dictionary to Target Year with Leap Year Handling
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process adjusts the <b>selected load dictionary</b> (either <b>Sector_Power_Load</b> or <b>vpp_Sector_Power_Load</b>) to have the correct number of rows for the target year, handling <b>leap year</b> differences (February 29).<br>It ensures that all DataFrames have the exact number of timesteps expected for the target year.<br>
#     <b>Adjustment Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         The script first determines if the target year is a leap year and calculates the expected number of rows (365 or 366 days × steps per day). It then selects the appropriate load dictionary based on <b>VPP</b> mode:
#             <div style="margin-left: 2em;">
#         <b>VPP = True</b> → Processes <b>vpp_Sector_Power_Load</b><br>
#         <b>VPP = False</b> → Processes <b>Sector_Power_Load</b>
#             </div>
#         For each zone, it adjusts the DataFrame to match the target year:
#             <div style="margin-left: 2em;">
#         <b>If target year has more rows</b> (leap year) → Duplicate February 28 data to create a February 29 row.<br>
#         <b>If target year has fewer rows</b> (non-leap year) → Remove February 29 data.
#             </div>
#         The process uses a <b>temporary leap year 2000 index</b> to safely handle February 29 during processing, then reindexes to the target year with a UTC timezone.<br>
#         After adjustment, all DataFrames have the correct number of rows for the target year and are properly indexed with a UTC datetime index named "snapshot".
#         </div>
#     </div>
# </div>

# %%
# TARGET YEAR SETTINGS
target_year = int(data_target_year)
is_leap_year = calendar.isleap(target_year)
# =============================================================================
steps_per_day = {
    "1h": 24,
    "30min": 48,
    "15min": 96
}
# =============================================================================
expected_rows = (
    366 if is_leap_year else 365
) * steps_per_day[data_target_time_step]

print(f"Target year   : {target_year}")
print(f"Leap year     : {is_leap_year}")
print(f"Expected rows : {expected_rows}")
# SELECT LOAD DICTIONARY DEPENDING ON VPP
if VPP:
    load_dictionary = vpp_Sector_Power_Load
    print("\nVPP enabled -> processing vpp_Sector_Power_Load")
else:
    load_dictionary = Sector_Power_Load
    print("\nVPP disabled -> processing Sector_Power_Load")
# ADJUST ALL ZONES
for zone, df in load_dictionary.items():
    df = df.copy()
    actual_rows = len(df)
    print(f"\nProcessing {zone}")
    print(f"Actual rows   : {actual_rows}")
    print(f"Expected rows : {expected_rows}")
    # CREATE TEMPORARY INDEX USING LEAP YEAR 2000
    # 2000 is a leap year, so Feb-29 can exist if needed.
    base_freq = {
        "1h": "h",
        "30min": "30min",
        "15min": "15min"
    }[data_target_time_step]
    temp_index = pd.date_range(
        start="2000-01-01 00:00:00",
        periods=actual_rows,
        freq=base_freq
    )
    df.index = temp_index
    # TARGET YEAR HAS MORE ROWS
    # ADD FEBRUARY 29
    if expected_rows > actual_rows:
        feb28_mask = (
            (temp_index.month == 2)
            & (temp_index.day == 28)
        )
        feb28 = df.loc[feb28_mask].copy()
        feb29_index = feb28.index + pd.Timedelta(days=1)
        feb29 = feb28.copy()
        feb29.index = feb29_index
        df = pd.concat(
            [df, feb29]
        )
        df = df.sort_index()
    # TARGET YEAR HAS FEWER ROWS
    # REMOVE FEBRUARY 29
    elif expected_rows < actual_rows:
        df = df[
            ~(
                (df.index.month == 2)
                & (df.index.day == 29)
            )
        ]
    # CREATE FINAL UTC INDEX
    final_index = pd.date_range(
        start=f"{target_year}-01-01 00:00:00",
        periods=len(df),
        freq=base_freq,
        tz="UTC"
    )
    df.index = final_index
    df.index.name = "snapshot"
    # SAVE BACK TO THE SELECTED DICTIONARY
    load_dictionary[zone] = df
    print(f"Final rows    : {len(df)}")
# FINAL MESSAGE
if VPP:
    print(
        "\nVPP enabled -> "
        "vpp_Sector_Power_Load was adjusted to the target year."
    )
else:
    print(
        "\nVPP disabled -> "
        "Sector_Power_Load was adjusted to the target year."
    )
# Out:
# Target year   : 2030
# Leap year     : False
# Expected rows : 8760
#
# VPP enabled -> processing vpp_Sector_Power_Load
#
# Processing BE
# Actual rows   : 8760
# Expected rows : 8760
# Final rows    : 8760
#
# Processing FR
# Actual rows   : 8760
# Expected rows : 8760
# Final rows    : 8760
#
# Processing DE
# Actual rows   : 8760
# Expected rows : 8760
# Final rows    : 8760
#
# Processing NL
# Actual rows   : 8760
# Expected rows : 8760
# Final rows    : 8760
#
# Processing UK
# Actual rows   : 8760
# Expected rows : 8760
# Final rows    : 8760
#
# VPP enabled -> vpp_Sector_Power_Load was adjusted to the target year.

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         H-2. Saving Load Data with Dynamic File Suffix Based on VPP Mode
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process exports the <b>selected load dictionary</b> (either <b>Sector_Power_Load</b> or <b>vpp_Sector_Power_Load</b>) to CSV files with <b>automatic time-step detection</b> and a <b>dynamic file suffix</b> based on VPP mode.<br> When VPP is enabled, files are saved with a <b>_vpp</b> suffix to distinguish them from standard load files.<br>
#     <b>Export Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         The script first selects the appropriate load dictionary and file suffix based on <b>VPP</b> mode:
#             <div style="margin-left: 2em;">
#         <b>VPP = True</b> → Uses <b>vpp_Sector_Power_Load</b> with <b>_vpp</b> suffix<br>
#         <b>VPP = False</b> → Uses <b>Sector_Power_Load</b> with <b>no suffix</b>
#             </div>
#         For each zone, it calculates the time difference between the first two timestamps to determine the time-step subfolder (1h, 30min, or 15min). The DataFrame is then saved as <b>{data_target_year}{file_suffix}.csv</b> in the appropriate subfolder, with <b>index=True</b> and <b>header=False</b>.<br>
#         This ensures that load data is correctly organized by time resolution for Dispa-SET compatibility.
#         </div>
#     </div>
# </div>

# %%
# SELECT LOAD DICTIONARY AND FILE SUFFIX
# _____________________________________________________________________________
if VPP:
    load_dictionary = vpp_Sector_Power_Load
    file_suffix = "_vpp"
    print("\nVPP enabled -> using vpp_Sector_Power_Load")
# _____________________________________________________________________________
else:
    load_dictionary = Sector_Power_Load
    file_suffix = ""
    print("\nVPP disabled -> using Sector_Power_Load")
# _____________________________________________________________________________
# SAVE LOAD DATA FOR EACH ZONE
for zone in zone_names:
    # Get the DataFrame for the current zone
    df = load_dictionary[zone]
    # EXTRACT THE TIME STEP FROM THE INDEX
    time_index = df.index
    if len(time_index) >= 2:
        # Calculate the time difference between
        # the first two timestamps
        time_diff = (
            pd.to_datetime(time_index[1])
            - pd.to_datetime(time_index[0])
        )
        time_diff_minutes = time_diff.total_seconds() / 60
        # Determine the time-step subfolder
        if time_diff_minutes == 60:
            time_step_subfolder = "1h"
        elif time_diff_minutes == 30:
            time_step_subfolder = "30min"
        elif time_diff_minutes == 15:
            time_step_subfolder = "15min"
        else:
            raise ValueError(
                f"Unsupported time step: "
                f"{time_diff_minutes} minutes"
            )
    else:
        raise ValueError(
            f"Zone {zone}: insufficient data points "
            f"to determine time step."
        )
    # DEFINE SAVE PATH
    save_path = os.path.join(
        loads_pypsa_formated_data_folder_path,
        zone,
        time_step_subfolder
    )
    # Create directory if it does not exist
    os.makedirs(
        save_path,
        exist_ok=True
    )
    # DEFINE FILE NAME
    file_name = (
        f"{data_target_year}{file_suffix}.csv"
    )
    file_path = os.path.join(
        save_path,
        file_name
    )
    # SAVE DATAFRAME
    df.to_csv(
        file_path,
        index=True,
        header=False
    )
    # DISPLAY SAVED FILE INFORMATION
    print(f"Zone: {zone}")
    print(f"Time step: {time_step_subfolder}")
    print(f"Saved file: {file_path}")
    print("-" * 80)
# Out:
# VPP enabled -> using vpp_Sector_Power_Load
# Zone: BE
# Time step: 1h
# Saved file: /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario/Load_RealTime/BE/1h/2030_vpp.csv
# --------------------------------------------------------------------------------
# Zone: FR
# Time step: 1h
# Saved file: /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario/Load_RealTime/FR/1h/2030_vpp.csv
# --------------------------------------------------------------------------------
# Zone: DE
# Time step: 1h
# Saved file: /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario/Load_RealTime/DE/1h/2030_vpp.csv
# --------------------------------------------------------------------------------
# Zone: NL
# Time step: 1h
# Saved file: /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario/Load_RealTime/NL/1h/2030_vpp.csv
# --------------------------------------------------------------------------------
# Zone: UK
# Time step: 1h
# Saved file: /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario/Load_RealTime/UK/1h/2030_vpp.csv
# --------------------------------------------------------------------------------

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         H-3. Copying VPP Power Sector Load Files with VPP Zone Handling
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process copies <b>load CSV files</b> from the source directory to the destination directory with <b>detailed VPP zone handling</b>.<br>
#         It distinguishes between <b>VPP zones</b> and <b>non-VPP zones</b>, and behaves differently depending on whether VPP mode is enabled.<br>
#     <b>Copy Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         The script first determines which zones are in <b>non_vpp_zones</b> (zones in zone_names but NOT in vpp_zone_names).<br>
#         It then handles two scenarios:<br>
#             <div style="margin-left: 2em;">
#         <b>When VPP = True:</b><br>
#                 <div style="margin-left: 2em;">
#         <li>VPP zones → Copy <code>{year}_vpp.csv</code> to <code>{year}.csv</code></li>
#         <li>Non-VPP zones → Copy <code>{year}.csv</code> to <code>{year}.csv</code></li>
#                 </div>
#         <b>When VPP = False:</b>
#                 <div style="margin-left: 2em;">
#         <li>Only non-VPP zones are processed (VPP zones are skipped)<br></li>
#         <li>Copy <code>{year}.csv</code> to <code>{year}.csv</code></li>
#                 </div>
#             </div>
# This ensures that all load files are correctly organized for Dispa-SET compatibility.
#     </div>
# </div>

# %%
# SOURCE AND DESTINATION ROOTS
source_root = Path(
    loads_pypsa_formated_data_folder_path
)
destination_root = Path(
    vpp_loads_pypsa_formated_data_folder_path
)
# DETERMINE ZONE GROUPS
# Zones that are in zone_names but NOT in vpp_zone_names
non_vpp_zones = [
    zone for zone in zone_names
    if zone not in vpp_zone_names
]
# INITIALIZE COPY SUMMARY
copied_files = []
# VPP = TRUE
# _____________________________________________________________________________
if VPP:
    print("\nVPP enabled")
    print("-" * 80)
    # 1. VPP ZONES
    # Source:
    #     2030_vpp.csv
    # Destination:
    #     2030.csv
    print("\nProcessing VPP zones...")
    for zone in vpp_zone_names:
        # Make sure we only process zones that are
        # actually part of the selected zone_names
        if zone not in zone_names:
            continue
        # TIME STEP
        source_df = vpp_Sector_Power_Load[zone]
        time_index = source_df.index
        if len(time_index) >= 2:
            time_diff = (
                pd.to_datetime(time_index[1])
                - pd.to_datetime(time_index[0])
            )
            time_diff_minutes = (
                time_diff.total_seconds() / 60
            )
            if time_diff_minutes == 60:
                time_step_subfolder = "1h"
            elif time_diff_minutes == 30:
                time_step_subfolder = "30min"
            elif time_diff_minutes == 15:
                time_step_subfolder = "15min"
            else:
                raise ValueError(
                    f"Zone {zone}: unsupported time step "
                    f"{time_diff_minutes} minutes."
                )
        else:
            raise ValueError(
                f"Zone {zone}: insufficient data points "
                f"to determine time step."
            )
        # SOURCE
        source_file = (
            source_root
            / zone
            / time_step_subfolder
            / f"{data_target_year}_vpp.csv"
        )
        # DESTINATION
        destination_file = (
            destination_root
            / zone
            / time_step_subfolder
            / f"{data_target_year}.csv"
        )
        # CREATE DESTINATION DIRECTORY
        destination_file.parent.mkdir(
            parents=True,
            exist_ok=True
        )
        # COPY / REPLACE
        shutil.copy2(
            source_file,
            destination_file
        )
        # RECORD
        copied_files.append(
            f"{zone}: "
            f"{source_file.name} -> "
            f"{destination_file.name} "
            f"(VPP, {time_step_subfolder})"
        )
    # 2. NON-VPP ZONES
    # Source:
    #     2030.csv
    # Destination:
    #     2030.csv
    print("\nProcessing non-VPP zones...")
    for zone in non_vpp_zones:
        # TIME STEP
        source_df = Sector_Power_Load[zone]
        time_index = source_df.index
        if len(time_index) >= 2:
            time_diff = (
                pd.to_datetime(time_index[1])
                - pd.to_datetime(time_index[0])
            )
            time_diff_minutes = (
                time_diff.total_seconds() / 60
            )
            if time_diff_minutes == 60:
                time_step_subfolder = "1h"
            elif time_diff_minutes == 30:
                time_step_subfolder = "30min"
            elif time_diff_minutes == 15:
                time_step_subfolder = "15min"
            else:
                raise ValueError(
                    f"Zone {zone}: unsupported time step "
                    f"{time_diff_minutes} minutes."
                )
        else:
            raise ValueError(
                f"Zone {zone}: insufficient data points "
                f"to determine time step."
            )
        # SOURCE
        source_file = (
            source_root
            / zone
            / time_step_subfolder
            / f"{data_target_year}.csv"
        )
        # DESTINATION
        destination_file = (
            destination_root
            / zone
            / time_step_subfolder
            / f"{data_target_year}.csv"
        )
        # CREATE DESTINATION DIRECTORY
        destination_file.parent.mkdir(
            parents=True,
            exist_ok=True
        )
        # COPY / REPLACE
        shutil.copy2(
            source_file,
            destination_file
        )
        # RECORD
        copied_files.append(
            f"{zone}: "
            f"{source_file.name} -> "
            f"{destination_file.name} "
            f"(Standard, {time_step_subfolder})"
        )
# VPP = FALSE
# _____________________________________________________________________________
else:
    print("\nVPP disabled")
    print("-" * 80)
    # ONLY PROCESS NON-VPP ZONES
    # Example:
    # zone_names     = ["BE", "DE"]
    # vpp_zone_names = ["BE"]
    # non_vpp_zones  = ["DE"]
    # Therefore BE is NOT copied when VPP is False.
    print("\nProcessing non-VPP zones only...")
    for zone in non_vpp_zones:
        # TIME STEP
        source_df = Sector_Power_Load[zone]
        time_index = source_df.index
        if len(time_index) >= 2:
            time_diff = (
                pd.to_datetime(time_index[1])
                - pd.to_datetime(time_index[0])
            )
            time_diff_minutes = (
                time_diff.total_seconds() / 60
            )
            if time_diff_minutes == 60:
                time_step_subfolder = "1h"
            elif time_diff_minutes == 30:
                time_step_subfolder = "30min"
            elif time_diff_minutes == 15:
                time_step_subfolder = "15min"
            else:
                raise ValueError(
                    f"Zone {zone}: unsupported time step "
                    f"{time_diff_minutes} minutes."
                )
        else:
            raise ValueError(
                f"Zone {zone}: insufficient data points "
                f"to determine time step."
            )
        # SOURCE
        source_file = (
            source_root
            / zone
            / time_step_subfolder
            / f"{data_target_year}.csv"
        )
        # DESTINATION
        destination_file = (
            destination_root
            / zone
            / time_step_subfolder
            / f"{data_target_year}.csv"
        )
        # CREATE DESTINATION DIRECTORY
        destination_file.parent.mkdir(
            parents=True,
            exist_ok=True
        )
        # COPY / REPLACE
        shutil.copy2(
            source_file,
            destination_file
        )
        # RECORD
        copied_files.append(
            f"{zone}: "
            f"{source_file.name} -> "
            f"{destination_file.name} "
            f"(Standard, {time_step_subfolder})"
        )
# SUMMARY
print("\nCopy Summary")
print("-" * 80)
for item in copied_files:
    print(item)
print(
    f"\nTotal files copied: "
    f"{len(copied_files)}"
)
# Out:
# VPP enabled
# --------------------------------------------------------------------------------
#
# Processing VPP zones...
#
# Processing non-VPP zones...
#
# Copy Summary
# --------------------------------------------------------------------------------
# BE: 2030_vpp.csv -> 2030.csv (VPP, 1h)
# FR: 2030.csv -> 2030.csv (Standard, 1h)
# DE: 2030.csv -> 2030.csv (Standard, 1h)
# NL: 2030.csv -> 2030.csv (Standard, 1h)
# UK: 2030.csv -> 2030.csv (Standard, 1h)
#
# Total files copied: 5

# %%
country_loads_time_series["BE"]["urban central heat"].to_csv('/home/ray/Documents/Unleash/Julios_Data/Auxiliar_Documents/testing_file12.csv', index=True)

# %% [markdown]
# <div style= "background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099; " >
#  <span style= "font-weight: bold; font-size: 16px; " >
# Section I Overview: DHW Load Desegregation & Aggregation
#  </span >
#  <div style= "border-top: 1px solid #000099; padding: 10px; " >
# This section organizes the Domestic Hot Water (DHW) demands for the VPP optimization. <br>It extracts all reshaped DHW columns from the heat load dictionaries, desegregates them by heat category for traceability, and then sums them horizontally to create a single, unified total DHW load time series per country.
#  </div >
#  </div >

# %%
# =============================================================================
### EXTRACT INDIVIDUAL RESISTIVE-HEATER DHW PROFILES
# =============================================================================

resistive_heater_dhw_profiles = {}

for country in zone_names:

    country_profiles = {}

    for heat_category in all_heat_loads:

        if heat_category not in country_loads_time_series[country]:
            continue

        df = country_loads_time_series[country][heat_category]

        if df.empty:
            continue

        dhw_columns = [
            col
            for col in df.columns
            if (
                "resistive heater" in str(col).lower()
                and str(col).endswith("DHW_demand_reshaped")
            )
        ]

        for dhw_column in dhw_columns:

            asset_name = str(dhw_column).replace(
                " DHW_demand_reshaped",
                ""
            )

            # Remove year suffix
            source_sector = re.sub(
                r"-\d{4}$",
                "",
                asset_name
            )

            country_profiles[source_sector] = (
                df[dhw_column].copy()
            )

    resistive_heater_dhw_profiles[country] = country_profiles

    print(
        f"[{country}] "
        f"{len(country_profiles)} individual "
        f"resistive-heater DHW profiles extracted."
    )

print("\n" + "=" * 100)
print("DONE: INDIVIDUAL RESISTIVE-HEATER DHW PROFILES EXTRACTED")
print("=" * 100)
# Out:
# [BE] 5 individual resistive-heater DHW profiles extracted.
# [FR] 5 individual resistive-heater DHW profiles extracted.
# [DE] 5 individual resistive-heater DHW profiles extracted.
# [NL] 5 individual resistive-heater DHW profiles extracted.
# [UK] 10 individual resistive-heater DHW profiles extracted.
#
# ====================================================================================================
# DONE: INDIVIDUAL RESISTIVE-HEATER DHW PROFILES EXTRACTED
# ====================================================================================================

# %%
if VPP:

    # =============================================================================
    ### LOAD FINAL VPP DEFINITIONS FROM THE FLEET DATASET
    # =============================================================================
    
    vpp_units_dictionary = {}
    
    for zone in zone_names:
    
        vpp_power_plants_file = (
            power_plants_pypsa_formated_data_folder_path
            / zone
            / f"{data_target_year}_vpp.csv"
        )
    
        vpp_units_df = pd.read_csv(vpp_power_plants_file)
    
        vpp_units_df = vpp_units_df[
            vpp_units_df["Unit"].astype(str).str.contains(
                "Resistive_Heaters_VPP_",
                case=False,
                na=False
            )
        ].copy()
    
        vpp_units_dictionary[zone] = vpp_units_df
    
        print("=" * 100)
        print(f"FINAL VPP DEFINITIONS LOADED: {zone}")
        print("=" * 100)
    
        print(
            vpp_units_df[
                [
                    "Unit",
                    "Sector1",
                    "Efficiency",
                    "VPP_SourceSectors"
                ]
            ].to_string(index=False)
        )
    
        print("=" * 100)
else:
    pass
# Out:
# ====================================================================================================
# FINAL VPP DEFINITIONS LOADED: BE
# ====================================================================================================
#                       Unit      Sector1  Efficiency                                                                                                                                                                    VPP_SourceSectors
#  Resistive_Heaters_VPP_0.9  DHW_VPP_0.9        0.90 BE1 0 residential rural resistive heater; BE1 0 residential urban decentral resistive heater; BE1 0 services urban decentral resistive heater; BE1 0 services rural resistive heater
# Resistive_Heaters_VPP_0.99 DHW_VPP_0.99        0.99                                                                                                                                                 BE1 0 urban central resistive heater
# ====================================================================================================
# ====================================================================================================
# FINAL VPP DEFINITIONS LOADED: FR
# ====================================================================================================
#                       Unit      Sector1  Efficiency                                                                                                                                                                    VPP_SourceSectors
#  Resistive_Heaters_VPP_0.9  DHW_VPP_0.9        0.90 FR1 0 residential rural resistive heater; FR1 0 residential urban decentral resistive heater; FR1 0 services urban decentral resistive heater; FR1 0 services rural resistive heater
# Resistive_Heaters_VPP_0.99 DHW_VPP_0.99        0.99                                                                                                                                                 FR1 0 urban central resistive heater
# ====================================================================================================
# ====================================================================================================
# FINAL VPP DEFINITIONS LOADED: DE
# ====================================================================================================
#                       Unit      Sector1  Efficiency                                                                                                                                                                    VPP_SourceSectors
#  Resistive_Heaters_VPP_0.9  DHW_VPP_0.9        0.90 DE1 0 residential rural resistive heater; DE1 0 residential urban decentral resistive heater; DE1 0 services urban decentral resistive heater; DE1 0 services rural resistive heater
# Resistive_Heaters_VPP_0.99 DHW_VPP_0.99        0.99                                                                                                                                                 DE1 0 urban central resistive heater
# ====================================================================================================
# ====================================================================================================
# FINAL VPP DEFINITIONS LOADED: NL
# ====================================================================================================
#                       Unit      Sector1  Efficiency                                                                                                                                                                    VPP_SourceSectors
#  Resistive_Heaters_VPP_0.9  DHW_VPP_0.9        0.90 NL1 0 residential rural resistive heater; NL1 0 residential urban decentral resistive heater; NL1 0 services urban decentral resistive heater; NL1 0 services rural resistive heater
# Resistive_Heaters_VPP_0.99 DHW_VPP_0.99        0.99                                                                                                                                                 NL1 0 urban central resistive heater
# ====================================================================================================
# ====================================================================================================
# FINAL VPP DEFINITIONS LOADED: UK
# ====================================================================================================
#                       Unit      Sector1  Efficiency                                                                                                                                                                                                                                                                                                                                                          VPP_SourceSectors
#  Resistive_Heaters_VPP_0.9  DHW_VPP_0.9        0.90 GB0 0 residential rural resistive heater; GB2 0 residential rural resistive heater; GB0 0 residential urban decentral resistive heater; GB2 0 residential urban decentral resistive heater; GB0 0 services urban decentral resistive heater; GB2 0 services urban decentral resistive heater; GB0 0 services rural resistive heater; GB2 0 services rural resistive heater
# Resistive_Heaters_VPP_0.99 DHW_VPP_0.99        0.99                                                                                                                                                                                                                                                                                                 GB0 0 urban central resistive heater; GB2 0 urban central resistive heater
# ====================================================================================================

# %% [markdown]
# <div style= "background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099; " >
#     <span style="font-weight: bold;">
#         I-1. Creating DHW Load Desegregated Dictionary
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process extracts all <b>DHW_demand_reshaped</b> columns from the <b>country_loads_time_series</b> dictionary and organizes them into a <b>desegregated</b> structure.<br>
#         Each heat load category's DHW columns are renamed with a suffix to preserve their origin, and all columns are combined into a single DataFrame per zone.<br>
#     <b>Desegregation Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each zone, the script iterates through all heat load categories (subkeys) and identifies columns containing <b>"DHW_demand_reshaped"</b>.<br>For each category, it extracts the matching columns and renames them by appending the subkey (with spaces replaced by underscores) to the original column name.<br>All extracted DataFrames are then concatenated <b>horizontally</b> into a single DataFrame per zone.
#          This desegregated structure provides a clear view of all DHW demand profiles organized by heat load category.
#         </div>
#     </div>
# </div>

# %%
'''DHW_load_desegregated = {}
for zone in zone_names:
    zone_dhw_data = {}
    for subkey, df in country_loads_time_series[zone].items():
        # Find columns containing "DHW_demand_reshaped"
        dhw_columns = [
            column
            for column in df.columns
            if "DHW_demand_reshaped" in str(column)
        ]
        if len(dhw_columns) == 0:
            continue
        # Copy only the selected columns
        dhw_df = df[dhw_columns].copy()
        # Rename each selected column by adding the subkey
        dhw_df.columns = [
            f"{column}_{subkey.replace(' ', '_')}"
            for column in dhw_df.columns
        ]
        zone_dhw_data[subkey] = dhw_df
    # Combine all subkeys horizontally, keeping the vertical index
    if zone_dhw_data:
        DHW_load_desegregated[zone] = pd.concat(
            zone_dhw_data.values(),
            axis=1
        )
    else:
        DHW_load_desegregated[zone] = pd.DataFrame(
            index=country_loads_time_series[zone].index
        )
print("\nDHW_load_desegregated successfully created.\n")
for zone, df in DHW_load_desegregated.items():
    print(
        f"Zone: {zone} \n "
        f"Rows: {len(df):,} \n "
        f"Columns ({len(df.columns)}): {list(df.columns)}"
    )'''
# Out:
# 'DHW_load_desegregated = {}\nfor zone in zone_names:\n    zone_dhw_data = {}\n    for subkey, df in country_loads_time_series[zone].items():\n        # Find columns containing "DHW_demand_reshaped"\n        dhw_columns = [\n            column\n            for column in df.columns\n            if "DHW_demand_reshaped" in str(column)\n        ]\n        if len(dhw_columns) == 0:\n            continue\n        # Copy only the selected columns\n        dhw_df = df[dhw_columns].copy()\n        # Rename each selected column by adding the subkey\n        dhw_df.columns = [\n            f"{column}_{subkey.replace(\' \', \'_\')}"\n            for column in dhw_df.columns\n        ]\n        zone_dhw_data[subkey] = dhw_df\n    # Combine all subkeys horizontally, keeping the vertical index\n    if zone_dhw_data:\n        DHW_load_desegregated[zone] = pd.concat(\n            zone_dhw_data.values(),\n            axis=1\n        )\n    else:\n        DHW_load_desegregated[zone] = pd.DataFrame(\n            index=country_loads_time_series[zone].index\n        )\nprint("\nDHW_load_desegregated successfully created.\n")\nfor zone, df in DHW_load_desegregated.items():\n    print(\n        f"Zone: {zone} \n "\n        f"Rows: {len(df):,} \n "\n        f"Columns ({len(df.columns)}): {list(df.columns)}"\n    )'

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         I-2. Creating DHW_load Dictionary (Total DHW Load)
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process creates the <b>DHW_load</b> dictionary by summing all columns of the <b>DHW_load_desegregated</b> DataFrame for each country.<br>
#         The result is a <b>single time series</b> per country representing the <b>total Domestic Hot Water (DHW) load</b> at each snapshot.<br>
#     <b>Aggregation Logic:</b>
#         <div style="margin-left: 2em; font-size: 12px;">
#         For each country, the script ensures that the <b>snapshot</b> is set as the DatetimeIndex.<br>
#         It then selects all columns except "snapshot" and calculates the <b>row-wise sum</b> using <b>df.sum(axis=1)</b>.<br>
#         The resulting total DHW load is stored as a single-column DataFrame named <b>"DHW_load"</b> with the snapshot as the index.<br>
#         A summary report displays the number of DHW columns summed and the number of snapshots per country.
#         </div>
#     </div>
# </div>

# %%
'''# CREATE DHW_LOAD DICTIONARY
# For each country in zone_names:
#     DHW_load[country]
# is the sum of ALL columns in:
#     DHW_load_desegregated[country]
# The snapshot index is preserved.
DHW_load = {}
# PROCESS EACH COUNTRY
for country in zone_names:
    print(f"\n--- Processing DHW Load: {country} ---")
    # GET COUNTRY DATAFRAME
    dhw_desegregated_df = DHW_load_desegregated[country]
    # MAKE SURE SNAPSHOT IS THE INDEX
    if "snapshot" in dhw_desegregated_df.columns:
        dhw_desegregated_df = dhw_desegregated_df.copy()
        dhw_desegregated_df["snapshot"] = pd.to_datetime(
            dhw_desegregated_df["snapshot"]
        )
        dhw_desegregated_df = dhw_desegregated_df.set_index(
            "snapshot"
        )
    else:
        dhw_desegregated_df = dhw_desegregated_df.copy()
        dhw_desegregated_df.index = pd.to_datetime(
            dhw_desegregated_df.index
        )
    # SELECT ALL DATA COLUMNS
    # Exclude snapshot if it somehow remains as a column.
    dhw_columns = [
        col
        for col in dhw_desegregated_df.columns
        if col != "snapshot"
    ]
    # SUM ALL DHW LOAD COLUMNS ROW-BY-ROW
    total_dhw = dhw_desegregated_df[dhw_columns].sum(
        axis=1
    )
    # CREATE OUTPUT DATAFRAME
    DHW_load[country] = pd.DataFrame(
        {
            "DHW_load": total_dhw
        },
        index=dhw_desegregated_df.index
    )
    DHW_load[country].index.name = "snapshot"
    print(
        f"  ✅ {country}: "
        f"Summed {len(dhw_columns)} DHW columns."
    )
    print(
        f"  → {len(DHW_load[country])} snapshots."
    )
print(
    "\nDone! Created 'DHW_load' "
    "with one total DHW load time series per country."
)'''
# Out:
# '# CREATE DHW_LOAD DICTIONARY\n# For each country in zone_names:\n#     DHW_load[country]\n# is the sum of ALL columns in:\n#     DHW_load_desegregated[country]\n# The snapshot index is preserved.\nDHW_load = {}\n# PROCESS EACH COUNTRY\nfor country in zone_names:\n    print(f"\n--- Processing DHW Load: {country} ---")\n    # GET COUNTRY DATAFRAME\n    dhw_desegregated_df = DHW_load_desegregated[country]\n    # MAKE SURE SNAPSHOT IS THE INDEX\n    if "snapshot" in dhw_desegregated_df.columns:\n        dhw_desegregated_df = dhw_desegregated_df.copy()\n        dhw_desegregated_df["snapshot"] = pd.to_datetime(\n            dhw_desegregated_df["snapshot"]\n        )\n        dhw_desegregated_df = dhw_desegregated_df.set_index(\n            "snapshot"\n        )\n    else:\n        dhw_desegregated_df = dhw_desegregated_df.copy()\n        dhw_desegregated_df.index = pd.to_datetime(\n            dhw_desegregated_df.index\n        )\n    # SELECT ALL DATA COLUMNS\n    # Exclude snapshot if it somehow remains as a column.\n    dhw_columns = [\n        col\n        for col in dhw_desegregated_df.columns\n        if col != "snapshot"\n    ]\n    # SUM ALL DHW LOAD COLUMNS ROW-BY-ROW\n    total_dhw = dhw_desegregated_df[dhw_columns].sum(\n        axis=1\n    )\n    # CREATE OUTPUT DATAFRAME\n    DHW_load[country] = pd.DataFrame(\n        {\n            "DHW_load": total_dhw\n        },\n        index=dhw_desegregated_df.index\n    )\n    DHW_load[country].index.name = "snapshot"\n    print(\n        f"  ✅ {country}: "\n        f"Summed {len(dhw_columns)} DHW columns."\n    )\n    print(\n        f"  → {len(DHW_load[country])} snapshots."\n    )\nprint(\n    "\nDone! Created \'DHW_load\' "\n    "with one total DHW load time series per country."\n)'

# %%
if VPP:
# =============================================================================
    ### COUNTRY-LEVEL VPP DHW THERMAL LOAD PROFILES
    # =============================================================================
    #
    # IMPORTANT:
    # VPP Sector 1 represents THERMAL DHW demand.
    #
    # Therefore, this aggregation uses only:
    #
    #     XXX 0 ... resistive heater-20XX DHW_demand_reshaped
    #
    # and NEVER:
    #
    #     XXX 0 ... resistive heater-20XX DHW_demand_reshaped_/Efficiency
    #
    # The VPP fleet efficiency is handled by the VPP PowerPlants definition
    # through EfficiencySector1 / ChargingEfficiencySector1.
    # =============================================================================
    
    vpp_dhw_loads = {}
    
    for country, loads_dict in country_loads_time_series.items():
    
        # -------------------------------------------------------------------------
        # Only countries with VPP definitions are processed
        # -------------------------------------------------------------------------
    
        if country not in vpp_units_dictionary:
            continue
    
        vpp_df = vpp_units_dictionary[country]
    
        if vpp_df.empty:
            continue
    
        # Temporary container for this country's VPP profiles
        country_vpp_profiles = {}
    
        print("\n" + "=" * 100)
        print(
            f"BUILDING VPP DHW THERMAL PROFILES: {country}"
        )
        print("=" * 100)
    
        # -------------------------------------------------------------------------
        # Loop over the VPP fleet definitions
        # -------------------------------------------------------------------------
    
        for _, vpp_row in vpp_df.iterrows():
    
            vpp_unit = str(
                vpp_row["Unit"]
            )
    
            vpp_sector = str(
                vpp_row["Sector1"]
            )
    
            source_sectors_raw = (
                vpp_row["VPP_SourceSectors"]
            )
    
            # ---------------------------------------------------------------------
            # Check source-sector definition
            # ---------------------------------------------------------------------
    
            if pd.isna(source_sectors_raw):
    
                print(
                    f"\n⚠️ {vpp_unit}: "
                    f"No VPP_SourceSectors defined."
                )
    
                continue
    
            source_sectors = [
                sector.strip()
                for sector in str(
                    source_sectors_raw
                ).split(";")
                if sector.strip()
            ]
    
            if not source_sectors:
    
                print(
                    f"\n⚠️ {vpp_unit}: "
                    f"VPP_SourceSectors is empty."
                )
    
                continue
    
            print(
                f"\nVPP unit: {vpp_unit}"
            )
    
            print(
                f"Sector 1: {vpp_sector}"
            )
    
            print(
                "Source sectors:"
            )
    
            for source_sector in source_sectors:
    
                print(
                    f"   - {source_sector}"
                )
    
            # ---------------------------------------------------------------------
            # Find individual thermal DHW profiles
            # ---------------------------------------------------------------------
    
            matched_profiles = []
            matched_units = set()
    
            for current_heat_load, ts_df in loads_dict.items():
    
                if ts_df.empty:
                    continue
    
                # -----------------------------------------------------------------
                # Only select the thermal DHW profiles
                #
                # This selects:
                #
                #     ... DHW_demand_reshaped
                #
                # and excludes:
                #
                #     ... DHW_demand_reshaped_/Efficiency
                # -----------------------------------------------------------------
    
                dhw_cols = [
                    col
                    for col in ts_df.columns
                    if (
                        "resistive heater"
                        in str(col).lower()
                        and str(col).endswith(
                            "DHW_demand_reshaped"
                        )
                    )
                ]
    
                if not dhw_cols:
                    continue
    
                # -----------------------------------------------------------------
                # Match each individual heater to VPP_SourceSectors
                # -----------------------------------------------------------------
    
                for dhw_col in dhw_cols:
    
                    # Recover original asset name
                    #
                    # Example:
                    #
                    # BE1 0 services urban decentral resistive heater-2019
                    # DHW_demand_reshaped
                    #
                    # becomes:
                    #
                    # BE1 0 services urban decentral resistive heater-2019
                    #
                    asset_name = str(
                        dhw_col
                    ).replace(
                        " DHW_demand_reshaped",
                        ""
                    )
    
                    # Remove year suffix for comparison with
                    # VPP_SourceSectors.
                    #
                    # Example:
                    #
                    # BE1 0 services urban decentral resistive heater-2019
                    #
                    # becomes:
                    #
                    # BE1 0 services urban decentral resistive heater
                    #
                    source_sector = re.sub(
                        r"-\d{4}$",
                        "",
                        asset_name
                    )
    
                    # -------------------------------------------------------------
                    # Match against fleet-side VPP source sectors
                    # -------------------------------------------------------------
    
                    if source_sector not in source_sectors:
                        continue
    
                    # -------------------------------------------------------------
                    # Avoid accidental double counting
                    # -------------------------------------------------------------
    
                    if asset_name in matched_units:
    
                        print(
                            f"   ⚠️ Duplicate profile skipped: "
                            f"{asset_name}"
                        )
    
                        continue
    
                    # -------------------------------------------------------------
                    # Use THERMAL DHW profile directly
                    #
                    # No division by efficiency.
                    # -------------------------------------------------------------
    
                    thermal_profile = (
                        pd.to_numeric(
                            ts_df[dhw_col],
                            errors="coerce"
                        )
                        .fillna(0.0)
                    )
    
                    matched_profiles.append(
                        thermal_profile
                    )
    
                    matched_units.add(
                        asset_name
                    )
    
                    print(
                        f"   ✅ Matched: "
                        f"{asset_name}"
                        f" | Heat category: "
                        f"{current_heat_load}"
                    )
    
            # ---------------------------------------------------------------------
            # Check whether any source profiles were found
            # ---------------------------------------------------------------------
    
            if not matched_profiles:
    
                print(
                    f"\n⚠️ {vpp_unit}: "
                    f"No DHW thermal profiles matched "
                    f"VPP_SourceSectors."
                )
    
                continue
    
            # ---------------------------------------------------------------------
            # Aggregate all individual thermal DHW profiles
            # ---------------------------------------------------------------------
    
            vpp_dhw_profile = (
                pd.concat(
                    matched_profiles,
                    axis=1
                )
                .sum(axis=1)
            )
    
            # ---------------------------------------------------------------------
            # Store profile temporarily
            # ---------------------------------------------------------------------
    
            country_vpp_profiles[
                vpp_sector
            ] = vpp_dhw_profile
    
            # ---------------------------------------------------------------------
            # Diagnostics
            # ---------------------------------------------------------------------
    
            print(
                f"\n   ✅ {vpp_sector}: "
                f"{len(matched_units)} individual "
                f"source-unit profiles aggregated."
            )
    
            print(
                f"   Annual thermal DHW energy: "
                f"{vpp_dhw_profile.sum():.6f}"
            )
    
            print(
                f"   Maximum thermal DHW demand: "
                f"{vpp_dhw_profile.max():.6f}"
            )
    
            print(
                f"   Average thermal DHW demand: "
                f"{vpp_dhw_profile.mean():.6f}"
            )
    
            print(
                "\n   Aggregated source units:"
            )
    
            for asset_name in sorted(
                matched_units
            ):
    
                print(
                    f"      - {asset_name}"
                )
    
        # -------------------------------------------------------------------------
        # Convert country's VPP profiles into ONE DataFrame
        # -------------------------------------------------------------------------
    
        if country_vpp_profiles:
    
            vpp_dhw_loads[country] = pd.DataFrame(
                country_vpp_profiles
            )
    
        print(
            f"\n✅ {country}: "
            f"{len(country_vpp_profiles)} VPP DHW profiles "
            f"stored in one DataFrame."
        )
    
    
    # =============================================================================
    ### FINAL SUMMARY
    # =============================================================================
    
    print(
        "\n" + "=" * 100
    )
    
    print(
        "DONE: VPP DHW THERMAL LOAD PROFILES HAVE BEEN CONSTRUCTED."
    )
    
    print(
        "=" * 100
    )
    
    for country, vpp_profiles_df in vpp_dhw_loads.items():
    
        print(
            f"\nCountry: {country}"
        )
    
        print(
            f"   DataFrame shape: "
            f"{vpp_profiles_df.shape}"
        )
    
        print(
            f"   Columns: "
            f"{vpp_profiles_df.columns.tolist()}"
        )
    
        for vpp_sector in vpp_profiles_df.columns:
    
            profile = vpp_profiles_df[vpp_sector]
    
            print(
                f"   {vpp_sector}: "
                f"{len(profile)} observations | "
                f"Annual thermal energy = "
                f"{profile.sum():.6f}"
            )
    
    print(
        "\nIMPORTANT:"
    )
    
    print(
        "VPP Sector 1 aggregation uses only "
        "'DHW_demand_reshaped' thermal columns."
    )
    
    print(
        "The '/Efficiency' columns are NOT used "
        "for VPP Sector 1 aggregation."
    )
    
    print(
        "VPP efficiency is handled by the VPP fleet "
        "definition through EfficiencySector1 / "
        "ChargingEfficiencySector1."
    )
    
    print(
        "=" * 100
    )
else:
    pass
# Out:
# ====================================================================================================
# BUILDING VPP DHW THERMAL PROFILES: BE
# ====================================================================================================
#
# VPP unit: Resistive_Heaters_VPP_0.9
# Sector 1: DHW_VPP_0.9
# Source sectors:
#    - BE1 0 residential rural resistive heater
#    - BE1 0 residential urban decentral resistive heater
#    - BE1 0 services urban decentral resistive heater
#    - BE1 0 services rural resistive heater
#    ✅ Matched: BE1 0 services urban decentral resistive heater-2030 | Heat category: services urban decentral heat
#    ✅ Matched: BE1 0 services urban decentral resistive heater-2015 | Heat category: services urban decentral heat
#    ✅ Matched: BE1 0 services urban decentral resistive heater-2019 | Heat category: services urban decentral heat
#    ✅ Matched: BE1 0 services rural resistive heater-2030 | Heat category: services rural heat
#    ✅ Matched: BE1 0 residential rural resistive heater-2030 | Heat category: residential rural heat
#    ✅ Matched: BE1 0 residential rural resistive heater-2015 | Heat category: residential rural heat
#    ✅ Matched: BE1 0 residential rural resistive heater-2019 | Heat category: residential rural heat
#    ✅ Matched: BE1 0 residential urban decentral resistive heater-2030 | Heat category: residential urban decentral heat
#    ✅ Matched: BE1 0 residential urban decentral resistive heater-2015 | Heat category: residential urban decentral heat
#    ✅ Matched: BE1 0 residential urban decentral resistive heater-2019 | Heat category: residential urban decentral heat
#
#    ✅ DHW_VPP_0.9: 10 individual source-unit profiles aggregated.
#    Annual thermal DHW energy: 3792010.763253
#    Maximum thermal DHW demand: 1052.627735
#    Average thermal DHW demand: 432.877941
#
#    Aggregated source units:
#       - BE1 0 residential rural resistive heater-2015
#       - BE1 0 residential rural resistive heater-2019
#       - BE1 0 residential rural resistive heater-2030
#       - BE1 0 residential urban decentral resistive heater-2015
#       - BE1 0 residential urban decentral resistive heater-2019
#       - BE1 0 residential urban decentral resistive heater-2030
#       - BE1 0 services rural resistive heater-2030
#       - BE1 0 services urban decentral resistive heater-2015
#       - BE1 0 services urban decentral resistive heater-2019
#       - BE1 0 services urban decentral resistive heater-2030
#
# VPP unit: Resistive_Heaters_VPP_0.99
# Sector 1: DHW_VPP_0.99
# Source sectors:
#    - BE1 0 urban central resistive heater
#    ✅ Matched: BE1 0 urban central resistive heater-2030 | Heat category: urban central heat
#
#    ✅ DHW_VPP_0.99: 1 individual source-unit profiles aggregated.
#    Annual thermal DHW energy: 933778.252973
#    Maximum thermal DHW demand: 259.208359
#    Average thermal DHW demand: 106.595691
#
#    Aggregated source units:
#       - BE1 0 urban central resistive heater-2030
#
# ✅ BE: 2 VPP DHW profiles stored in one DataFrame.
#
# ====================================================================================================
# BUILDING VPP DHW THERMAL PROFILES: FR
# ====================================================================================================
#
# VPP unit: Resistive_Heaters_VPP_0.9
# Sector 1: DHW_VPP_0.9
# Source sectors:
#    - FR1 0 residential rural resistive heater
#    - FR1 0 residential urban decentral resistive heater
#    - FR1 0 services urban decentral resistive heater
#    - FR1 0 services rural resistive heater
#    ✅ Matched: FR1 0 services urban decentral resistive heater-2030 | Heat category: services urban decentral heat
#    ✅ Matched: FR1 0 services urban decentral resistive heater-2015 | Heat category: services urban decentral heat
#    ✅ Matched: FR1 0 services urban decentral resistive heater-2019 | Heat category: services urban decentral heat
#    ✅ Matched: FR1 0 services rural resistive heater-2030 | Heat category: services rural heat
#    ✅ Matched: FR1 0 services rural resistive heater-2015 | Heat category: services rural heat
#    ✅ Matched: FR1 0 services rural resistive heater-2019 | Heat category: services rural heat
#    ✅ Matched: FR1 0 residential rural resistive heater-2030 | Heat category: residential rural heat
#    ✅ Matched: FR1 0 residential rural resistive heater-2015 | Heat category: residential rural heat
#    ✅ Matched: FR1 0 residential rural resistive heater-2019 | Heat category: residential rural heat
#    ✅ Matched: FR1 0 residential urban decentral resistive heater-2030 | Heat category: residential urban decentral heat
#    ✅ Matched: FR1 0 residential urban decentral resistive heater-2015 | Heat category: residential urban decentral heat
#    ✅ Matched: FR1 0 residential urban decentral resistive heater-2019 | Heat category: residential urban decentral heat
#
#    ✅ DHW_VPP_0.9: 12 individual source-unit profiles aggregated.
#    Annual thermal DHW energy: 51868001.853080
#    Maximum thermal DHW demand: 14398.086064
#    Average thermal DHW demand: 5921.004778
#
#    Aggregated source units:
#       - FR1 0 residential rural resistive heater-2015
#       - FR1 0 residential rural resistive heater-2019
#       - FR1 0 residential rural resistive heater-2030
#       - FR1 0 residential urban decentral resistive heater-2015
#       - FR1 0 residential urban decentral resistive heater-2019
#       - FR1 0 residential urban decentral resistive heater-2030
#       - FR1 0 services rural resistive heater-2015
#       - FR1 0 services rural resistive heater-2019
#       - FR1 0 services rural resistive heater-2030
#       - FR1 0 services urban decentral resistive heater-2015
#       - FR1 0 services urban decentral resistive heater-2019
#       - FR1 0 services urban decentral resistive heater-2030
#
# VPP unit: Resistive_Heaters_VPP_0.99
# Sector 1: DHW_VPP_0.99
# Source sectors:
#    - FR1 0 urban central resistive heater
#    ✅ Matched: FR1 0 urban central resistive heater-2030 | Heat category: urban central heat
#
#    ✅ DHW_VPP_0.99: 1 individual source-unit profiles aggregated.
#    Annual thermal DHW energy: 1974492.008481
#    Maximum thermal DHW demand: 548.101042
#    Average thermal DHW demand: 225.398631
#
#    Aggregated source units:
#       - FR1 0 urban central resistive heater-2030
#
# ✅ FR: 2 VPP DHW profiles stored in one DataFrame.
#
# ====================================================================================================
# BUILDING VPP DHW THERMAL PROFILES: DE
# ====================================================================================================
#
# VPP unit: Resistive_Heaters_VPP_0.9
# Sector 1: DHW_VPP_0.9
# Source sectors:
#    - DE1 0 residential rural resistive heater
#    - DE1 0 residential urban decentral resistive heater
#    - DE1 0 services urban decentral resistive heater
#    - DE1 0 services rural resistive heater
#    ✅ Matched: DE1 0 services urban decentral resistive heater-2030 | Heat category: services urban decentral heat
#    ✅ Matched: DE1 0 services rural resistive heater-2030 | Heat category: services rural heat
#    ✅ Matched: DE1 0 residential rural resistive heater-2030 | Heat category: residential rural heat
#    ✅ Matched: DE1 0 residential urban decentral resistive heater-2030 | Heat category: residential urban decentral heat
#
#    ✅ DHW_VPP_0.9: 4 individual source-unit profiles aggregated.
#    Annual thermal DHW energy: 19180182.715362
#    Maximum thermal DHW demand: 5324.244459
#    Average thermal DHW demand: 2189.518575
#
#    Aggregated source units:
#       - DE1 0 residential rural resistive heater-2030
#       - DE1 0 residential urban decentral resistive heater-2030
#       - DE1 0 services rural resistive heater-2030
#       - DE1 0 services urban decentral resistive heater-2030
#
# VPP unit: Resistive_Heaters_VPP_0.99
# Sector 1: DHW_VPP_0.99
# Source sectors:
#    - DE1 0 urban central resistive heater
#    ✅ Matched: DE1 0 urban central resistive heater-2030 | Heat category: urban central heat
#
#    ✅ DHW_VPP_0.99: 1 individual source-unit profiles aggregated.
#    Annual thermal DHW energy: 9392850.812406
#    Maximum thermal DHW demand: 2607.370046
#    Average thermal DHW demand: 1072.243243
#
#    Aggregated source units:
#       - DE1 0 urban central resistive heater-2030
#
# ✅ DE: 2 VPP DHW profiles stored in one DataFrame.
#
# ====================================================================================================
# BUILDING VPP DHW THERMAL PROFILES: NL
# ====================================================================================================
#
# VPP unit: Resistive_Heaters_VPP_0.9
# Sector 1: DHW_VPP_0.9
# Source sectors:
#    - NL1 0 residential rural resistive heater
#    - NL1 0 residential urban decentral resistive heater
#    - NL1 0 services urban decentral resistive heater
#    - NL1 0 services rural resistive heater
#    ✅ Matched: NL1 0 services urban decentral resistive heater-2030 | Heat category: services urban decentral heat
#    ✅ Matched: NL1 0 services rural resistive heater-2030 | Heat category: services rural heat
#    ✅ Matched: NL1 0 residential rural resistive heater-2030 | Heat category: residential rural heat
#    ✅ Matched: NL1 0 residential urban decentral resistive heater-2030 | Heat category: residential urban decentral heat
#    ✅ Matched: NL1 0 residential urban decentral resistive heater-2015 | Heat category: residential urban decentral heat
#    ✅ Matched: NL1 0 residential urban decentral resistive heater-2019 | Heat category: residential urban decentral heat
#
#    ✅ DHW_VPP_0.9: 6 individual source-unit profiles aggregated.
#    Annual thermal DHW energy: 3561094.236786
#    Maximum thermal DHW demand: 988.527406
#    Average thermal DHW demand: 406.517607
#
#    Aggregated source units:
#       - NL1 0 residential rural resistive heater-2030
#       - NL1 0 residential urban decentral resistive heater-2015
#       - NL1 0 residential urban decentral resistive heater-2019
#       - NL1 0 residential urban decentral resistive heater-2030
#       - NL1 0 services rural resistive heater-2030
#       - NL1 0 services urban decentral resistive heater-2030
#
# VPP unit: Resistive_Heaters_VPP_0.99
# Sector 1: DHW_VPP_0.99
# Source sectors:
#    - NL1 0 urban central resistive heater
#    ✅ Matched: NL1 0 urban central resistive heater-2030 | Heat category: urban central heat
#
#    ✅ DHW_VPP_0.99: 1 individual source-unit profiles aggregated.
#    Annual thermal DHW energy: 7991663.584097
#    Maximum thermal DHW demand: 2218.413202
#    Average thermal DHW demand: 912.290363
#
#    Aggregated source units:
#       - NL1 0 urban central resistive heater-2030
#
# ✅ NL: 2 VPP DHW profiles stored in one DataFrame.
#
# ====================================================================================================
# BUILDING VPP DHW THERMAL PROFILES: UK
# ====================================================================================================
#
# VPP unit: Resistive_Heaters_VPP_0.9
# Sector 1: DHW_VPP_0.9
# Source sectors:
#    - GB0 0 residential rural resistive heater
#    - GB2 0 residential rural resistive heater
#    - GB0 0 residential urban decentral resistive heater
#    - GB2 0 residential urban decentral resistive heater
#    - GB0 0 services urban decentral resistive heater
#    - GB2 0 services urban decentral resistive heater
#    - GB0 0 services rural resistive heater
#    - GB2 0 services rural resistive heater
#    ✅ Matched: GB0 0 services urban decentral resistive heater-2030 | Heat category: services urban decentral heat
#    ✅ Matched: GB2 0 services urban decentral resistive heater-2030 | Heat category: services urban decentral heat
#    ✅ Matched: GB0 0 services urban decentral resistive heater-2015 | Heat category: services urban decentral heat
#    ✅ Matched: GB0 0 services urban decentral resistive heater-2019 | Heat category: services urban decentral heat
#    ✅ Matched: GB0 0 services rural resistive heater-2030 | Heat category: services rural heat
#    ✅ Matched: GB2 0 services rural resistive heater-2030 | Heat category: services rural heat
#    ✅ Matched: GB0 0 services rural resistive heater-2015 | Heat category: services rural heat
#    ✅ Matched: GB2 0 services rural resistive heater-2015 | Heat category: services rural heat
#    ✅ Matched: GB0 0 services rural resistive heater-2019 | Heat category: services rural heat
#    ✅ Matched: GB2 0 services rural resistive heater-2019 | Heat category: services rural heat
#    ✅ Matched: GB0 0 residential rural resistive heater-2030 | Heat category: residential rural heat
#    ✅ Matched: GB2 0 residential rural resistive heater-2030 | Heat category: residential rural heat
#    ✅ Matched: GB0 0 residential rural resistive heater-2015 | Heat category: residential rural heat
#    ✅ Matched: GB2 0 residential rural resistive heater-2015 | Heat category: residential rural heat
#    ✅ Matched: GB0 0 residential rural resistive heater-2019 | Heat category: residential rural heat
#    ✅ Matched: GB2 0 residential rural resistive heater-2019 | Heat category: residential rural heat
#    ✅ Matched: GB0 0 residential urban decentral resistive heater-2030 | Heat category: residential urban decentral heat
#    ✅ Matched: GB2 0 residential urban decentral resistive heater-2030 | Heat category: residential urban decentral heat
#    ✅ Matched: GB0 0 residential urban decentral resistive heater-2015 | Heat category: residential urban decentral heat
#    ✅ Matched: GB2 0 residential urban decentral resistive heater-2015 | Heat category: residential urban decentral heat
#    ✅ Matched: GB0 0 residential urban decentral resistive heater-2019 | Heat category: residential urban decentral heat
#    ✅ Matched: GB2 0 residential urban decentral resistive heater-2019 | Heat category: residential urban decentral heat
#
#    ✅ DHW_VPP_0.9: 22 individual source-unit profiles aggregated.
#    Annual thermal DHW energy: 47293190.480477
#    Maximum thermal DHW demand: 13128.159992
#    Average thermal DHW demand: 5398.766037
#
#    Aggregated source units:
#       - GB0 0 residential rural resistive heater-2015
#       - GB0 0 residential rural resistive heater-2019
#       - GB0 0 residential rural resistive heater-2030
#       - GB0 0 residential urban decentral resistive heater-2015
#       - GB0 0 residential urban decentral resistive heater-2019
#       - GB0 0 residential urban decentral resistive heater-2030
#       - GB0 0 services rural resistive heater-2015
#       - GB0 0 services rural resistive heater-2019
#       - GB0 0 services rural resistive heater-2030
#       - GB0 0 services urban decentral resistive heater-2015
#       - GB0 0 services urban decentral resistive heater-2019
#       - GB0 0 services urban decentral resistive heater-2030
#       - GB2 0 residential rural resistive heater-2015
#       - GB2 0 residential rural resistive heater-2019
#       - GB2 0 residential rural resistive heater-2030
#       - GB2 0 residential urban decentral resistive heater-2015
#       - GB2 0 residential urban decentral resistive heater-2019
#       - GB2 0 residential urban decentral resistive heater-2030
#       - GB2 0 services rural resistive heater-2015
#       - GB2 0 services rural resistive heater-2019
#       - GB2 0 services rural resistive heater-2030
#       - GB2 0 services urban decentral resistive heater-2030
#
# VPP unit: Resistive_Heaters_VPP_0.99
# Sector 1: DHW_VPP_0.99
# Source sectors:
#    - GB0 0 urban central resistive heater
#    - GB2 0 urban central resistive heater
#    ✅ Matched: GB0 0 urban central resistive heater-2030 | Heat category: urban central heat
#    ✅ Matched: GB2 0 urban central resistive heater-2030 | Heat category: urban central heat
#
#    ✅ DHW_VPP_0.99: 2 individual source-unit profiles aggregated.
#    Annual thermal DHW energy: 6234145.919528
#    Maximum thermal DHW demand: 1730.542266
#    Average thermal DHW demand: 711.660493
#
#    Aggregated source units:
#       - GB0 0 urban central resistive heater-2030
#       - GB2 0 urban central resistive heater-2030
#
# ✅ UK: 2 VPP DHW profiles stored in one DataFrame.
#
# ====================================================================================================
# DONE: VPP DHW THERMAL LOAD PROFILES HAVE BEEN CONSTRUCTED.
# ====================================================================================================
#
# Country: BE
#    DataFrame shape: (8760, 2)
#    Columns: ['DHW_VPP_0.9', 'DHW_VPP_0.99']
#    DHW_VPP_0.9: 8760 observations | Annual thermal energy = 3792010.763253
#    DHW_VPP_0.99: 8760 observations | Annual thermal energy = 933778.252973
#
# Country: FR
#    DataFrame shape: (8760, 2)
#    Columns: ['DHW_VPP_0.9', 'DHW_VPP_0.99']
#    DHW_VPP_0.9: 8760 observations | Annual thermal energy = 51868001.853080
#    DHW_VPP_0.99: 8760 observations | Annual thermal energy = 1974492.008481
#
# Country: DE
#    DataFrame shape: (8760, 2)
#    Columns: ['DHW_VPP_0.9', 'DHW_VPP_0.99']
#    DHW_VPP_0.9: 8760 observations | Annual thermal energy = 19180182.715362
#    DHW_VPP_0.99: 8760 observations | Annual thermal energy = 9392850.812406
#
# Country: NL
#    DataFrame shape: (8760, 2)
#    Columns: ['DHW_VPP_0.9', 'DHW_VPP_0.99']
#    DHW_VPP_0.9: 8760 observations | Annual thermal energy = 3561094.236786
#    DHW_VPP_0.99: 8760 observations | Annual thermal energy = 7991663.584097
#
# Country: UK
#    DataFrame shape: (8760, 2)
#    Columns: ['DHW_VPP_0.9', 'DHW_VPP_0.99']
#    DHW_VPP_0.9: 8760 observations | Annual thermal energy = 47293190.480477
#    DHW_VPP_0.99: 8760 observations | Annual thermal energy = 6234145.919528
#
# IMPORTANT:
# VPP Sector 1 aggregation uses only 'DHW_demand_reshaped' thermal columns.
# The '/Efficiency' columns are NOT used for VPP Sector 1 aggregation.
# VPP efficiency is handled by the VPP fleet definition through EfficiencySector1 / ChargingEfficiencySector1.
# ====================================================================================================

# %% [markdown]
# <div style= "background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099; " >
#  <span style= "font-weight: bold; font-size: 16px; " >
# Section J Overview: Target Year Adjustment & DHW Export
#  </span >
#  <div style= "border-top: 1px solid #000099; padding: 10px; " >
# This section finalizes the DHW demand exports.<br> It adjusts the total DHW load time series to match the target year's temporal scope (handling leap years), renames the columns using the Sector identifiers from the VPP features CSV, and exports the finalized files to the dedicated VPP demand directory.
#  </div >
#  </div >
#  <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         J-1. Adjusting DHW_load to Target Year with Leap Year Handling
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process adjusts the <b>DHW_load</b> DataFrames to have the correct number of rows for the target year, handling <b>leap year</b> differences (February 29).<br>
#         It ensures that all DHW load DataFrames have the exact number of timesteps expected for the target year.<br>
#     <b>Adjustment Logic:</b>
#             <div style="margin-left: 2em; font-size: 12px;">
#         The script first determines if the target year is a leap year and calculates the expected number of rows (365 or 366 days × steps per day). For each zone, it:
#                 <div style="margin-left: 2em;">
#         <b>If target year has more rows</b> (leap year) → Duplicate February 28 data to create a February 29 row.<br>
#         <b>If target year has fewer rows</b> (non-leap year) → Remove February 29 data.
#                 </div>
#         The process uses a <b>temporary leap year 2000 index</b> to safely handle February 29 during processing, then reindexes to the target year with a UTC timezone.<br>
#         After adjustment, all DataFrames have the correct number of rows for the target year and are properly indexed with a UTC datetime index named "snapshot"
#         </div>
#     </div>
# </div>

# %%
if VPP:

    # TARGET YEAR SETTINGS
    target_year = int(data_target_year)
    is_leap_year = calendar.isleap(target_year)
    # =============================================================================
    steps_per_day = {
        "1h": 24,
        "30min": 48,
        "15min": 96
    }
    # =============================================================================
    expected_rows = (
        366 if is_leap_year else 365
    ) * steps_per_day[data_target_time_step]
    print(f"Target year   : {target_year}")
    print(f"Leap year     : {is_leap_year}")
    print(f"Expected rows : {expected_rows}")
    # ADJUST ALL ZONES IN DHW_LOAD
    for zone, df in vpp_dhw_loads.items():
        df = df.copy()
        actual_rows = len(df)
        print(f"\nProcessing {zone}")
        print(f"Actual rows   : {actual_rows}")
        print(f"Expected rows : {expected_rows}")
        # CREATE TEMPORARY INDEX USING LEAP YEAR 2000
        # 2000 is a leap year, so Feb-29 can exist if needed.
        base_freq = {
            "1h": "h",
            "30min": "30min",
            "15min": "15min"
        }[data_target_time_step]
        temp_index = pd.date_range(
            start="2000-01-01 00:00:00",
            periods=actual_rows,
            freq=base_freq
        )
        df.index = temp_index
        # TARGET YEAR HAS MORE ROWS
        # ADD FEBRUARY 29
        if expected_rows > actual_rows:
            feb28_mask = (
                (temp_index.month == 2)
                & (temp_index.day == 28)
            )
            feb28 = df.loc[feb28_mask].copy()
            feb29_index = feb28.index + pd.Timedelta(days=1)
            feb29 = feb28.copy()
            feb29.index = feb29_index
            df = pd.concat(
                [df, feb29]
            )
            df = df.sort_index()
        # TARGET YEAR HAS FEWER ROWS
        # REMOVE FEBRUARY 29
        elif expected_rows < actual_rows:
            df = df[
                ~(
                    (df.index.month == 2)
                    & (df.index.day == 29)
                )
            ]
        # CREATE FINAL UTC INDEX
        final_index = pd.date_range(
            start=f"{target_year}-01-01 00:00:00",
            periods=len(df),
            freq=base_freq,
            tz="UTC"
        )
        df.index = final_index
        df.index.name = "snapshot"
        # SAVE BACK TO THE DICTIONARY
        vpp_dhw_loads[zone] = df
        print(f"Final rows    : {len(df)}")
    # FINAL MESSAGE
    print(
        "\nDHW_load was adjusted "
        "to the target year."
    )
else:
    pass
# Out:
# Target year   : 2030
# Leap year     : False
# Expected rows : 8760
#
# Processing BE
# Actual rows   : 8760
# Expected rows : 8760
# Final rows    : 8760
#
# Processing FR
# Actual rows   : 8760
# Expected rows : 8760
# Final rows    : 8760
#
# Processing DE
# Actual rows   : 8760
# Expected rows : 8760
# Final rows    : 8760
#
# Processing NL
# Actual rows   : 8760
# Expected rows : 8760
# Final rows    : 8760
#
# Processing UK
# Actual rows   : 8760
# Expected rows : 8760
# Final rows    : 8760
#
# DHW_load was adjusted to the target year.

# %% [markdown]
# <div style="background-color: #FFFFFF; padding: 15px; font-family: 'Times New Roman', Times, serif; font-size: 14px; text-align: justify; color: #000099;">
#     <span style="font-weight: bold;">
#         J-2. Copying DHW Load Data to VPP Demand Directory
#     </span>
#     <div style="border-top: 1px solid #000099; padding: 10px;">
#         This process copies the <b>DHW_load</b> DataFrames to the <b>VPP demand directory</b>, renaming the columns using <b>Sector values</b> from the VPP features CSV.<br>
#         The time step is automatically detected from the index, and the files are saved in the appropriate subfolder.<br>
#     <b>Copy Logic:</b>
#             <div style="margin-left: 2em; font-size: 12px;">
#         For each zone, the script retrieves the DHW DataFrame and determines the time step from the index (1h, 30min, or 15min).<br>
#         It then reads the VPP features CSV and extracts the <b>Sector</b> values.<br>
#         The number of DHW columns is validated against the number of Sector values, and the DHW columns are <b>renamed</b> using the Sector values.<br>
#         The renamed DataFrame is saved in the destination directory with the index included.<br>
#         This ensures that DHW load data is correctly formatted for VPP demand profiles.
#             </div>
#     </div>
# </div>

# %%
if VPP:
    # =============================================================================
    ### COPY VPP DHW LOAD DATA TO VPP DEMAND DIRECTORY
    # =============================================================================
    
    features_root = Path(
        vpp_features_data_folder_path
    )
    
    demand_root = Path(
        vpp_demand_data_folder_path
    )
    
    year_filename = f"{data_target_year}.csv"
    
    
    for zone in zone_names:
    
        print(
            f"\nProcessing VPP DHW demand: {zone}..."
        )
    
        # -------------------------------------------------------------------------
        # GET VPP DHW DATAFRAME
        # -------------------------------------------------------------------------
    
        if zone not in vpp_dhw_loads:
    
            print(
                f"  ⚠️ No VPP DHW profiles found for {zone}. "
                f"Skipping."
            )
    
            continue
    
        dhw_df = vpp_dhw_loads[zone].copy()
    
        print(
            f"  VPP DHW columns: "
            f"{len(dhw_df.columns)}"
        )
    
        print(
            f"  VPP DHW rows   : "
            f"{len(dhw_df)}"
        )
    
        print(
            f"  VPP DHW sectors: "
            f"{dhw_df.columns.tolist()}"
        )
    
    
        # -------------------------------------------------------------------------
        # IDENTIFY TIME STEP FROM THE INDEX
        # -------------------------------------------------------------------------
    
        snapshot_index = pd.to_datetime(
            dhw_df.index
        )
    
        if len(snapshot_index) < 2:
    
            raise ValueError(
                f"{zone}: at least two timestamps are "
                f"required to identify the time step."
            )
    
        time_difference = (
            snapshot_index[1]
            - snapshot_index[0]
        )
    
        if time_difference == pd.Timedelta(hours=1):
    
            time_step = "1h"
    
        elif time_difference == pd.Timedelta(minutes=30):
    
            time_step = "30min"
    
        elif time_difference == pd.Timedelta(minutes=15):
    
            time_step = "15min"
    
        else:
    
            raise ValueError(
                f"{zone}: unsupported time step detected: "
                f"{time_difference}"
            )
    
        print(
            f"  Time step      : {time_step}"
        )
    
    
        # -------------------------------------------------------------------------
        # READ VPP FEATURES CSV
        # -------------------------------------------------------------------------
    
        features_file = (
            features_root
            / zone
            / year_filename
        )
    
        features_df = pd.read_csv(
            features_file
        )
    
        # -------------------------------------------------------------------------
        # EXTRACT VPP SECTOR VALUES
        # -------------------------------------------------------------------------
    
        sector_values = (
            features_df["Sector"]
            .dropna()
            .astype(str)
            .tolist()
        )
    
        print(
            f"  Feature sectors: "
            f"{len(sector_values)}"
        )
    
    
        # -------------------------------------------------------------------------
        # CHECK NUMBER OF COLUMNS
        # -------------------------------------------------------------------------
    
        if len(dhw_df.columns) != len(sector_values):
    
            raise ValueError(
                f"{zone}: number of VPP DHW columns does not "
                f"match number of Sector values.\n"
                f"  VPP DHW columns : {len(dhw_df.columns)}\n"
                f"  Sector values   : {len(sector_values)}"
            )
    
    
        # -------------------------------------------------------------------------
        # RENAME VPP DHW COLUMNS USING SECTOR VALUES
        # -------------------------------------------------------------------------
    
        dhw_df.columns = sector_values
    
    
        # -------------------------------------------------------------------------
        # RESTORE SNAPSHOT INDEX
        # -------------------------------------------------------------------------
    
        dhw_df.index.name = "snapshot"
    
    
        # -------------------------------------------------------------------------
        # CREATE DESTINATION DIRECTORY
        # -------------------------------------------------------------------------
    
        destination_folder = (
            demand_root
            / zone
            / time_step
        )
    
        destination_folder.mkdir(
            parents=True,
            exist_ok=True
        )
    
    
        # -------------------------------------------------------------------------
        # DESTINATION FILE
        # -------------------------------------------------------------------------
    
        destination_file = (
            destination_folder
            / year_filename
        )
    
    
        # -------------------------------------------------------------------------
        # SAVE CSV
        # -------------------------------------------------------------------------
    
        dhw_df.to_csv(
            destination_file,
            index=True
        )
    
        print(
            f"  Saved to       : "
            f"{destination_file}"
        )
    
    
    # =============================================================================
    ### FINAL MESSAGE
    # =============================================================================
    
    print(
        "\n" + "=" * 100
    )
    
    print(
        "DONE: VPP DHW THERMAL DEMAND PROFILES COPIED "
        "TO THE VPP DEMAND DIRECTORY."
    )
    
    print(
        "=" * 100
    )
else:
    pass
# Out:
# Processing VPP DHW demand: BE...
#   VPP DHW columns: 2
#   VPP DHW rows   : 8760
#   VPP DHW sectors: ['DHW_VPP_0.9', 'DHW_VPP_0.99']
#   Time step      : 1h
#   Feature sectors: 2
#   Saved to       : /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario________VPP/VPP_data/VPP_demand/BE/1h/2030.csv
#
# Processing VPP DHW demand: FR...
#   VPP DHW columns: 2
#   VPP DHW rows   : 8760
#   VPP DHW sectors: ['DHW_VPP_0.9', 'DHW_VPP_0.99']
#   Time step      : 1h
#   Feature sectors: 2
#   Saved to       : /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario________VPP/VPP_data/VPP_demand/FR/1h/2030.csv
#
# Processing VPP DHW demand: DE...
#   VPP DHW columns: 2
#   VPP DHW rows   : 8760
#   VPP DHW sectors: ['DHW_VPP_0.9', 'DHW_VPP_0.99']
#   Time step      : 1h
#   Feature sectors: 2
#   Saved to       : /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario________VPP/VPP_data/VPP_demand/DE/1h/2030.csv
#
# Processing VPP DHW demand: NL...
#   VPP DHW columns: 2
#   VPP DHW rows   : 8760
#   VPP DHW sectors: ['DHW_VPP_0.9', 'DHW_VPP_0.99']
#   Time step      : 1h
#   Feature sectors: 2
#   Saved to       : /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario________VPP/VPP_data/VPP_demand/NL/1h/2030.csv
#
# Processing VPP DHW demand: UK...
#   VPP DHW columns: 2
#   VPP DHW rows   : 8760
#   VPP DHW sectors: ['DHW_VPP_0.9', 'DHW_VPP_0.99']
#   Time step      : 1h
#   Feature sectors: 2
#   Saved to       : /home/ray/Dispa-SET_Unleash/Database_PyPSA/Sufficiency_Scenario________VPP/VPP_data/VPP_demand/UK/1h/2030.csv
#
# ====================================================================================================
# DONE: VPP DHW THERMAL DEMAND PROFILES COPIED TO THE VPP DEMAND DIRECTORY.
# ====================================================================================================
